# %%
import pandas as pd

# %%
import numpy as np

# %%
#import data
df = pd.read_csv('2015.csv')

# %%
#filter data
rdf = df[['CADULT', 'MARITAL', 'INCOME2', '_AGEG5YR', 'CVDSTRK3', 'CVDINFR4', 'BPHIGH4', 'EXERANY2', 'DRNKANY5', '_RFSMOK3']]

# %%
rdf
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 0          NaN        1      3.0         9         2         2      1.0
# 1          NaN        2      1.0         7         2         2      3.0
# 2          NaN        2     99.0        11         1         7      3.0
# 3          NaN        1      8.0         9         2         2      1.0
# 4          NaN        1     77.0         9         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441451     2.0        3      4.0        11         2         2      1.0
# 441452     2.0        1      2.0         2         2         2      3.0
# 441453     2.0        1      5.0        11         2         2      1.0
# 441454     1.0        5      1.0         7         2         2      1.0
# 441455     2.0        1      2.0         9         2         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 0            2.0         2         1
# ...

# %% [markdown]
# FLOW OF PROGRAM
#
# Grouping
#
# Original statitics
#
# Answer 1 to question 1 statitics
#
# Answer 2 to question 1 statitics
#
# Answer 1 to question 2 statitics
#
# Answer 2 to question 2 statitics
#
# Answer 1 to question 3 statitics
#
# Answer 2 to question 3 statitics
#
# Next group
#
# Dataframe compiled and saved

# %%
#Female, married, below 35000 income, 18-39 age 
FMB1 = rdf[(rdf['CADULT'] == 2) &
           (rdf['MARITAL'] == 1) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))]
FMB1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3453       2.0        1      5.0         2         2         2      3.0
# 3454       2.0        1      5.0         3         2         2      3.0
# 3463       2.0        1      3.0         3         2         2      3.0
# 3583       2.0        1      5.0         4         2         2      1.0
# 3589       2.0        1      4.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441378     2.0        1      5.0         4         2         2      3.0
# 441391     2.0        1      1.0         4         2         2      1.0
# 441393     2.0        1      2.0         4         2         2      3.0
# 441443     2.0        1      2.0         3         2         2      3.0
# 441452     2.0        1      2.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3453         1.0         1         1
# ...

# %%
#Stroke Chance FMB1
stroke = 0
for x in FMB1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB1 = ((stroke / len(FMB1) * 100))

stroke_FMB1
# Out:
# 1.0342598577892694

# %%
#Heart Attack Chance FMB1
HA = 0
for x in FMB1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB1 = ((HA / len(FMB1) * 100))

HA_FMB1
# Out:
# 0.904977375565611

# %%
#High Blood pressure FMB1
HBP = 0
for x in FMB1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB1 = ((HBP / len(FMB1) * 100))

HBP_FMB1
# Out:
# 10.277957336780865

# %%
#FMB1_E1
FMB1_E1 = rdf[(rdf['CADULT'] == 2) &
           (rdf['MARITAL'] == 1) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 1)]
           
FMB1_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3453       2.0        1      5.0         2         2         2      3.0
# 3454       2.0        1      5.0         3         2         2      3.0
# 3463       2.0        1      3.0         3         2         2      3.0
# 3589       2.0        1      4.0         1         2         2      3.0
# 3603       2.0        1      5.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441182     2.0        1      3.0         1         2         2      3.0
# 441226     2.0        1      3.0         4         2         2      3.0
# 441246     2.0        1      3.0         1         2         2      3.0
# 441443     2.0        1      2.0         3         2         2      3.0
# 441452     2.0        1      2.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3453         1.0         1         1
# ...

# %%
#Stroke Chance FMB1_E1
stroke = 0
for x in FMB1_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB1_E1 = ((stroke / len(FMB1_E1) * 100))

stroke_FMB1_E1
# Out:
# 0.8478802992518704

# %%
#Heart Attack Chance FMB1_E1
HA = 0
for x in FMB1_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB1_E1 = ((HA / len(FMB1_E1) * 100))

HA_FMB1_E1
# Out:
# 0.997506234413965

# %%
#High Blood pressure FMB1
HBP = 0
for x in FMB1_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB1_E1 = ((HBP / len(FMB1_E1) * 100))

HBP_FMB1_E1
# Out:
# 9.42643391521197

# %%
#FMB1_E2
FMB1_E2 = rdf[(rdf['CADULT'] == 2) &
           (rdf['MARITAL'] == 1) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 2)]
           
FMB1_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3583       2.0        1      5.0         4         2         2      1.0
# 3697       2.0        1      2.0         1         2         2      1.0
# 3701       2.0        1      2.0         3         2         2      1.0
# 4005       2.0        1      1.0         3         2         2      3.0
# 4082       2.0        1      2.0         4         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441279     2.0        1      1.0         1         2         2      3.0
# 441303     2.0        1      3.0         1         2         2      3.0
# 441304     2.0        1      5.0         3         2         2      3.0
# 441322     2.0        1      5.0         3         2         2      3.0
# 441393     2.0        1      2.0         4         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3583         2.0         2         1
# ...

# %%
#Stroke Chance FMB1_E2
stroke = 0
for x in FMB1_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB1_E2 = ((stroke / len(FMB1_E2) * 100))

stroke_FMB1_E2
# Out:
# 1.3192612137203166

# %%
#Heart Attack Chance FMB1_E2
HA = 0
for x in FMB1_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB1_E2 = ((HA / len(FMB1_E2) * 100))

HA_FMB1_E2
# Out:
# 0.79155672823219

# %%
#High Blood pressure FMB1_E2
HBP = 0
for x in FMB1_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB1_E2 = ((HBP / len(FMB1_E2) * 100))

HBP_FMB1_E2
# Out:
# 13.192612137203167

# %%
#FMB1_D1
FMB1_D1 = rdf[(rdf['CADULT'] == 2) &
           (rdf['MARITAL'] == 1) &  
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 1)]
           
FMB1_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3453       2.0        1      5.0         2         2         2      3.0
# 3454       2.0        1      5.0         3         2         2      3.0
# 3603       2.0        1      5.0         2         2         2      3.0
# 3697       2.0        1      2.0         1         2         2      1.0
# 3701       2.0        1      2.0         3         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440948     2.0        1      3.0         1         2         2      3.0
# 441115     2.0        1      1.0         1         2         2      3.0
# 441246     2.0        1      3.0         1         2         2      3.0
# 441304     2.0        1      5.0         3         2         2      3.0
# 441322     2.0        1      5.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3453         1.0         1         1
# ...

# %%
#Stroke Chance FMB1_D1
stroke = 0
for x in FMB1_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB1_D1 = ((stroke / len(FMB1_D1) * 100))

stroke_FMB1_D1
# Out:
# 0.7714561234329798

# %%
#Heart Attack Chance FMB1_D1
HA = 0
for x in FMB1_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB1_D1 = ((HA / len(FMB1_D1) * 100))

HA_FMB1_D1
# Out:
# 1.0607521697203472

# %%
#High Blood pressure FMB1_D1
HBP = 0
for x in FMB1_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB1_D1 = ((HBP / len(FMB1_D1) * 100))

HBP_FMB1_D1
# Out:
# 9.643201542912246

# %%
#FMB1_D2
FMB1_D2 = rdf[(rdf['CADULT'] == 2) &
           (rdf['MARITAL'] == 1) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 2)]
           
FMB1_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3463       2.0        1      3.0         3         2         2      3.0
# 3583       2.0        1      5.0         4         2         2      1.0
# 3589       2.0        1      4.0         1         2         2      3.0
# 3800       2.0        1      4.0         3         2         2      3.0
# 3910       2.0        1      3.0         4         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441303     2.0        1      3.0         1         2         2      3.0
# 441391     2.0        1      1.0         4         2         2      1.0
# 441393     2.0        1      2.0         4         2         2      3.0
# 441443     2.0        1      2.0         3         2         2      3.0
# 441452     2.0        1      2.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3463         1.0         2         1
# ...

# %%
#Stroke Chance FMB1_D2
stroke = 0
for x in FMB1_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB1_D2 = ((stroke / len(FMB1_D2) * 100))

stroke_FMB1_D2
# Out:
# 1.0966057441253265

# %%
#Heart Attack Chance FMB1_D2
HA = 0
for x in FMB1_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB1_D2 = ((HA / len(FMB1_D2) * 100))

HA_FMB1_D2
# Out:
# 0.8877284595300261

# %%
#High Blood pressure FMB1_D2
HBP = 0
for x in FMB1_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB1_D2 = ((HBP / len(FMB1_D2) * 100))

HBP_FMB1_D2
# Out:
# 10.809399477806789

# %%
#FMB1_S1
FMB1_S1 = rdf[(rdf['CADULT'] == 2) &
           (rdf['MARITAL'] == 1) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 1)]
           
FMB1_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3453       2.0        1      5.0         2         2         2      3.0
# 3454       2.0        1      5.0         3         2         2      3.0
# 3463       2.0        1      3.0         3         2         2      3.0
# 3583       2.0        1      5.0         4         2         2      1.0
# 3589       2.0        1      4.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441303     2.0        1      3.0         1         2         2      3.0
# 441322     2.0        1      5.0         3         2         2      3.0
# 441391     2.0        1      1.0         4         2         2      1.0
# 441393     2.0        1      2.0         4         2         2      3.0
# 441452     2.0        1      2.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3453         1.0         1         1
# ...

# %%
#Stroke Chance FMB1_S1
stroke = 0
for x in FMB1_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB1_S1 = ((stroke / len(FMB1_S1) * 100))

stroke_FMB1_S1
# Out:
# 0.8

# %%
#Heart Attack Chance FMB1_S1
HA = 0
for x in FMB1_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB1_S1 = ((HA / len(FMB1_S1) * 100))

HA_FMB1_S1
# Out:
# 0.5894736842105264

# %%
#High Blood pressure FMB1_S1
HBP = 0
for x in FMB1_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB1_S1 = ((HBP / len(FMB1_S1) * 100))

HBP_FMB1_S1
# Out:
# 8.715789473684211

# %%
#FMB1_S2
FMB1_S2 = rdf[(rdf['CADULT'] == 2) &
           (rdf['MARITAL'] == 1) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 2)]
           
FMB1_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3979       2.0        1      5.0         2         2         2      1.0
# 4005       2.0        1      1.0         3         2         2      3.0
# 4140       2.0        1      1.0         2         2         2      1.0
# 4167       2.0        1      2.0         4         2         2      1.0
# 4184       2.0        1      1.0         3         1         1      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439873     2.0        1      1.0         3         2         2      1.0
# 440921     2.0        1      5.0         2         2         2      3.0
# 441083     2.0        1      2.0         1         2         2      3.0
# 441304     2.0        1      5.0         3         2         2      3.0
# 441443     2.0        1      2.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3979         NaN         1         2
# ...

# %%
#Stroke Chance FMB1_S2
stroke = 0
for x in FMB1_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB1_S2 = ((stroke / len(FMB1_S2) * 100))

stroke_FMB1_S2
# Out:
# 2.0202020202020203

# %%
#Heart Attack Chance FMB1_S2
HA = 0
for x in FMB1_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB1_S2 = ((HA / len(FMB1_S2) * 100))

HA_FMB1_S2
# Out:
# 2.1885521885521886

# %%
#High Blood pressure FMB1_S2
HBP = 0
for x in FMB1_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB1_S2 = ((HBP / len(FMB1_S2) * 100))

HBP_FMB1_S2
# Out:
# 17.003367003367003

# %%
#male, married, below 35000 income, 18-39 age
MMB1 = rdf[(rdf['CADULT'] == 1) &
           (rdf['MARITAL'] == 1) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))]
MMB1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3500       1.0        1      3.0         4         2         2      3.0
# 3648       1.0        1      2.0         1         2         2      3.0
# 3673       1.0        1      2.0         4         2         2      3.0
# 3840       1.0        1      2.0         4         2         2      1.0
# 3928       1.0        1      3.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441258     1.0        1      2.0         2         2         2      3.0
# 441334     1.0        1      4.0         1         2         2      3.0
# 441335     1.0        1      4.0         4         2         2      3.0
# 441396     1.0        1      1.0         3         2         1      1.0
# 441430     1.0        1      5.0         4         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3500         1.0         2         2
# ...

# %%
stroke = 0
for x in MMB1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB1 = ((stroke / len(MMB1) * 100))

stroke_MMB1
# Out:
# 0.8144020574367767

# %%
HA = 0
for x in MMB1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB1 = ((HA / len(MMB1) * 100))

HA_MMB1
# Out:
# 1.0715816545220747

# %%
HBP = 0
for x in MMB1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB1 = ((HBP / len(MMB1) * 100))
HBP_MMB1
# Out:
# 17.402486069438492

# %%
#MMB1_E1
MMB1_E1 = rdf[(rdf['CADULT'] == 1) &
           (rdf['MARITAL'] == 1) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 1)]
MMB1_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3500       1.0        1      3.0         4         2         2      3.0
# 3648       1.0        1      2.0         1         2         2      3.0
# 3673       1.0        1      2.0         4         2         2      3.0
# 3840       1.0        1      2.0         4         2         2      1.0
# 4177       1.0        1      4.0         2         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441123     1.0        1      4.0         4         2         2      1.0
# 441231     1.0        1      1.0         2         2         2      3.0
# 441252     1.0        1      4.0         4         2         2      1.0
# 441334     1.0        1      4.0         1         2         2      3.0
# 441335     1.0        1      4.0         4         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3500         1.0         2         2
# ...

# %%
stroke = 0
for x in MMB1_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB1_E1 = ((stroke / len(MMB1_E1) * 100))

stroke_MMB1_E1
# Out:
# 0.4905395935529082

# %%
HA = 0
for x in MMB1_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB1_E1 = ((HA / len(MMB1_E1) * 100))

HA_MMB1_E1
# Out:
# 0.9110021023125439

# %%
HBP = 0
for x in MMB1_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB1_E1 = ((HBP / len(MMB1_E1) * 100))
HBP_MMB1_E1
# Out:
# 17.379117028731606

# %%
#MMB1_E2
MMB1_E2 = rdf[(rdf['CADULT'] == 1) &
           (rdf['MARITAL'] == 1) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 2)]
MMB1_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3928       1.0        1      3.0         1         2         2      3.0
# 5052       1.0        1      4.0         3         2         2      3.0
# 5292       1.0        1      5.0         2         2         2      3.0
# 5620       1.0        1      2.0         4         2         1      4.0
# 5844       1.0        1      4.0         4         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441037     1.0        1      5.0         2         2         2      3.0
# 441109     1.0        1      3.0         4         2         2      1.0
# 441122     1.0        1      5.0         4         2         2      1.0
# 441258     1.0        1      2.0         2         2         2      3.0
# 441396     1.0        1      1.0         3         2         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3928         2.0         2         1
# ...

# %%
stroke = 0
for x in MMB1_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB1_E2 = ((stroke / len(MMB1_E2) * 100))

stroke_MMB1_E2
# Out:
# 1.1382113821138211

# %%
HA = 0
for x in MMB1_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB1_E2 = ((HA / len(MMB1_E2) * 100))

HA_MMB1_E2
# Out:
# 1.788617886178862

# %%
HBP = 0
for x in MMB1_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB1_E2 = ((HBP / len(MMB1_E2) * 100))
HBP_MMB1_E2
# Out:
# 19.1869918699187

# %%
#MMB1_D1
MMB1_D1 = rdf[(rdf['CADULT'] == 1) &
           (rdf['MARITAL'] == 1) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 1)]
MMB1_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3648       1.0        1      2.0         1         2         2      3.0
# 4177       1.0        1      4.0         2         2         2      1.0
# 4318       1.0        1      4.0         4         2         2      3.0
# 4886       1.0        1      1.0         2         2         2      3.0
# 5247       1.0        1      5.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441123     1.0        1      4.0         4         2         2      1.0
# 441252     1.0        1      4.0         4         2         2      1.0
# 441258     1.0        1      2.0         2         2         2      3.0
# 441334     1.0        1      4.0         1         2         2      3.0
# 441430     1.0        1      5.0         4         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3648         1.0         1         2
# ...

# %%
stroke = 0
for x in MMB1_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB1_D1 = ((stroke / len(MMB1_D1) * 100))

stroke_MMB1_D1
# Out:
# 0.5176876617773942

# %%
HA = 0
for x in MMB1_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB1_D1 = ((HA / len(MMB1_D1) * 100))

HA_MMB1_D1
# Out:
# 1.0353753235547885

# %%
HBP = 0
for x in MMB1_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB1_D1 = ((HBP / len(MMB1_D1) * 100))
HBP_MMB1_D1
# Out:
# 17.860224331320104

# %%
#MMB1_D2
MMB1_D2 = rdf[(rdf['CADULT'] == 1) &
           (rdf['MARITAL'] == 1) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 2)]
MMB1_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3500       1.0        1      3.0         4         2         2      3.0
# 3673       1.0        1      2.0         4         2         2      3.0
# 3840       1.0        1      2.0         4         2         2      1.0
# 3928       1.0        1      3.0         1         2         2      3.0
# 5032       1.0        1      3.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441109     1.0        1      3.0         4         2         2      1.0
# 441122     1.0        1      5.0         4         2         2      1.0
# 441231     1.0        1      1.0         2         2         2      3.0
# 441335     1.0        1      4.0         4         2         2      3.0
# 441396     1.0        1      1.0         3         2         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3500         1.0         2         2
# ...

# %%
stroke = 0
for x in MMB1_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB1_D2 = ((stroke / len(MMB1_D2) * 100))

stroke_MMB1_D2
# Out:
# 1.0516252390057361

# %%
HA = 0
for x in MMB1_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB1_D2 = ((HA / len(MMB1_D2) * 100))

HA_MMB1_D2
# Out:
# 1.0516252390057361

# %%
HBP = 0
for x in MMB1_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB1_D2 = ((HBP / len(MMB1_D2) * 100))
HBP_MMB1_D2
# Out:
# 17.495219885277248

# %%
#MMB1_S1
MMB1_S1 = rdf[(rdf['CADULT'] == 1) &
           (rdf['MARITAL'] == 1) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 1)]
MMB1_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3673       1.0        1      2.0         4         2         2      3.0
# 3840       1.0        1      2.0         4         2         2      1.0
# 3928       1.0        1      3.0         1         2         2      3.0
# 4177       1.0        1      4.0         2         2         2      1.0
# 4318       1.0        1      4.0         4         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441252     1.0        1      4.0         4         2         2      1.0
# 441334     1.0        1      4.0         1         2         2      3.0
# 441335     1.0        1      4.0         4         2         2      3.0
# 441396     1.0        1      1.0         3         2         1      1.0
# 441430     1.0        1      5.0         4         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3673         1.0         2         1
# ...

# %%
stroke = 0
for x in MMB1_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB1_S1 = ((stroke / len(MMB1_S1) * 100))

stroke_MMB1_S1
# Out:
# 0.6571087216248507

# %%
HA = 0
for x in MMB1_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB1_S1 = ((HA / len(MMB1_S1) * 100))

HA_MMB1_S1
# Out:
# 1.015531660692951

# %%
HBP = 0
for x in MMB1_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB1_S1 = ((HBP / len(MMB1_S1) * 100))
HBP_MMB1_S1
# Out:
# 16.726403823178014

# %%
#MMB1_S2
MMB1_S2 = rdf[(rdf['CADULT'] == 1) &
           (rdf['MARITAL'] == 1) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 2)]
MMB1_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3500       1.0        1      3.0         4         2         2      3.0
# 3648       1.0        1      2.0         1         2         2      3.0
# 5350       1.0        1      1.0         3         2         2      3.0
# 5408       1.0        1      3.0         3         2         2      3.0
# 5620       1.0        1      2.0         4         2         1      4.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 435879     1.0        1      3.0         3         2         2      1.0
# 439098     1.0        1      5.0         4         2         2      3.0
# 439416     1.0        1      1.0         1         2         2      1.0
# 439544     1.0        1      1.0         1         2         2      3.0
# 441258     1.0        1      2.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3500         1.0         2         2
# ...

# %%
stroke = 0
for x in MMB1_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB1_S2 = ((stroke / len(MMB1_S2) * 100))

stroke_MMB1_S2
# Out:
# 1.2727272727272727

# %%
HA = 0
for x in MMB1_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB1_S2 = ((HA / len(MMB1_S2) * 100))

HA_MMB1_S2
# Out:
# 1.4545454545454546

# %%
HBP = 0
for x in MMB1_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB1_S2 = ((HBP / len(MMB1_S2) * 100))
HBP_MMB1_S2
# Out:
# 19.818181818181817

# %%
#female, single, above 35000, 18-39
FSA1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))]
FSA1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3558       2.0        5      6.0         1         2         2      3.0
# 3582       2.0        5      8.0         2         2         2      3.0
# 3590       2.0        4      7.0         1         2         2      3.0
# 3657       2.0        5      6.0         2         2         2      3.0
# 3716       2.0        5      6.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441018     2.0        5      7.0         1         2         2      3.0
# 441146     2.0        6      7.0         3         2         2      3.0
# 441176     2.0        5      6.0         3         2         2      3.0
# 441284     2.0        6      6.0         2         2         2      3.0
# 441416     2.0        6      8.0         4         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3558         1.0         1         1
# ...

# %%
#Stroke Chance FSA1
stroke = 0
for x in FSA1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA1 = ((stroke / len(FSA1) * 100))

stroke_FSA1
# Out:
# 0.3264417845484222

# %%
#Heart Attack Chance FSA1
HA = 0
for x in FSA1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA1 = ((HA / len(FSA1) * 100))

HA_FSA1
# Out:
# 0.1865381625990984

# %%
#High Blood pressure FSA1
HBP = 0
for x in FSA1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA1 = ((HBP / len(FSA1) * 100))

HBP_FSA1
# Out:
# 7.445981657080678

# %%
#FSA1_E1
FSA1_E1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 1)]
FSA1_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3558       2.0        5      6.0         1         2         2      3.0
# 3582       2.0        5      8.0         2         2         2      3.0
# 3590       2.0        4      7.0         1         2         2      3.0
# 3657       2.0        5      6.0         2         2         2      3.0
# 3716       2.0        5      6.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440769     2.0        6      6.0         3         2         2      3.0
# 440994     2.0        5      6.0         4         2         2      3.0
# 441018     2.0        5      7.0         1         2         2      3.0
# 441176     2.0        5      6.0         3         2         2      3.0
# 441416     2.0        6      8.0         4         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3558         1.0         1         1
# ...

# %%
#Stroke Chance FSA1_E1
stroke = 0
for x in FSA1_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA1_E1 = ((stroke / len(FSA1_E1) * 100))

stroke_FSA1_E1
# Out:
# 0.2776675922253074

# %%
#Heart Attack Chance FSA1_E1
HA = 0
for x in FSA1_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA1_E1 = ((HA / len(FSA1_E1) * 100))

HA_FSA1_E1
# Out:
# 0.15866719555731854

# %%
#High Blood pressure FSA1_E1
HBP = 0
for x in FSA1_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA1_E1 = ((HBP / len(FSA1_E1) * 100))

HBP_FSA1_E1
# Out:
# 6.882189607298692

# %%
#FSA1_E2
FSA1_E2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 2)]
FSA1_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3737       2.0        5      7.0         1         2         2      3.0
# 3829       2.0        5      7.0         2         2         2      1.0
# 4213       2.0        5      7.0         1         2         2      3.0
# 4344       2.0        5      7.0         2         2         2      2.0
# 4436       2.0        2      7.0         4         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440278     2.0        5      6.0         2         2         2      3.0
# 440292     2.0        4      6.0         4         2         2      3.0
# 440487     2.0        6      7.0         4         2         2      3.0
# 441146     2.0        6      7.0         3         2         2      3.0
# 441284     2.0        6      6.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3737         2.0         2         1
# ...

# %%
#Stroke Chance FSA1_E2
stroke = 0
for x in FSA1_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA1_E2 = ((stroke / len(FSA1_E2) * 100))

stroke_FSA1_E2
# Out:
# 0.4778972520908005

# %%
#Heart Attack Chance FSA1_E2
HA = 0
for x in FSA1_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA1_E2 = ((HA / len(FSA1_E2) * 100))

HA_FSA1_E2
# Out:
# 0.23894862604540024

# %%
#High Blood pressure FSA1_E2
HBP = 0
for x in FSA1_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA1_E2 = ((HBP / len(FSA1_E2) * 100))

HBP_FSA1_E2
# Out:
# 9.67741935483871

# %%
#FSA1_D1
FSA1_D1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 1)]
FSA1_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3558       2.0        5      6.0         1         2         2      3.0
# 3582       2.0        5      8.0         2         2         2      3.0
# 3716       2.0        5      6.0         2         2         2      3.0
# 3820       2.0        5      7.0         2         2         2      3.0
# 3829       2.0        5      7.0         2         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440769     2.0        6      6.0         3         2         2      3.0
# 440994     2.0        5      6.0         4         2         2      3.0
# 441176     2.0        5      6.0         3         2         2      3.0
# 441284     2.0        6      6.0         2         2         2      3.0
# 441416     2.0        6      8.0         4         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3558         1.0         1         1
# ...

# %%
#Stroke Chance FSA1_D1
stroke = 0
for x in FSA1_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA1_D1 = ((stroke / len(FSA1_D1) * 100))

stroke_FSA1_D1
# Out:
# 0.24960290447016112

# %%
#Heart Attack Chance FSA1_D1
HA = 0
for x in FSA1_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA1_D1 = ((HA / len(FSA1_D1) * 100))

HA_FSA1_D1
# Out:
# 0.13614703880190604

# %%
#High Blood pressure FSA1_D1
HBP = 0
for x in FSA1_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA1_D1 = ((HBP / len(FSA1_D1) * 100))

HBP_FSA1_D1
# Out:
# 7.488087134104833

# %%
#FSA1_D2
FSA1_D2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 2)]
FSA1_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3590       2.0        4      7.0         1         2         2      3.0
# 3657       2.0        5      6.0         2         2         2      3.0
# 3737       2.0        5      7.0         1         2         2      3.0
# 3844       2.0        2      6.0         3         2         2      3.0
# 3950       2.0        5      8.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440292     2.0        4      6.0         4         2         2      3.0
# 440487     2.0        6      7.0         4         2         2      3.0
# 440559     2.0        5      8.0         2         2         2      3.0
# 441018     2.0        5      7.0         1         2         2      3.0
# 441146     2.0        6      7.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3590         1.0         2         1
# ...

# %%
#Stroke Chance FSA1_D2
stroke = 0
for x in FSA1_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA1_D2 = ((stroke / len(FSA1_D2) * 100))

stroke_FSA1_D2
# Out:
# 0.554016620498615

# %%
#Heart Attack Chance FSA1_D2
HA = 0
for x in FSA1_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA1_D2 = ((HA / len(FSA1_D2) * 100))

HA_FSA1_D2
# Out:
# 0.2770083102493075

# %%
#High Blood pressure FMB1_E2
HBP = 0
for x in FSA1_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA1_D2 = ((HBP / len(FSA1_D2) * 100))

HBP_FSA1_D2
# Out:
# 7.313019390581718

# %%
#FSA1_S1
FSA1_S1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 1)]
FSA1_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3558       2.0        5      6.0         1         2         2      3.0
# 3582       2.0        5      8.0         2         2         2      3.0
# 3590       2.0        4      7.0         1         2         2      3.0
# 3657       2.0        5      6.0         2         2         2      3.0
# 3716       2.0        5      6.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441018     2.0        5      7.0         1         2         2      3.0
# 441146     2.0        6      7.0         3         2         2      3.0
# 441176     2.0        5      6.0         3         2         2      3.0
# 441284     2.0        6      6.0         2         2         2      3.0
# 441416     2.0        6      8.0         4         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3558         1.0         1         1
# ...

# %%
#Stroke Chance FSA1_S1
stroke = 0
for x in FSA1_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA1_S1 = ((stroke / len(FSA1_S1) * 100))

stroke_FSA1_S1
# Out:
# 0.24262784621127287

# %%
#Heart Attack Chance FSA1_S1
HA = 0
for x in FSA1_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA1_S1 = ((HA / len(FSA1_S1) * 100))

HA_FSA1_S1
# Out:
# 0.13064576334453154

# %%
#High Blood pressure FSA1_S1
HBP = 0
for x in FSA1_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA1_S1 = ((HBP / len(FSA1_S1) * 100))

HBP_FSA1_S1
# Out:
# 6.7562523329600594

# %%
#FSA1_S2
FSA1_S2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 2)]
FSA1_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 4655       2.0        2      6.0         4         2         2      3.0
# 4740       2.0        2      7.0         2         2         2      3.0
# 4815       2.0        5      6.0         2         2         2      3.0
# 4849       2.0        2      6.0         3         2         2      3.0
# 5411       2.0        6      8.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 434076     2.0        6      6.0         4         2         2      2.0
# 435691     2.0        6      8.0         3         2         2      3.0
# 435857     2.0        4      8.0         3         2         2      3.0
# 435875     2.0        5      6.0         1         2         2      3.0
# 440994     2.0        5      6.0         4         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 4655         NaN         1         2
# ...

# %%
#Stroke Chance FSA1_S2
stroke = 0
for x in FSA1_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA1_S2 = ((stroke / len(FSA1_S2) * 100))

stroke_FSA1_S2
# Out:
# 0.904977375565611

# %%
#Heart Attack Chance FSA1_S2
HA = 0
for x in FSA1_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA1_S2 = ((HA / len(FSA1_S2) * 100))

HA_FSA1_S2
# Out:
# 0.4524886877828055

# %%
#High Blood pressure FSA1_S2
HBP = 0
for x in FSA1_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA1_S2 = ((HBP / len(FSA1_S2) * 100))

HBP_FSA1_S2
# Out:
# 11.312217194570136

# %%
#male, single, above 35000, 18-39
MSA1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))]
MSA1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3483       1.0        5      7.0         2         2         2      3.0
# 3513       1.0        5      7.0         2         2         2      3.0
# 3527       1.0        5      8.0         2         2         2      3.0
# 3554       1.0        4      7.0         4         2         2      1.0
# 3563       1.0        5      6.0         4         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441161     1.0        6      8.0         4         2         2      3.0
# 441184     1.0        5      6.0         2         2         2      3.0
# 441274     1.0        4      8.0         2         2         2      3.0
# 441381     1.0        5      6.0         1         2         2      3.0
# 441444     1.0        5      6.0         1         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3483         1.0         1         2
# ...

# %%
stroke = 0
for x in MSA1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA1 = ((stroke / len(MSA1) * 100))

stroke_MSA1
# Out:
# 0.34349953159154784

# %%
HA = 0
for x in MSA1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA1 = ((HA / len(MSA1) * 100))

HA_MSA1
# Out:
# 0.5308629124596649

# %%
HBP = 0
for x in MSA1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA1 = ((HBP / len(MSA1) * 100))
HBP_MSA1
# Out:
# 13.583845112938484

# %%
#MSA1_E1
MSA1_E1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 1)]
MSA1_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3483       1.0        5      7.0         2         2         2      3.0
# 3513       1.0        5      7.0         2         2         2      3.0
# 3554       1.0        4      7.0         4         2         2      1.0
# 3563       1.0        5      6.0         4         2         2      3.0
# 3598       1.0        6      7.0         3         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441045     1.0        6      7.0         4         2         2      3.0
# 441114     1.0        5      6.0         3         2         2      3.0
# 441184     1.0        5      6.0         2         2         2      3.0
# 441381     1.0        5      6.0         1         2         2      3.0
# 441444     1.0        5      6.0         1         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3483         1.0         1         2
# ...

# %%
stroke = 0
for x in MSA1_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA1_E1 = ((stroke / len(MSA1_E1) * 100))

stroke_MSA1_E1
# Out:
# 0.26720106880427524

# %%
HA = 0
for x in MSA1_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA1_E1 = ((HA / len(MSA1_E1) * 100))

HA_MSA1_E1
# Out:
# 0.41416165664662663

# %%
HBP = 0
for x in MSA1_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA1_E1 = ((HBP / len(MSA1_E1) * 100))
HBP_MSA1_E1
# Out:
# 12.852371409485638

# %%
#MSA1_E2
MSA1_E2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 2)]
MSA1_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3703       1.0        2      7.0         3         2         2      3.0
# 3740       1.0        2      6.0         4         2         2      3.0
# 3744       1.0        5      6.0         1         2         2      1.0
# 3817       1.0        5      7.0         2         2         2      3.0
# 3920       1.0        5      6.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439342     1.0        5      6.0         2         2         2      3.0
# 439411     1.0        6      7.0         3         2         2      3.0
# 440245     1.0        2      6.0         1         2         2      3.0
# 441161     1.0        6      8.0         4         2         2      3.0
# 441274     1.0        4      8.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3703         2.0         2         2
# ...

# %%
stroke = 0
for x in MSA1_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA1_E2 = ((stroke / len(MSA1_E2) * 100))

stroke_MSA1_E2
# Out:
# 0.8957654723127036

# %%
HA = 0
for x in MSA1_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA1_E2 = ((HA / len(MSA1_E2) * 100))

HA_MSA1_E2
# Out:
# 1.0586319218241043

# %%
HBP = 0
for x in MSA1_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA1_E2 = ((HBP / len(MSA1_E2) * 100))
HBP_MSA1_E2
# Out:
# 17.996742671009773

# %%
#MSA1_D1
MSA1_D1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 1)]
MSA1_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3483       1.0        5      7.0         2         2         2      3.0
# 3563       1.0        5      6.0         4         2         2      3.0
# 3598       1.0        6      7.0         3         2         2      3.0
# 3621       1.0        2      7.0         3         2         2      3.0
# 3659       1.0        5      6.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441114     1.0        5      6.0         3         2         2      3.0
# 441161     1.0        6      8.0         4         2         2      3.0
# 441274     1.0        4      8.0         2         2         2      3.0
# 441381     1.0        5      6.0         1         2         2      3.0
# 441444     1.0        5      6.0         1         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3483         1.0         1         2
# ...

# %%
stroke = 0
for x in MSA1_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA1_D1 = ((stroke / len(MSA1_D1) * 100))

stroke_MSA1_D1
# Out:
# 0.3700414446417999

# %%
HA = 0
for x in MSA1_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA1_D1 = ((HA / len(MSA1_D1) * 100))

HA_MSA1_D1
# Out:
# 0.5476613380698638

# %%
HBP = 0
for x in MSA1_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA1_D1 = ((HBP / len(MSA1_D1) * 100))
HBP_MSA1_D1
# Out:
# 14.328004736530492

# %%
#MSA1_D2
MSA1_D2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 2)]
MSA1_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3513       1.0        5      7.0         2         2         2      3.0
# 3527       1.0        5      8.0         2         2         2      3.0
# 3554       1.0        4      7.0         4         2         2      1.0
# 3703       1.0        2      7.0         3         2         2      3.0
# 3740       1.0        2      6.0         4         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440687     1.0        5      6.0         1         2         2      3.0
# 440871     1.0        6      6.0         4         2         2      3.0
# 440975     1.0        5      7.0         2         2         2      3.0
# 441045     1.0        6      7.0         4         2         2      3.0
# 441184     1.0        5      6.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3513         1.0         2         1
# ...

# %%
stroke = 0
for x in MSA1_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA1_D2 = ((stroke / len(MSA1_D2) * 100))

stroke_MSA1_D2
# Out:
# 0.28112449799196787

# %%
HA = 0
for x in MSA1_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA1_D2 = ((HA / len(MSA1_D2) * 100))

HA_MSA1_D2
# Out:
# 0.48192771084337355

# %%
HBP = 0
for x in MSA1_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA1_D2 = ((HBP / len(MSA1_D2) * 100))
HBP_MSA1_D2
# Out:
# 11.606425702811245

# %%
#MSA1_S1
MSA1_S1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 1)]
MSA1_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3513       1.0        5      7.0         2         2         2      3.0
# 3527       1.0        5      8.0         2         2         2      3.0
# 3554       1.0        4      7.0         4         2         2      1.0
# 3563       1.0        5      6.0         4         2         2      3.0
# 3659       1.0        5      6.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441161     1.0        6      8.0         4         2         2      3.0
# 441184     1.0        5      6.0         2         2         2      3.0
# 441274     1.0        4      8.0         2         2         2      3.0
# 441381     1.0        5      6.0         1         2         2      3.0
# 441444     1.0        5      6.0         1         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3513         1.0         2         1
# ...

# %%
stroke = 0
for x in MSA1_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA1_S1 = ((stroke / len(MSA1_S1) * 100))

stroke_MSA1_S1
# Out:
# 0.24606971975393027

# %%
HA = 0
for x in MSA1_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA1_S1 = ((HA / len(MSA1_S1) * 100))

HA_MSA1_S1
# Out:
# 0.3417634996582365

# %%
HBP = 0
for x in MSA1_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA1_S1 = ((HBP / len(MSA1_S1) * 100))
HBP_MSA1_S1
# Out:
# 12.276144907723856

# %%
#MSA1_S2
MSA1_S2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 2)]
MSA1_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3483       1.0        5      7.0         2         2         2      3.0
# 3598       1.0        6      7.0         3         2         2      3.0
# 3621       1.0        2      7.0         3         2         2      3.0
# 3703       1.0        2      7.0         3         2         2      3.0
# 3752       1.0        5      8.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439342     1.0        5      6.0         2         2         2      3.0
# 439644     1.0        5      6.0         3         2         2      3.0
# 440248     1.0        6      6.0         3         2         2      3.0
# 440259     1.0        5      7.0         4         2         2      1.0
# 440650     1.0        5      6.0         1         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3483         1.0         1         2
# ...

# %%
stroke = 0
for x in MSA1_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA1_S2 = ((stroke / len(MSA1_S2) * 100))

stroke_MSA1_S2
# Out:
# 0.7526342197691922

# %%
HA = 0
for x in MSA1_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA1_S2 = ((HA / len(MSA1_S2) * 100))

HA_MSA1_S2
# Out:
# 1.3045659809332664

# %%
HBP = 0
for x in MSA1_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA1_S2 = ((HBP / len(MSA1_S2) * 100))
HBP_MSA1_S2
# Out:
# 18.314099347717008

# %%
#female, married, above 35000, 18-39
FMA1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))]
FMA1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3512       2.0        1      8.0         4         2         2      3.0
# 3641       2.0        1      6.0         1         2         2      3.0
# 3649       2.0        1      8.0         4         2         2      3.0
# 3656       2.0        1      8.0         3         2         2      3.0
# 3682       2.0        1      7.0         3         2         2      2.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441108     2.0        1      6.0         4         2         2      1.0
# 441174     2.0        1      8.0         3         1         2      3.0
# 441175     2.0        1      6.0         3         2         2      3.0
# 441341     2.0        1      7.0         2         2         2      1.0
# 441369     2.0        1      6.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3512         1.0         2         2
# ...

# %%
#Stroke Chance FMA1
stroke = 0
for x in FMA1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA1 = ((stroke / len(FMA1) * 100))

stroke_FMA1
# Out:
# 0.507998270644185

# %%
#Heart Attack Chance FMA1
HA = 0
for x in FMA1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA1 = ((HA / len(FMA1) * 100))

HA_FMA1
# Out:
# 0.28102031993082577

# %%
#High Blood pressure FMA1
HBP = 0
for x in FMA1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA1 = ((HBP / len(FMA1) * 100))

HBP_FMA1
# Out:
# 6.2797233030696065

# %%
#FMA1_E1
FMA1_E1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 1)]
FMA1_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3512       2.0        1      8.0         4         2         2      3.0
# 3641       2.0        1      6.0         1         2         2      3.0
# 3649       2.0        1      8.0         4         2         2      3.0
# 3682       2.0        1      7.0         3         2         2      2.0
# 3685       2.0        1      8.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441103     2.0        1      7.0         4         2         2      3.0
# 441108     2.0        1      6.0         4         2         2      1.0
# 441174     2.0        1      8.0         3         1         2      3.0
# 441175     2.0        1      6.0         3         2         2      3.0
# 441341     2.0        1      7.0         2         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3512         1.0         2         2
# ...

# %%
#Stroke Chance FMA1_E1
stroke = 0
for x in FMA1_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA1_E1 = ((stroke / len(FMA1_E1) * 100))

stroke_FMA1_E1
# Out:
# 0.5009741163373226

# %%
#Heart Attack Chance FMA1_E1
HA = 0
for x in FMA1_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA1_E1 = ((HA / len(FMA1_E1) * 100))

HA_FMA1_E1
# Out:
# 0.18090731978847757

# %%
#High Blood pressure FMA1_E1
HBP = 0
for x in FMA1_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA1_E1 = ((HBP / len(FMA1_E1) * 100))

HBP_FMA1_E1
# Out:
# 6.081269134428054

# %%
#FMA1_E2
FMA1_E2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 2)]
FMA1_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3656       2.0        1      8.0         3         2         2      3.0
# 3690       2.0        1      8.0         4         2         2      3.0
# 3769       2.0        1      8.0         3         2         2      3.0
# 3782       2.0        1      7.0         3         2         2      3.0
# 3799       2.0        1      8.0         4         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440987     2.0        1      8.0         4         2         2      3.0
# 440992     2.0        1      6.0         4         2         2      3.0
# 440997     2.0        1      6.0         4         2         2      3.0
# 441051     2.0        1      6.0         3         2         2      3.0
# 441369     2.0        1      6.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3656         2.0         1         1
# ...

# %%
#Stroke Chance FMA1_E2
stroke = 0
for x in FMA1_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA1_E2 = ((stroke / len(FMA1_E2) * 100))

stroke_FMA1_E2
# Out:
# 0.43103448275862066

# %%
#Heart Attack Chance FMA1_E2
HA = 0
for x in FMA1_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA1_E2 = ((HA / len(FMA1_E2) * 100))

HA_FMA1_E2
# Out:
# 0.646551724137931

# %%
#High Blood pressure FMA1_E2
HBP = 0
for x in FMA1_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA1_E2 = ((HBP / len(FMA1_E2) * 100))

HBP_FMA1_E2
# Out:
# 7.471264367816093

# %%
#FMA1_D1
FMA1_D1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 1)]
FMA1_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3649       2.0        1      8.0         4         2         2      3.0
# 3656       2.0        1      8.0         3         2         2      3.0
# 3690       2.0        1      8.0         4         2         2      3.0
# 3769       2.0        1      8.0         3         2         2      3.0
# 3885       2.0        1      8.0         4         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440911     2.0        1      6.0         2         2         2      1.0
# 440987     2.0        1      8.0         4         2         2      3.0
# 440997     2.0        1      6.0         4         2         2      3.0
# 441174     2.0        1      8.0         3         1         2      3.0
# 441175     2.0        1      6.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3649         1.0         1         1
# ...

# %%
#Stroke Chance FMA1_D1
stroke = 0
for x in FMA1_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA1_D1 = ((stroke / len(FMA1_D1) * 100))

stroke_FMA1_D1
# Out:
# 0.4952380952380952

# %%
#Heart Attack Chance FMA1_D1
HA = 0
for x in FMA1_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA1_D1 = ((HA / len(FMA1_D1) * 100))

HA_FMA1_D1
# Out:
# 0.19047619047619047

# %%
#High Blood pressure FMA1_D1
HBP = 0
for x in FMA1_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA1_D1 = ((HBP / len(FMA1_D1) * 100))

HBP_FMA1_D1
# Out:
# 6.076190476190476

# %%
#FMA1_D2
FMA1_D2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 2)]
FMA1_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3512       2.0        1      8.0         4         2         2      3.0
# 3641       2.0        1      6.0         1         2         2      3.0
# 3682       2.0        1      7.0         3         2         2      2.0
# 3685       2.0        1      8.0         2         2         2      3.0
# 3782       2.0        1      7.0         3         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441051     2.0        1      6.0         3         2         2      3.0
# 441103     2.0        1      7.0         4         2         2      3.0
# 441108     2.0        1      6.0         4         2         2      1.0
# 441341     2.0        1      7.0         2         2         2      1.0
# 441369     2.0        1      6.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3512         1.0         2         2
# ...

# %%
#Stroke Chance FMA1_D2
stroke = 0
for x in FMA1_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA1_D2 = ((stroke / len(FMA1_D2) * 100))

stroke_FMA1_D2
# Out:
# 0.4829621679635095

# %%
#Heart Attack Chance FMA1_D2
HA = 0
for x in FMA1_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA1_D2 = ((HA / len(FMA1_D2) * 100))

HA_FMA1_D2
# Out:
# 0.3756372417493963

# %%
#High Blood pressure FMA1_D2
HBP = 0
for x in FMA1_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA1_D2 = ((HBP / len(FMA1_D2) * 100))

HBP_FMA1_D2
# Out:
# 6.546820499060907

# %%
#FMA1_S1
FMA1_S1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 1)]
FMA1_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3641       2.0        1      6.0         1         2         2      3.0
# 3649       2.0        1      8.0         4         2         2      3.0
# 3656       2.0        1      8.0         3         2         2      3.0
# 3682       2.0        1      7.0         3         2         2      2.0
# 3685       2.0        1      8.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441103     2.0        1      7.0         4         2         2      3.0
# 441108     2.0        1      6.0         4         2         2      1.0
# 441174     2.0        1      8.0         3         1         2      3.0
# 441341     2.0        1      7.0         2         2         2      1.0
# 441369     2.0        1      6.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3641         1.0         2         1
# ...

# %%
#Stroke Chance FMA1_S1
stroke = 0
for x in FMA1_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA1_S1 = ((stroke / len(FMA1_S1) * 100))

stroke_FMA1_S1
# Out:
# 0.4270896888346553

# %%
#Heart Attack Chance FMA1_S1
HA = 0
for x in FMA1_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA1_S1 = ((HA / len(FMA1_S1) * 100))

HA_FMA1_S1
# Out:
# 0.23184868822452714

# %%
#High Blood pressure FMA1_S1
HBP = 0
for x in FMA1_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA1_S1 = ((HBP / len(FMA1_S1) * 100))

HBP_FMA1_S1
# Out:
# 5.845027455765711

# %%
#FMA1_S2
FMA1_S2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 2)]
FMA1_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3512       2.0        1      8.0         4         2         2      3.0
# 3769       2.0        1      8.0         3         2         2      3.0
# 3971       2.0        1      8.0         4         2         2      3.0
# 4024       2.0        1      7.0         4         2         2      1.0
# 4078       2.0        1      6.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 434029     2.0        1      8.0         2         2         2      3.0
# 434244     2.0        1      6.0         4         2         2      3.0
# 434255     2.0        1      8.0         4         2         2      3.0
# 435823     2.0        1      8.0         4         2         2      1.0
# 441175     2.0        1      6.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3512         1.0         2         2
# ...

# %%
#Stroke Chance FMA1_S2
stroke = 0
for x in FMA1_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA1_S2 = ((stroke / len(FMA1_S2) * 100))

stroke_FMA1_S2
# Out:
# 1.2121212121212122

# %%
#Heart Attack Chance FMA1_S2
HA = 0
for x in FMA1_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA1_S2 = ((HA / len(FMA1_S2) * 100))

HA_FMA1_S2
# Out:
# 0.6060606060606061

# %%
#High Blood pressure FMA1_S2
HBP = 0
for x in FMA1_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA1_S2 = ((HBP / len(FMA1_S2) * 100))

HBP_FMA1_S2
# Out:
# 10.787878787878787

# %%
#male, married, above 35000, 18-39
MMA1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))]
MMA1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3482       1.0        1      6.0         3         2         2      3.0
# 3516       1.0        1      8.0         3         2         2      3.0
# 3579       1.0        1      8.0         2         2         2      3.0
# 3652       1.0        1      8.0         4         2         7      1.0
# 3721       1.0        1      7.0         3         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440852     1.0        1      7.0         3         2         2      3.0
# 441130     1.0        1      6.0         4         2         2      3.0
# 441350     1.0        1      8.0         4         2         2      1.0
# 441372     1.0        1      7.0         4         2         2      3.0
# 441448     1.0        1      8.0         3         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3482         1.0         2         1
# ...

# %%
stroke = 0
for x in MMA1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA1 = ((stroke / len(MMA1) * 100))

stroke_MMA1
# Out:
# 0.24714605154760502

# %%
HA = 0
for x in MMA1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA1 = ((HA / len(MMA1) * 100))

HA_MMA1
# Out:
# 0.43544780510768505

# %%
HBP = 0
for x in MMA1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA1 = ((HBP / len(MMA1) * 100))
HBP_MMA1
# Out:
# 16.676474049664588

# %%
#MMA1_E1
MMA1_E1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 1)]
MMA1_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3482       1.0        1      6.0         3         2         2      3.0
# 3579       1.0        1      8.0         2         2         2      3.0
# 3721       1.0        1      7.0         3         2         2      3.0
# 3738       1.0        1      8.0         3         2         2      3.0
# 3778       1.0        1      7.0         4         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440760     1.0        1      8.0         3         2         2      3.0
# 440804     1.0        1      6.0         4         2         2      3.0
# 441130     1.0        1      6.0         4         2         2      3.0
# 441372     1.0        1      7.0         4         2         2      3.0
# 441448     1.0        1      8.0         3         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3482         1.0         2         1
# ...

# %%
stroke = 0
for x in MMA1_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA1_E1 = ((stroke / len(MMA1_E1) * 100))

stroke_MMA1_E1
# Out:
# 0.18838304552590265

# %%
HA = 0
for x in MMA1_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA1_E1 = ((HA / len(MMA1_E1) * 100))

HA_MMA1_E1
# Out:
# 0.423861852433281

# %%
HBP = 0
for x in MMA1_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA1_E1 = ((HBP / len(MMA1_E1) * 100))
HBP_MMA1_E1
# Out:
# 16.20094191522763

# %%
#MMA1_E2
MMA1_E2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 2)]
MMA1_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3516       1.0        1      8.0         3         2         2      3.0
# 3652       1.0        1      8.0         4         2         7      1.0
# 3739       1.0        1      8.0         2         2         2      3.0
# 3822       1.0        1      7.0         2         2         2      3.0
# 3977       1.0        1      8.0         3         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439751     1.0        1      6.0         3         2         2      1.0
# 439869     1.0        1      6.0         4         2         2      3.0
# 440096     1.0        1      6.0         4         2         2      1.0
# 440852     1.0        1      7.0         3         2         2      3.0
# 441350     1.0        1      8.0         4         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3516         2.0         1         1
# ...

# %%
stroke = 0
for x in MMA1_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA1_E2 = ((stroke / len(MMA1_E2) * 100))

stroke_MMA1_E2
# Out:
# 0.44709388971684055

# %%
HA = 0
for x in MMA1_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA1_E2 = ((HA / len(MMA1_E2) * 100))

HA_MMA1_E2
# Out:
# 0.5961251862891207

# %%
HBP = 0
for x in MMA1_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA1_E2 = ((HBP / len(MMA1_E2) * 100))
HBP_MMA1_E2
# Out:
# 19.523099850968702

# %%
#MMA1_D1
MMA1_D1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 1)]
MMA1_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3516       1.0        1      8.0         3         2         2      3.0
# 3579       1.0        1      8.0         2         2         2      3.0
# 3652       1.0        1      8.0         4         2         7      1.0
# 3721       1.0        1      7.0         3         2         2      3.0
# 3738       1.0        1      8.0         3         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440353     1.0        1      6.0         4         2         7      1.0
# 440440     1.0        1      8.0         3         2         2      3.0
# 440760     1.0        1      8.0         3         2         2      3.0
# 441350     1.0        1      8.0         4         2         2      1.0
# 441448     1.0        1      8.0         3         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3516         2.0         1         1
# ...

# %%
stroke = 0
for x in MMA1_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA1_D1 = ((stroke / len(MMA1_D1) * 100))

stroke_MMA1_D1
# Out:
# 0.24229837313949465

# %%
HA = 0
for x in MMA1_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA1_D1 = ((HA / len(MMA1_D1) * 100))

HA_MMA1_D1
# Out:
# 0.3461405330564209

# %%
HBP = 0
for x in MMA1_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA1_D1 = ((HBP / len(MMA1_D1) * 100))
HBP_MMA1_D1
# Out:
# 16.857043959847697

# %%
#MMA1_D2
MMA1_D2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 2)]
MMA1_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3482       1.0        1      6.0         3         2         2      3.0
# 3778       1.0        1      7.0         4         2         2      3.0
# 3889       1.0        1      8.0         4         2         2      3.0
# 3899       1.0        1      8.0         4         2         2      3.0
# 3913       1.0        1      8.0         3         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440429     1.0        1      7.0         4         2         2      3.0
# 440804     1.0        1      6.0         4         2         2      3.0
# 440852     1.0        1      7.0         3         2         2      3.0
# 441130     1.0        1      6.0         4         2         2      3.0
# 441372     1.0        1      7.0         4         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3482         1.0         2         1
# ...

# %%
stroke = 0
for x in MMA1_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA1_D2 = ((stroke / len(MMA1_D2) * 100))

stroke_MMA1_D2
# Out:
# 0.24937655860349126

# %%
HA = 0
for x in MMA1_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA1_D2 = ((HA / len(MMA1_D2) * 100))

HA_MMA1_D2
# Out:
# 0.7065669160432253

# %%
HBP = 0
for x in MMA1_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA1_D2 = ((HBP / len(MMA1_D2) * 100))
HBP_MMA1_D2
# Out:
# 15.96009975062344

# %%
#MMA1_S1
MMA1_S1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 1)]
MMA1_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3482       1.0        1      6.0         3         2         2      3.0
# 3516       1.0        1      8.0         3         2         2      3.0
# 3579       1.0        1      8.0         2         2         2      3.0
# 3721       1.0        1      7.0         3         2         2      3.0
# 3739       1.0        1      8.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440804     1.0        1      6.0         4         2         2      3.0
# 440852     1.0        1      7.0         3         2         2      3.0
# 441130     1.0        1      6.0         4         2         2      3.0
# 441350     1.0        1      8.0         4         2         2      1.0
# 441448     1.0        1      8.0         3         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3482         1.0         2         1
# ...

# %%
stroke = 0
for x in MMA1_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA1_S1 = ((stroke / len(MMA1_S1) * 100))

stroke_MMA1_S1
# Out:
# 0.22516183506895582

# %%
HA = 0
for x in MMA1_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA1_S1 = ((HA / len(MMA1_S1) * 100))

HA_MMA1_S1
# Out:
# 0.3518153672952435

# %%
HBP = 0
for x in MMA1_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA1_S1 = ((HBP / len(MMA1_S1) * 100))
HBP_MMA1_S1
# Out:
# 15.761328454826906

# %%
#MMA1_S2
MMA1_S2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 2)]
MMA1_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3652       1.0        1      8.0         4         2         7      1.0
# 3738       1.0        1      8.0         3         2         2      3.0
# 3778       1.0        1      7.0         4         2         2      3.0
# 3878       1.0        1      8.0         4         2         2      1.0
# 3977       1.0        1      8.0         3         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 436049     1.0        1      6.0         4         2         2      3.0
# 438676     1.0        1      7.0         2         2         2      3.0
# 439751     1.0        1      6.0         3         2         2      1.0
# 440440     1.0        1      8.0         3         2         2      3.0
# 441372     1.0        1      7.0         4         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3652         2.0         1         2
# ...

# %%
stroke = 0
for x in MMA1_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA1_S2 = ((stroke / len(MMA1_S2) * 100))

stroke_MMA1_S2
# Out:
# 0.3590664272890485

# %%
HA = 0
for x in MMA1_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA1_S2 = ((HA / len(MMA1_S2) * 100))

HA_MMA1_S2
# Out:
# 0.8976660682226212

# %%
HBP = 0
for x in MMA1_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA1_S2 = ((HBP / len(MMA1_S2) * 100))
HBP_MMA1_S2
# Out:
# 21.723518850987432

# %%
#Female, single, below 35000, 18-39
FSB1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))]
FSB1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3481       2.0        4      3.0         3         2         2      1.0
# 3501       2.0        2      1.0         4         2         2      1.0
# 3514       2.0        5      3.0         1         2         2      3.0
# 3529       2.0        5      4.0         4         2         2      3.0
# 3531       2.0        5      5.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441402     2.0        2      5.0         4         2         2      3.0
# 441403     2.0        5      1.0         1         2         2      3.0
# 441415     2.0        5      4.0         2         2         2      3.0
# 441418     2.0        2      5.0         3         2         2      3.0
# 441449     2.0        6      5.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3481         1.0         2         1
# ...

# %%
#Stroke Chance FSB1
stroke = 0
for x in FSB1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB1 = ((stroke / len(FSB1) * 100))

stroke_FSB1
# Out:
# 1.181017822632596

# %%
#Heart Attack Chance FSB1
HA = 0
for x in FSB1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB1 = ((HA / len(FSB1) * 100))

HA_FSB1
# Out:
# 0.8911316298045951

# %%
#High Blood pressure FSB1
HBP = 0
for x in FSB1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB1 = ((HBP / len(FSB1) * 100))

HBP_FSB1
# Out:
# 11.23040584066996

# %%
#FSB1_E1
FSB1_E1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 1)]
FSB1_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3481       2.0        4      3.0         3         2         2      1.0
# 3514       2.0        5      3.0         1         2         2      3.0
# 3529       2.0        5      4.0         4         2         2      3.0
# 3541       2.0        5      3.0         1         2         2      3.0
# 3564       2.0        6      4.0         1         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441370     2.0        2      4.0         4         2         2      1.0
# 441380     2.0        4      1.0         2         2         2      3.0
# 441390     2.0        4      2.0         1         2         2      3.0
# 441415     2.0        5      4.0         2         2         2      3.0
# 441418     2.0        2      5.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3481         1.0         2         1
# ...

# %%
#Stroke Chance FSB1_E1
stroke = 0
for x in FSB1_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB1_E1 = ((stroke / len(FSB1_E1) * 100))

stroke_FSB1_E1
# Out:
# 1.0341431385423505

# %%
#Heart Attack Chance FSB1_E1
HA = 0
for x in FSB1_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB1_E1 = ((HA / len(FSB1_E1) * 100))

HA_FSB1_E1
# Out:
# 0.7386736703873933

# %%
#High Blood pressure FSB1_E1
HBP = 0
for x in FSB1_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB1_E1 = ((HBP / len(FSB1_E1) * 100))

HBP_FSB1_E1
# Out:
# 10.35784635587656

# %%
#FSB1_E2
FSB1_E2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 2)]
FSB1_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3501       2.0        2      1.0         4         2         2      1.0
# 3531       2.0        5      5.0         2         2         2      3.0
# 3549       2.0        6      3.0         3         2         2      3.0
# 3629       2.0        4      2.0         4         2         2      2.0
# 3736       2.0        4      4.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441389     2.0        5      3.0         1         2         2      3.0
# 441394     2.0        5      1.0         2         2         2      3.0
# 441397     2.0        5      1.0         2         2         2      3.0
# 441402     2.0        2      5.0         4         2         2      3.0
# 441449     2.0        6      5.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3501         2.0         2         2
# ...

# %%
#Stroke Chance FSB1_E2
stroke = 0
for x in FSB1_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB1_E2 = ((stroke / len(FSB1_E2) * 100))

stroke_FSB1_E2
# Out:
# 1.4726184997699034

# %%
#Heart Attack Chance FSB1_E2
HA = 0
for x in FSB1_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB1_E2 = ((HA / len(FSB1_E2) * 100))

HA_FSB1_E2
# Out:
# 1.1965025310630464

# %%
#High Blood pressure FSB1_E2
HBP = 0
for x in FSB1_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB1_E2 = ((HBP / len(FSB1_E2) * 100))

HBP_FSB1_E2
# Out:
# 13.989875747814082

# %%
#FSB1_D1
FSB1_D1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 1)]
FSB1_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3531       2.0        5      5.0         2         2         2      3.0
# 3546       2.0        5      4.0         2         2         2      3.0
# 3564       2.0        6      4.0         1         2         2      1.0
# 3581       2.0        5      3.0         3         2         2      3.0
# 3599       2.0        5      3.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441353     2.0        2      3.0         3         2         2      3.0
# 441394     2.0        5      1.0         2         2         2      3.0
# 441397     2.0        5      1.0         2         2         2      3.0
# 441402     2.0        2      5.0         4         2         2      3.0
# 441418     2.0        2      5.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3531         2.0         1         1
# ...

# %%
#Stroke Chance FSB1_D1
stroke = 0
for x in FSB1_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB1_D1 = ((stroke / len(FSB1_D1) * 100))

stroke_FSB1_D1
# Out:
# 0.9236314485244426

# %%
#Heart Attack Chance FSB1_D1
HA = 0
for x in FSB1_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB1_D1 = ((HA / len(FSB1_D1) * 100))

HA_FSB1_D1
# Out:
# 0.7884658706915972

# %%
#High Blood pressure FSB1_D1
HBP = 0
for x in FSB1_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB1_D1 = ((HBP / len(FSB1_D1) * 100))

HBP_FSB1_D1
# Out:
# 10.678080648794772

# %%
#FSB1_D2
FSB1_D2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 2)]
FSB1_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3481       2.0        4      3.0         3         2         2      1.0
# 3501       2.0        2      1.0         4         2         2      1.0
# 3514       2.0        5      3.0         1         2         2      3.0
# 3529       2.0        5      4.0         4         2         2      3.0
# 3541       2.0        5      3.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441389     2.0        5      3.0         1         2         2      3.0
# 441390     2.0        4      2.0         1         2         2      3.0
# 441403     2.0        5      1.0         1         2         2      3.0
# 441415     2.0        5      4.0         2         2         2      3.0
# 441449     2.0        6      5.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3481         1.0         2         1
# ...

# %%
#Stroke Chance FSB1_D2
stroke = 0
for x in FSB1_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB1_D2 = ((stroke / len(FSB1_D2) * 100))

stroke_FSB1_D2
# Out:
# 1.418918918918919

# %%
#Heart Attack Chance FSB1_D2
HA = 0
for x in FSB1_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB1_D2 = ((HA / len(FSB1_D2) * 100))

HA_FSB1_D2
# Out:
# 0.990990990990991

# %%
#High Blood pressure FSB1_D2
HBP = 0
for x in FSB1_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB1_D2 = ((HBP / len(FSB1_D2) * 100))

HBP_FSB1_D2
# Out:
# 11.621621621621623

# %%
#FSB1_S1
FSB1_S1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 1)]
FSB1_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3481       2.0        4      3.0         3         2         2      1.0
# 3514       2.0        5      3.0         1         2         2      3.0
# 3529       2.0        5      4.0         4         2         2      3.0
# 3531       2.0        5      5.0         2         2         2      3.0
# 3541       2.0        5      3.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441402     2.0        2      5.0         4         2         2      3.0
# 441403     2.0        5      1.0         1         2         2      3.0
# 441415     2.0        5      4.0         2         2         2      3.0
# 441418     2.0        2      5.0         3         2         2      3.0
# 441449     2.0        6      5.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3481         1.0         2         1
# ...

# %%
#Stroke Chance FSB1_S1
stroke = 0
for x in FSB1_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB1_S1 = ((stroke / len(FSB1_S1) * 100))

stroke_FSB1_S1
# Out:
# 0.8360704687966557

# %%
#Heart Attack Chance FSB1_S1
HA = 0
for x in FSB1_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB1_S1 = ((HA / len(FSB1_S1) * 100))

HA_FSB1_S1
# Out:
# 0.5374738727978501

# %%
#High Blood pressure FSB1_S1
HBP = 0
for x in FSB1_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB1_S1 = ((HBP / len(FSB1_S1) * 100))

HBP_FSB1_S1
# Out:
# 9.510301582561958

# %%
#FSB1_S2
FSB1_S2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 2)]
FSB1_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3501       2.0        2      1.0         4         2         2      1.0
# 3549       2.0        6      3.0         3         2         2      3.0
# 3564       2.0        6      4.0         1         2         2      1.0
# 3736       2.0        4      4.0         2         2         2      3.0
# 3764       2.0        5      1.0         3         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441023     2.0        5      1.0         3         2         2      3.0
# 441026     2.0        5      1.0         2         2         2      1.0
# 441348     2.0        6      3.0         3         2         2      3.0
# 441353     2.0        2      3.0         3         2         2      3.0
# 441376     2.0        6      1.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3501         2.0         2         2
# ...

# %%
#Stroke Chance FSB1_S2
stroke = 0
for x in FSB1_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB1_S2 = ((stroke / len(FSB1_S2) * 100))

stroke_FSB1_S2
# Out:
# 2.10989010989011

# %%
#Heart Attack Chance FSB1_S2
HA = 0
for x in FSB1_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB1_S2 = ((HA / len(FSB1_S2) * 100))

HA_FSB1_S2
# Out:
# 1.8461538461538463

# %%
#High Blood pressure FSB1_S2
HBP = 0
for x in FSB1_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB1_S2 = ((HBP / len(FSB1_S2) * 100))

HBP_FSB1_S2
# Out:
# 16.21978021978022

# %%
#male, single, below 35000, 18-39
MSB1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))]
MSB1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3490       1.0        6      5.0         1         2         2      3.0
# 3504       1.0        2      4.0         2         2         2      3.0
# 3506       1.0        5      2.0         1         2         2      3.0
# 3509       1.0        5      2.0         2         2         2      3.0
# 3556       1.0        5      4.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441367     1.0        6      4.0         2         2         2      1.0
# 441386     1.0        3      4.0         4         2         2      3.0
# 441405     1.0        6      3.0         2         2         2      3.0
# 441411     1.0        6      1.0         3         2         2      3.0
# 441434     1.0        5      5.0         1         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3490         1.0         2         2
# ...

# %%
stroke = 0
for x in MSB1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB1 = ((stroke / len(MSB1) * 100))

stroke_MSB1
# Out:
# 0.8421870951023581

# %%
HA = 0
for x in MSB1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB1 = ((HA / len(MSB1) * 100))

HA_MSB1
# Out:
# 0.9717543405027208

# %%
HBP = 0
for x in MSB1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB1 = ((HBP / len(MSB1) * 100))
HBP_MSB1
# Out:
# 15.2500647836227

# %%
#MSB1_E1
MSB1_E1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 1)]
MSB1_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3481       2.0        4      3.0         3         2         2      1.0
# 3514       2.0        5      3.0         1         2         2      3.0
# 3529       2.0        5      4.0         4         2         2      3.0
# 3541       2.0        5      3.0         1         2         2      3.0
# 3564       2.0        6      4.0         1         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441370     2.0        2      4.0         4         2         2      1.0
# 441380     2.0        4      1.0         2         2         2      3.0
# 441390     2.0        4      2.0         1         2         2      3.0
# 441415     2.0        5      4.0         2         2         2      3.0
# 441418     2.0        2      5.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3481         1.0         2         1
# ...

# %%
stroke = 0
for x in MSB1_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB1_E1 = ((stroke / len(MSB1_E1) * 100))

stroke_MSB1_E1
# Out:
# 1.0341431385423505

# %%
HA = 0
for x in MSB1_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB1_E1 = ((HA / len(MSB1_E1) * 100))

HA_MSB1_E1
# Out:
# 0.7386736703873933

# %%
HBP = 0
for x in MSB1_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB1_E1 = ((HBP / len(MSB1_E1) * 100))
HBP_MSB1_E1
# Out:
# 10.35784635587656

# %%
#MSB1_E2
MSB1_E2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['EXERANY2'] == 2)]
MSB1_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3501       2.0        2      1.0         4         2         2      1.0
# 3531       2.0        5      5.0         2         2         2      3.0
# 3549       2.0        6      3.0         3         2         2      3.0
# 3629       2.0        4      2.0         4         2         2      2.0
# 3736       2.0        4      4.0         2         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441389     2.0        5      3.0         1         2         2      3.0
# 441394     2.0        5      1.0         2         2         2      3.0
# 441397     2.0        5      1.0         2         2         2      3.0
# 441402     2.0        2      5.0         4         2         2      3.0
# 441449     2.0        6      5.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3501         2.0         2         2
# ...

# %%
stroke = 0
for x in MSB1_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB1_E2 = ((stroke / len(MSB1_E2) * 100))

stroke_MSB1_E2
# Out:
# 1.4726184997699034

# %%
HA = 0
for x in MSB1_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB1_E2 = ((HA / len(MSB1_E2) * 100))

HA_MSB1_E2
# Out:
# 1.1965025310630464

# %%
HBP = 0
for x in MSB1_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB1_E2 = ((HBP / len(MSB1_E2) * 100))
HBP_MSB1_E2
# Out:
# 13.989875747814082

# %%
#MSB1_D1
MSB1_D1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 1)]
MSB1_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3531       2.0        5      5.0         2         2         2      3.0
# 3546       2.0        5      4.0         2         2         2      3.0
# 3564       2.0        6      4.0         1         2         2      1.0
# 3581       2.0        5      3.0         3         2         2      3.0
# 3599       2.0        5      3.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441353     2.0        2      3.0         3         2         2      3.0
# 441394     2.0        5      1.0         2         2         2      3.0
# 441397     2.0        5      1.0         2         2         2      3.0
# 441402     2.0        2      5.0         4         2         2      3.0
# 441418     2.0        2      5.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3531         2.0         1         1
# ...

# %%
stroke = 0
for x in MSB1_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB1_D1 = ((stroke / len(MSB1_D1) * 100))

stroke_MSB1_D1
# Out:
# 0.9236314485244426

# %%
HA = 0
for x in MSB1_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB1_D1 = ((HA / len(MSB1_D1) * 100))

HA_MSB1_D1
# Out:
# 0.7884658706915972

# %%
HBP = 0
for x in MSB1_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB1_D1 = ((HBP / len(MSB1_D1) * 100))
HBP_MSB1_D1
# Out:
# 10.678080648794772

# %%
#MSB1_D2
MSB1_D2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['DRNKANY5'] == 2)]
MSB1_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3481       2.0        4      3.0         3         2         2      1.0
# 3501       2.0        2      1.0         4         2         2      1.0
# 3514       2.0        5      3.0         1         2         2      3.0
# 3529       2.0        5      4.0         4         2         2      3.0
# 3541       2.0        5      3.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441389     2.0        5      3.0         1         2         2      3.0
# 441390     2.0        4      2.0         1         2         2      3.0
# 441403     2.0        5      1.0         1         2         2      3.0
# 441415     2.0        5      4.0         2         2         2      3.0
# 441449     2.0        6      5.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3481         1.0         2         1
# ...

# %%
stroke = 0
for x in MSB1_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB1_D2 = ((stroke / len(MSB1_D2) * 100))

stroke_MSB1_D2
# Out:
# 1.418918918918919

# %%
HA = 0
for x in MSB1_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB1_D2 = ((HA / len(MSB1_D2) * 100))

HA_MSB1_D2
# Out:
# 0.990990990990991

# %%
HBP = 0
for x in MSB1_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB1_D2 = ((HBP / len(MSB1_D2) * 100))
HBP_MSB1_D2
# Out:
# 11.621621621621623

# %%
#MSB1_S1
MSB1_S1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 1)]
MSB1_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3481       2.0        4      3.0         3         2         2      1.0
# 3514       2.0        5      3.0         1         2         2      3.0
# 3529       2.0        5      4.0         4         2         2      3.0
# 3531       2.0        5      5.0         2         2         2      3.0
# 3541       2.0        5      3.0         1         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441402     2.0        2      5.0         4         2         2      3.0
# 441403     2.0        5      1.0         1         2         2      3.0
# 441415     2.0        5      4.0         2         2         2      3.0
# 441418     2.0        2      5.0         3         2         2      3.0
# 441449     2.0        6      5.0         3         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3481         1.0         2         1
# ...

# %%
stroke = 0
for x in MSB1_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB1_S1 = ((stroke / len(MSB1_S1) * 100))

stroke_MSB1_S1
# Out:
# 0.8360704687966557

# %%
HA = 0
for x in MSB1_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB1_S1 = ((HA / len(MSB1_S1) * 100))

HA_MSB1_S1
# Out:
# 0.5374738727978501

# %%
HBP = 0
for x in MSB1_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB1_S1 = ((HBP / len(MSB1_S1) * 100))
HBP_MSB1_S1
# Out:
# 9.510301582561958

# %%
#MSB1_S2
MSB1_S2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 1) | (rdf['_AGEG5YR'] == 2) | (rdf['_AGEG5YR'] == 3) | (rdf['_AGEG5YR'] == 4))&
           (rdf['_RFSMOK3'] == 2)]
MSB1_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3501       2.0        2      1.0         4         2         2      1.0
# 3549       2.0        6      3.0         3         2         2      3.0
# 3564       2.0        6      4.0         1         2         2      1.0
# 3736       2.0        4      4.0         2         2         2      3.0
# 3764       2.0        5      1.0         3         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441023     2.0        5      1.0         3         2         2      3.0
# 441026     2.0        5      1.0         2         2         2      1.0
# 441348     2.0        6      3.0         3         2         2      3.0
# 441353     2.0        2      3.0         3         2         2      3.0
# 441376     2.0        6      1.0         2         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3501         2.0         2         2
# ...

# %%
stroke = 0
for x in MSB1_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB1_S2 = ((stroke / len(MSB1_S2) * 100))

stroke_MSB1_S2
# Out:
# 2.10989010989011

# %%
HA = 0
for x in MSB1_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB1_S2 = ((HA / len(MSB1_S2) * 100))

HA_MSB1_S2
# Out:
# 1.8461538461538463

# %%
HBP = 0
for x in MSB1_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB1_S2 = ((HBP / len(MSB1_S2) * 100))
HBP_MSB1_S2
# Out:
# 16.21978021978022

# %%
#female, single, above 35000, 39-59
FSA2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))]
FSA2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3537       2.0        2      6.0         5         2         2      4.0
# 3588       2.0        3      6.0         8         2         2      3.0
# 3686       2.0        2      6.0         8         2         2      3.0
# 3704       2.0        4      6.0         6         2         2      1.0
# 3729       2.0        4      7.0         8         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440892     2.0        5      7.0         7         2         2      1.0
# 440920     2.0        6      8.0         6         2         2      1.0
# 440951     2.0        5      6.0         6         2         2      3.0
# 441076     2.0        2      6.0         5         2         2      1.0
# 441363     2.0        3      6.0         6         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3537         2.0         1         1
# ...

# %%
#Stroke Chance FSA2
stroke = 0
for x in FSA2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA2 = ((stroke / len(FSA2) * 100))

stroke_FSA2
# Out:
# 1.4245629181955537

# %%
#Heart Attack Chance FSA2
HA = 0
for x in FSA2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA2 = ((HA / len(FSA2) * 100))

HA_FSA2
# Out:
# 1.100798618605655

# %%
#High Blood pressure FSA2
HBP = 0
for x in FSA2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA2 = ((HBP / len(FSA2) * 100))

HBP_FSA2
# Out:
# 26.527088279732354

# %%
#FSA2_E1
FSA2_E1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 1)]
FSA2_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3704       2.0        4      6.0         6         2         2      1.0
# 3729       2.0        4      7.0         8         2         2      3.0
# 3734       2.0        2      7.0         8         2         2      3.0
# 3893       2.0        2      6.0         7         2         2      3.0
# 3964       2.0        5      7.0         6         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439800     2.0        2      8.0         7         2         2      3.0
# 440438     2.0        6      7.0         6         2         2      1.0
# 440566     2.0        4      6.0         5         2         2      3.0
# 440951     2.0        5      6.0         6         2         2      3.0
# 441363     2.0        3      6.0         6         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3704         1.0         2         1
# ...

# %%
#Stroke Chance FSA2_E1
stroke = 0
for x in FSA2_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA2_E1 = ((stroke / len(FSA2_E1) * 100))

stroke_FSA2_E1
# Out:
# 1.142689715792558

# %%
#Heart Attack Chance FSA2_E1
HA = 0
for x in FSA2_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA2_E1 = ((HA / len(FSA2_E1) * 100))

HA_FSA2_E1
# Out:
# 0.9668912979783182

# %%
#High Blood pressure FSA2_E1
HBP = 0
for x in FSA2_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA2_E1 = ((HBP / len(FSA2_E1) * 100))

HBP_FSA2_E1
# Out:
# 23.7913858775271

# %%
#FSA2_E2
FSA2_E2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 2)]
FSA2_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3537       2.0        2      6.0         5         2         2      4.0
# 3588       2.0        3      6.0         8         2         2      3.0
# 3686       2.0        2      6.0         8         2         2      3.0
# 3794       2.0        2      7.0         8         2         2      1.0
# 3809       2.0        3      6.0         6         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440227     2.0        2      8.0         7         2         2      3.0
# 440516     2.0        6      7.0         5         2         2      1.0
# 440892     2.0        5      7.0         7         2         2      1.0
# 440920     2.0        6      8.0         6         2         2      1.0
# 441076     2.0        2      6.0         5         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3537         2.0         1         1
# ...

# %%
#Stroke Chance FSA2_E2
stroke = 0
for x in FSA2_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA2_E2 = ((stroke / len(FSA2_E2) * 100))

stroke_FSA2_E2
# Out:
# 2.083333333333333

# %%
#Heart Attack Chance FSA2_E2
HA = 0
for x in FSA2_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA2_E2 = ((HA / len(FSA2_E2) * 100))

HA_FSA2_E2
# Out:
# 1.644736842105263

# %%
#High Blood pressure FSA2_E2
HBP = 0
for x in FSA2_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA2_E2 = ((HBP / len(FSA2_E2) * 100))

HBP_FSA2_E2
# Out:
# 36.29385964912281

# %%
#FSA2_D1
FSA2_D1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 1)]
FSA2_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3537       2.0        2      6.0         5         2         2      4.0
# 3809       2.0        3      6.0         6         2         2      1.0
# 3964       2.0        5      7.0         6         2         2      3.0
# 3974       2.0        5      6.0         8         2         2      1.0
# 4093       2.0        2      8.0         7         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440089     2.0        2      8.0         5         2         2      3.0
# 440227     2.0        2      8.0         7         2         2      3.0
# 440516     2.0        6      7.0         5         2         2      1.0
# 441076     2.0        2      6.0         5         2         2      1.0
# 441363     2.0        3      6.0         6         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3537         2.0         1         1
# ...

# %%
#Stroke Chance FSA2_D1
stroke = 0
for x in FSA2_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA2_D1 = ((stroke / len(FSA2_D1) * 100))

stroke_FSA2_D1
# Out:
# 1.1169284467713787

# %%
#Heart Attack Chance FSA2_D1
HA = 0
for x in FSA2_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA2_D1 = ((HA / len(FSA2_D1) * 100))

HA_FSA2_D1
# Out:
# 0.9773123909249565

# %%
#High Blood pressure FSA2_D1
HBP = 0
for x in FSA2_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA2_D1 = ((HBP / len(FSA2_D1) * 100))

HBP_FSA2_D1
# Out:
# 25.165794066317627

# %%
#FSA2_D2
FSA2_D2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 2)]
FSA2_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3588       2.0        3      6.0         8         2         2      3.0
# 3686       2.0        2      6.0         8         2         2      3.0
# 3704       2.0        4      6.0         6         2         2      1.0
# 3729       2.0        4      7.0         8         2         2      3.0
# 3734       2.0        2      7.0         8         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440438     2.0        6      7.0         6         2         2      1.0
# 440566     2.0        4      6.0         5         2         2      3.0
# 440892     2.0        5      7.0         7         2         2      1.0
# 440920     2.0        6      8.0         6         2         2      1.0
# 440951     2.0        5      6.0         6         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3588         2.0         2         1
# ...

# %%
#Stroke Chance FSA2_D2
stroke = 0
for x in FSA2_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA2_D2 = ((stroke / len(FSA2_D2) * 100))

stroke_FSA2_D2
# Out:
# 1.9704433497536946

# %%
#Heart Attack Chance FSA2_D2
HA = 0
for x in FSA2_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA2_D2 = ((HA / len(FSA2_D2) * 100))

HA_FSA2_D2
# Out:
# 1.416256157635468

# %%
#High Blood pressure FSA2_D2
HBP = 0
for x in FSA2_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA2_D2 = ((HBP / len(FSA2_D2) * 100))

HBP_FSA2_D2
# Out:
# 29.064039408866993

# %%
#FSA2_S1
FSA2_S1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 1)]
FSA2_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3537       2.0        2      6.0         5         2         2      4.0
# 3588       2.0        3      6.0         8         2         2      3.0
# 3686       2.0        2      6.0         8         2         2      3.0
# 3704       2.0        4      6.0         6         2         2      1.0
# 3729       2.0        4      7.0         8         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440566     2.0        4      6.0         5         2         2      3.0
# 440920     2.0        6      8.0         6         2         2      1.0
# 440951     2.0        5      6.0         6         2         2      3.0
# 441076     2.0        2      6.0         5         2         2      1.0
# 441363     2.0        3      6.0         6         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3537         2.0         1         1
# ...

# %%
#Stroke Chance FSA2_S1
stroke = 0
for x in FSA2_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA2_S1 = ((stroke / len(FSA2_S1) * 100))

stroke_FSA2_S1
# Out:
# 1.2776151184455682

# %%
#Heart Attack Chance FSA2_S1
HA = 0
for x in FSA2_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA2_S1 = ((HA / len(FSA2_S1) * 100))

HA_FSA2_S1
# Out:
# C:\Users\zacha\anaconda3\lib\site-packages\IPython\core\displayhook.py:275: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
# 0.8517434122970455

# %%
#High Blood pressure FSA2_S1
HBP = 0
for x in FSA2_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA2_S1 = ((HBP / len(FSA2_S1) * 100))

HBP_FSA2_S1
# Out:
# 26.244343891402718

# %%
#FSA2_S2
FSA2_S2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 2)]
FSA2_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 4073       2.0        2      6.0         8         2         2      3.0
# 4880       2.0        2      6.0         5         2         2      1.0
# 4894       2.0        5      6.0         8         2         2      1.0
# 5193       2.0        5      6.0         6         2         2      3.0
# 5323       2.0        2      7.0         6         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439413     2.0        3      6.0         7         2         2      1.0
# 439451     2.0        2      8.0         5         2         2      3.0
# 439698     2.0        2      6.0         6         2         2      3.0
# 440227     2.0        2      8.0         7         2         2      3.0
# 440892     2.0        5      7.0         7         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 4073         1.0         2         2
# ...

# %%
#Stroke Chance FSA2_S2
stroke = 0
for x in FSA2_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA2_S2 = ((stroke / len(FSA2_S2) * 100))

stroke_FSA2_S2
# Out:
# 2.204928664072633

# %%
#Heart Attack Chance FSA2_S2
HA = 0
for x in FSA2_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA2_S2 = ((HA / len(FSA2_S2) * 100))

HA_FSA2_S2
# Out:
# 2.4643320363164722

# %%
#High Blood pressure FSA2_S2
HBP = 0
for x in FSA2_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA2_S2 = ((HBP / len(FSA2_S2) * 100))

HBP_FSA2_S2
# Out:
# 28.404669260700388

# %%
#male, single, above 35000, 39-59
MSA2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))]
MSA2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3461       1.0        2      7.0         6         2         2      3.0
# 3620       1.0        2      8.0         5         2         2      1.0
# 3675       1.0        6      7.0         6         2         2      1.0
# 3725       1.0        2      8.0         6         2         2      3.0
# 3784       1.0        2      7.0         6         2         1      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441019     1.0        2      7.0         7         2         2      1.0
# 441197     1.0        2      7.0         7         2         2      1.0
# 441214     1.0        6      6.0         5         2         2      1.0
# 441232     1.0        3      8.0         8         2         2      3.0
# 441328     1.0        6      6.0         7         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3461         1.0         1         1
# ...

# %%
stroke = 0
for x in MSA2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA2 = ((stroke / len(MSA2) * 100))

stroke_MSA2
# Out:
# 1.4060092449922958

# %%
HA = 0
for x in MSA2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA2 = ((HA / len(MSA2) * 100))

HA_MSA2
# Out:
# 3.1201848998459165

# %%
HBP = 0
for x in MSA2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA2 = ((HBP / len(MSA2) * 100))
HBP_MSA2
# Out:
# 35.07318952234206

# %%
#MSA2_E1
MSA2_E1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 1)]
MSA2_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3461       1.0        2      7.0         6         2         2      3.0
# 3620       1.0        2      8.0         5         2         2      1.0
# 3725       1.0        2      8.0         6         2         2      3.0
# 3784       1.0        2      7.0         6         2         1      1.0
# 3990       1.0        2      8.0         7         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440930     1.0        2      7.0         5         1         2      3.0
# 441197     1.0        2      7.0         7         2         2      1.0
# 441214     1.0        6      6.0         5         2         2      1.0
# 441232     1.0        3      8.0         8         2         2      3.0
# 441328     1.0        6      6.0         7         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3461         1.0         1         1
# ...

# %%
stroke = 0
for x in MSA2_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA2_E1 = ((stroke / len(MSA2_E1) * 100))

stroke_MSA2_E1
# Out:
# 1.3568521031207599

# %%
HA = 0
for x in MSA2_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA2_E1 = ((HA / len(MSA2_E1) * 100))

HA_MSA2_E1
# Out:
# 2.7679782903663503

# %%
HBP = 0
for x in MSA2_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA2_E1 = ((HBP / len(MSA2_E1) * 100))
HBP_MSA2_E1
# Out:
# 32.72727272727273

# %%
#MSA2_E2
MSA2_E2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 2)]
MSA2_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3675       1.0        6      7.0         6         2         2      1.0
# 4103       1.0        2      6.0         8         2         2      1.0
# 4158       1.0        2      6.0         7         2         2      1.0
# 4255       1.0        2      6.0         8         2         2      1.0
# 4343       1.0        2      7.0         7         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439038     1.0        2      8.0         7         2         2      3.0
# 439358     1.0        6      8.0         7         2         2      1.0
# 439857     1.0        6      6.0         8         2         2      1.0
# 440173     1.0        6      6.0         7         2         2      3.0
# 440734     1.0        5      8.0         5         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3675         2.0         2         2
# ...

# %%
stroke = 0
for x in MSA2_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA2_E2 = ((stroke / len(MSA2_E2) * 100))

stroke_MSA2_E2
# Out:
# 1.3262599469496021

# %%
HA = 0
for x in MSA2_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA2_E2 = ((HA / len(MSA2_E2) * 100))

HA_MSA2_E2
# Out:
# 3.978779840848806

# %%
HBP = 0
for x in MSA2_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA2_E2 = ((HBP / len(MSA2_E2) * 100))
HBP_MSA2_E2
# Out:
# 41.644562334217504

# %%
#MSA2_D1
MSA2_D1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 1)]
MSA2_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3461       1.0        2      7.0         6         2         2      3.0
# 3620       1.0        2      8.0         5         2         2      1.0
# 4061       1.0        2      6.0         6         2         2      3.0
# 4092       1.0        5      7.0         7         2         2      3.0
# 4128       1.0        2      6.0         6         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440734     1.0        5      8.0         5         2         2      3.0
# 440930     1.0        2      7.0         5         1         2      3.0
# 441214     1.0        6      6.0         5         2         2      1.0
# 441232     1.0        3      8.0         8         2         2      3.0
# 441328     1.0        6      6.0         7         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3461         1.0         1         1
# ...

# %%
stroke = 0
for x in MSA2_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA2_D1 = ((stroke / len(MSA2_D1) * 100))

stroke_MSA2_D1
# Out:
# 1.0256410256410255

# %%
HA = 0
for x in MSA2_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA2_D1 = ((HA / len(MSA2_D1) * 100))

HA_MSA2_D1
# Out:
# 2.564102564102564

# %%
HBP = 0
for x in MSA2_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA2_D1 = ((HBP / len(MSA2_D1) * 100))
HBP_MSA2_D1
# Out:
# 34.87179487179487

# %%
#MSA2_D2
MSA2_D2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 2)]
MSA2_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3675       1.0        6      7.0         6         2         2      1.0
# 3725       1.0        2      8.0         6         2         2      3.0
# 3784       1.0        2      7.0         6         2         1      1.0
# 3990       1.0        2      8.0         7         2         2      1.0
# 4103       1.0        2      6.0         8         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440173     1.0        6      6.0         7         2         2      3.0
# 440216     1.0        5      6.0         5         2         2      1.0
# 440446     1.0        5      6.0         8         2         2      1.0
# 440668     1.0        2      6.0         5         2         2      3.0
# 441197     1.0        2      7.0         7         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3675         2.0         2         2
# ...

# %%
stroke = 0
for x in MSA2_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA2_D2 = ((stroke / len(MSA2_D2) * 100))

stroke_MSA2_D2
# Out:
# 2.18978102189781

# %%
HA = 0
for x in MSA2_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA2_D2 = ((HA / len(MSA2_D2) * 100))

HA_MSA2_D2
# Out:
# 4.57863304578633

# %%
HBP = 0
for x in MSA2_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA2_D2 = ((HBP / len(MSA2_D2) * 100))
HBP_MSA2_D2
# Out:
# 34.505640345056406

# %%
#MSA2_S1
MSA2_S1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 1)]
MSA2_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3461       1.0        2      7.0         6         2         2      3.0
# 3620       1.0        2      8.0         5         2         2      1.0
# 3725       1.0        2      8.0         6         2         2      3.0
# 3784       1.0        2      7.0         6         2         1      1.0
# 3990       1.0        2      8.0         7         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440930     1.0        2      7.0         5         1         2      3.0
# 441197     1.0        2      7.0         7         2         2      1.0
# 441214     1.0        6      6.0         5         2         2      1.0
# 441232     1.0        3      8.0         8         2         2      3.0
# 441328     1.0        6      6.0         7         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3461         1.0         1         1
# ...

# %%
stroke = 0
for x in MSA2_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA2_S1 = ((stroke / len(MSA2_S1) * 100))

stroke_MSA2_S1
# Out:
# 1.1547344110854503

# %%
HA = 0
for x in MSA2_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA2_S1 = ((HA / len(MSA2_S1) * 100))

HA_MSA2_S1
# Out:
# 2.5660764690787787

# %%
HBP = 0
for x in MSA2_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA2_S1 = ((HBP / len(MSA2_S1) * 100))
HBP_MSA2_S1
# Out:
# 34.64203233256351

# %%
#MSA2_S2
MSA2_S2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 2)]
MSA2_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3675       1.0        6      7.0         6         2         2      1.0
# 4128       1.0        2      6.0         6         2         2      1.0
# 4160       1.0        6      8.0         5         2         2      3.0
# 4260       1.0        4      7.0         7         2         2      1.0
# 4356       1.0        2      7.0         7         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 434191     1.0        2      8.0         8         2         2      1.0
# 435819     1.0        2      7.0         8         2         1      1.0
# 435903     1.0        5      6.0         7         2         2      3.0
# 436001     1.0        2      6.0         8         2         2      3.0
# 438875     1.0        2      7.0         7         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3675         2.0         2         2
# ...

# %%
stroke = 0
for x in MSA2_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA2_S2 = ((stroke / len(MSA2_S2) * 100))

stroke_MSA2_S2
# Out:
# 2.1367521367521367

# %%
HA = 0
for x in MSA2_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA2_S2 = ((HA / len(MSA2_S2) * 100))

HA_MSA2_S2
# Out:
# 5.042735042735043

# %%
HBP = 0
for x in MSA2_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA2_S2 = ((HBP / len(MSA2_S2) * 100))
HBP_MSA2_S2
# Out:
# 35.38461538461539

# %%
#female, married, above 3500, 39-59
FMA2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))]
FMA2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3458       2.0        1      8.0         8         2         2      3.0
# 3468       2.0        1      8.0         7         2         2      3.0
# 3471       2.0        1      8.0         6         2         2      3.0
# 3474       2.0        1      7.0         5         2         2      1.0
# 3497       2.0        1      7.0         5         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441294     2.0        1      7.0         7         2         2      3.0
# 441302     2.0        1      8.0         5         2         2      3.0
# 441316     2.0        1      6.0         8         2         2      1.0
# 441351     2.0        1      6.0         7         2         2      3.0
# 441384     2.0        1      7.0         5         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3458         2.0         2         1
# ...

# %%
#Stroke Chance FMA2
stroke = 0
for x in FMA2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA2 = ((stroke / len(FMA2) * 100))

stroke_FMA2
# Out:
# 1.3430176784980128

# %%
#Heart Attack Chance FMA2
HA = 0
for x in FMA2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA2 = ((HA / len(FMA2) * 100))

HA_FMA2
# Out:
# 1.1717144031793887

# %%
#High Blood pressure FMA2
HBP = 0
for x in FMA2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA2 = ((HBP / len(FMA2) * 100))

HBP_FMA2
# Out:
# 22.77648348636426

# %%
#FMA2_E1
FMA2_E1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 1)]
FMA2_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3468       2.0        1      8.0         7         2         2      3.0
# 3474       2.0        1      7.0         5         2         2      1.0
# 3497       2.0        1      7.0         5         2         2      3.0
# 3533       2.0        1      7.0         8         2         2      1.0
# 3539       2.0        1      8.0         5         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441208     2.0        1      8.0         7         2         2      3.0
# 441302     2.0        1      8.0         5         2         2      3.0
# 441316     2.0        1      6.0         8         2         2      1.0
# 441351     2.0        1      6.0         7         2         2      3.0
# 441384     2.0        1      7.0         5         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3468         1.0         2         1
# ...

# %%
#Stroke Chance FMA2_E1
stroke = 0
for x in FMA2_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA2_E1 = ((stroke / len(FMA2_E1) * 100))

stroke_FMA2_E1
# Out:
# 1.077489449582473

# %%
#Heart Attack Chance FMA2_E1
HA = 0
for x in FMA2_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA2_E1 = ((HA / len(FMA2_E1) * 100))

HA_FMA2_E1
# Out:
# 0.915866032145102

# %%
#High Blood pressure FMA2_E1
HBP = 0
for x in FMA2_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA2_E1 = ((HBP / len(FMA2_E1) * 100))

HBP_FMA2_E1
# Out:
# 20.606985723264792

# %%
#FMA2_E2
FMA2_E2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 2)]
FMA2_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3458       2.0        1      8.0         8         2         2      3.0
# 3499       2.0        1      8.0         6         2         2      1.0
# 3522       2.0        1      8.0         7         2         2      3.0
# 3672       2.0        1      8.0         6         2         2      1.0
# 3727       2.0        1      8.0         8         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440432     2.0        1      8.0         6         2         2      3.0
# 440612     2.0        1      7.0         6         2         2      1.0
# 440884     2.0        1      6.0         6         2         2      3.0
# 440902     2.0        1      7.0         6         2         2      3.0
# 441294     2.0        1      7.0         7         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3458         2.0         2         1
# ...

# %%
#Stroke Chance FMA2_E2
stroke = 0
for x in FMA2_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA2_E2 = ((stroke / len(FMA2_E2) * 100))

stroke_FMA2_E2
# Out:
# 2.5048923679060664

# %%
#Heart Attack Chance FMA2_E2
HA = 0
for x in FMA2_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA2_E2 = ((HA / len(FMA2_E2) * 100))

HA_FMA2_E2
# Out:
# 1.9960861056751469

# %%
#High Blood pressure FMA2_E2
HBP = 0
for x in FMA2_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA2_E2 = ((HBP / len(FMA2_E2) * 100))

HBP_FMA2_E2
# Out:
# 32.68101761252446

# %%
#FMA2_D1
FMA2_D1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 1)]
FMA2_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3497       2.0        1      7.0         5         2         2      3.0
# 3499       2.0        1      8.0         6         2         2      1.0
# 3533       2.0        1      7.0         8         2         2      1.0
# 3602       2.0        1      6.0         7         2         2      3.0
# 3693       2.0        1      7.0         8         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441144     2.0        1      6.0         8         2         2      3.0
# 441294     2.0        1      7.0         7         2         2      3.0
# 441302     2.0        1      8.0         5         2         2      3.0
# 441316     2.0        1      6.0         8         2         2      1.0
# 441351     2.0        1      6.0         7         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3497         1.0         1         1
# ...

# %%
#Stroke Chance FMA2_D1
stroke = 0
for x in FMA2_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA2_D1 = ((stroke / len(FMA2_D1) * 100))

stroke_FMA2_D1
# Out:
# 0.9432877027493385

# %%
#Heart Attack Chance FMA2_D1
HA = 0
for x in FMA2_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA2_D1 = ((HA / len(FMA2_D1) * 100))

HA_FMA2_D1
# Out:
# 0.805245599907972

# %%
#High Blood pressure FMA2_D1
HBP = 0
for x in FMA2_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA2_D1 = ((HBP / len(FMA2_D1) * 100))

HBP_FMA2_D1
# Out:
# 20.33820315196135

# %%
#FMA2_D2
FMA2_D2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 2)]
FMA2_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3458       2.0        1      8.0         8         2         2      3.0
# 3468       2.0        1      8.0         7         2         2      3.0
# 3471       2.0        1      8.0         6         2         2      3.0
# 3474       2.0        1      7.0         5         2         2      1.0
# 3522       2.0        1      8.0         7         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440884     2.0        1      6.0         6         2         2      3.0
# 440902     2.0        1      7.0         6         2         2      3.0
# 441159     2.0        1      8.0         7         2         2      3.0
# 441208     2.0        1      8.0         7         2         2      3.0
# 441384     2.0        1      7.0         5         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3458         2.0         2         1
# ...

# %%
#Stroke Chance FMA2_D2
stroke = 0
for x in FMA2_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA2_D2 = ((stroke / len(FMA2_D2) * 100))

stroke_FMA2_D2
# Out:
# 1.9941456275155507

# %%
#Heart Attack Chance FMA2_D2
HA = 0
for x in FMA2_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA2_D2 = ((HA / len(FMA2_D2) * 100))

HA_FMA2_D2
# Out:
# 1.7380168313208928

# %%
#High Blood pressure FMA2_D2
HBP = 0
for x in FMA2_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA2_D2 = ((HBP / len(FMA2_D2) * 100))

HBP_FMA2_D2
# Out:
# 26.94840834248079

# %%
#FMA2_S1
FMA2_S1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 1)]
FMA2_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3458       2.0        1      8.0         8         2         2      3.0
# 3468       2.0        1      8.0         7         2         2      3.0
# 3471       2.0        1      8.0         6         2         2      3.0
# 3474       2.0        1      7.0         5         2         2      1.0
# 3497       2.0        1      7.0         5         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441294     2.0        1      7.0         7         2         2      3.0
# 441302     2.0        1      8.0         5         2         2      3.0
# 441316     2.0        1      6.0         8         2         2      1.0
# 441351     2.0        1      6.0         7         2         2      3.0
# 441384     2.0        1      7.0         5         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3458         2.0         2         1
# ...

# %%
#Stroke Chance FMA2_S1
stroke = 0
for x in FMA2_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA2_S1 = ((stroke / len(FMA2_S1) * 100))

stroke_FMA2_S1
# Out:
# 1.2724844866860419

# %%
#Heart Attack Chance FMA2_S1
HA = 0
for x in FMA2_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA2_S1 = ((HA / len(FMA2_S1) * 100))

HA_FMA2_S1
# Out:
# 0.94258110124892

# %%
#High Blood pressure FMA2_S1
HBP = 0
for x in FMA2_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA2_S1 = ((HBP / len(FMA2_S1) * 100))

HBP_FMA2_S1
# Out:
# 22.268478517005736

# %%
#FMA2_S2
FMA2_S2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 2)]
FMA2_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3539       2.0        1      8.0         5         2         2      3.0
# 3722       2.0        1      6.0         6         2         2      3.0
# 3815       2.0        1      7.0         6         2         2      3.0
# 3864       2.0        1      7.0         7         1         2      3.0
# 3880       2.0        1      7.0         7         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 435869     2.0        1      7.0         7         2         2      1.0
# 435893     2.0        1      8.0         6         2         2      3.0
# 435911     2.0        1      8.0         6         2         2      1.0
# 435913     2.0        1      7.0         7         2         2      3.0
# 438827     2.0        1      8.0         5         1         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3539         1.0         2         2
# ...

# %%
#Stroke Chance FMA2_S2
stroke = 0
for x in FMA2_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA2_S2 = ((stroke / len(FMA2_S2) * 100))

stroke_FMA2_S2
# Out:
# 2.2073578595317724

# %%
#Heart Attack Chance FMA2_S2
HA = 0
for x in FMA2_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA2_S2 = ((HA / len(FMA2_S2) * 100))

HA_FMA2_S2
# Out:
# 3.0100334448160537

# %%
#High Blood pressure FMA2_S2
HBP = 0
for x in FMA2_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA2_S2 = ((HBP / len(FMA2_S2) * 100))

HBP_FMA2_S2
# Out:
# 28.02675585284281

# %%
#male, married, above 3500, 39-59
MMA2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))]
MMA2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3456       1.0        1      8.0         6         2         2      1.0
# 3488       1.0        1      6.0         7         2         2      7.0
# 3495       1.0        1      8.0         8         1         2      1.0
# 3502       1.0        1      7.0         6         2         2      1.0
# 3520       1.0        1      8.0         7         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441282     1.0        1      8.0         7         2         2      1.0
# 441317     1.0        1      6.0         8         2         2      3.0
# 441412     1.0        1      6.0         7         2         2      3.0
# 441424     1.0        1      6.0         6         2         2      1.0
# 441450     1.0        1      7.0         5         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3456         1.0         2         2
# ...

# %%
stroke = 0
for x in MMA2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA2 = ((stroke / len(MMA2) * 100))

stroke_MMA2
# Out:
# 1.0241596638655461

# %%
HA = 0
for x in MMA2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA2 = ((HA / len(MMA2) * 100))

HA_MMA2
# Out:
# 2.6851365546218484

# %%
HBP = 0
for x in MMA2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA2 = ((HBP / len(MMA2) * 100))
HBP_MMA2
# Out:
# 33.528098739495796

# %%
#MMA2_E1
MMA2_E1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 1)]
MMA2_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3456       1.0        1      8.0         6         2         2      1.0
# 3523       1.0        1      8.0         6         2         2      1.0
# 3536       1.0        1      6.0         7         2         2      3.0
# 3575       1.0        1      7.0         7         2         2      1.0
# 3591       1.0        1      8.0         8         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441055     1.0        1      6.0         5         2         2      3.0
# 441086     1.0        1      6.0         5         2         2      1.0
# 441264     1.0        1      7.0         6         2         2      3.0
# 441282     1.0        1      8.0         7         2         2      1.0
# 441424     1.0        1      6.0         6         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3456         1.0         2         2
# ...

# %%
stroke = 0
for x in MMA2_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA2_E1 = ((stroke / len(MMA2_E1) * 100))

stroke_MMA2_E1
# Out:
# 0.8613034984904989

# %%
HA = 0
for x in MMA2_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA2_E1 = ((HA / len(MMA2_E1) * 100))

HA_MMA2_E1
# Out:
# 2.5927899129817087

# %%
HBP = 0
for x in MMA2_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA2_E1 = ((HBP / len(MMA2_E1) * 100))
HBP_MMA2_E1
# Out:
# 32.205647309536495

# %%
#MMA2_E2
MMA2_E2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 2)]
MMA2_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3488       1.0        1      6.0         7         2         2      7.0
# 3502       1.0        1      7.0         6         2         2      1.0
# 3520       1.0        1      8.0         7         2         2      1.0
# 3524       1.0        1      8.0         7         2         2      1.0
# 3544       1.0        1      7.0         7         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441225     1.0        1      7.0         8         2         2      3.0
# 441250     1.0        1      7.0         5         2         2      1.0
# 441317     1.0        1      6.0         8         2         2      3.0
# 441412     1.0        1      6.0         7         2         2      3.0
# 441450     1.0        1      7.0         5         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3488         2.0         2         1
# ...

# %%
stroke = 0
for x in MMA2_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA2_E2 = ((stroke / len(MMA2_E2) * 100))

stroke_MMA2_E2
# Out:
# 1.7293997965412005

# %%
HA = 0
for x in MMA2_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA2_E2 = ((HA / len(MMA2_E2) * 100))

HA_MMA2_E2
# Out:
# 2.9162427941675144

# %%
HBP = 0
for x in MMA2_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA2_E2 = ((HBP / len(MMA2_E2) * 100))
HBP_MMA2_E2
# Out:
# 38.72499152255002

# %%
#MMA2_D1
MMA2_D1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 1)]
MMA2_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3502       1.0        1      7.0         6         2         2      1.0
# 3524       1.0        1      8.0         7         2         2      1.0
# 3536       1.0        1      6.0         7         2         2      3.0
# 3567       1.0        1      8.0         8         2         2      3.0
# 3591       1.0        1      8.0         8         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441250     1.0        1      7.0         5         2         2      1.0
# 441264     1.0        1      7.0         6         2         2      3.0
# 441282     1.0        1      8.0         7         2         2      1.0
# 441412     1.0        1      6.0         7         2         2      3.0
# 441450     1.0        1      7.0         5         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3502         2.0         1         2
# ...

# %%
stroke = 0
for x in MMA2_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA2_D1 = ((stroke / len(MMA2_D1) * 100))

stroke_MMA2_D1
# Out:
# 0.8048289738430584

# %%
HA = 0
for x in MMA2_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA2_D1 = ((HA / len(MMA2_D1) * 100))

HA_MMA2_D1
# Out:
# 2.3138832997987926

# %%
HBP = 0
for x in MMA2_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA2_D1 = ((HBP / len(MMA2_D1) * 100))
HBP_MMA2_D1
# Out:
# 32.95774647887324

# %%
#MMA2_D2
MMA2_D2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 2)]
MMA2_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3456       1.0        1      8.0         6         2         2      1.0
# 3488       1.0        1      6.0         7         2         2      7.0
# 3520       1.0        1      8.0         7         2         2      1.0
# 3523       1.0        1      8.0         6         2         2      1.0
# 3544       1.0        1      7.0         7         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441015     1.0        1      7.0         5         2         2      1.0
# 441055     1.0        1      6.0         5         2         2      3.0
# 441225     1.0        1      7.0         8         2         2      3.0
# 441317     1.0        1      6.0         8         2         2      3.0
# 441424     1.0        1      6.0         6         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3456         1.0         2         2
# ...

# %%
stroke = 0
for x in MMA2_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA2_D2 = ((stroke / len(MMA2_D2) * 100))

stroke_MMA2_D2
# Out:
# 1.486988847583643

# %%
HA = 0
for x in MMA2_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA2_D2 = ((HA / len(MMA2_D2) * 100))

HA_MMA2_D2
# Out:
# 3.469640644361834

# %%
HBP = 0
for x in MMA2_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA2_D2 = ((HBP / len(MMA2_D2) * 100))
HBP_MMA2_D2
# Out:
# 34.84097480380009

# %%
#MMA2_S1
MMA2_S1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 1)]
MMA2_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3488       1.0        1      6.0         7         2         2      7.0
# 3520       1.0        1      8.0         7         2         2      1.0
# 3523       1.0        1      8.0         6         2         2      1.0
# 3524       1.0        1      8.0         7         2         2      1.0
# 3536       1.0        1      6.0         7         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441282     1.0        1      8.0         7         2         2      1.0
# 441317     1.0        1      6.0         8         2         2      3.0
# 441412     1.0        1      6.0         7         2         2      3.0
# 441424     1.0        1      6.0         6         2         2      1.0
# 441450     1.0        1      7.0         5         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3488         2.0         2         1
# ...

# %%
stroke = 0
for x in MMA2_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA2_S1 = ((stroke / len(MMA2_S1) * 100))

stroke_MMA2_S1
# Out:
# 0.9404626469472885

# %%
HA = 0
for x in MMA2_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA2_S1 = ((HA / len(MMA2_S1) * 100))

HA_MMA2_S1
# Out:
# 2.495259764884338

# %%
HBP = 0
for x in MMA2_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA2_S1 = ((HBP / len(MMA2_S1) * 100))
HBP_MMA2_S1
# Out:
# 33.310580204778155

# %%
#MMA2_S2
MMA2_S2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 2)]
MMA2_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3456       1.0        1      8.0         6         2         2      1.0
# 3502       1.0        1      7.0         6         2         2      1.0
# 3575       1.0        1      7.0         7         2         2      1.0
# 3622       1.0        1      6.0         5         2         2      3.0
# 3997       1.0        1      8.0         7         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 435847     1.0        1      6.0         5         2         2      3.0
# 438925     1.0        1      8.0         6         2         2      1.0
# 440592     1.0        1      7.0         7         2         2      1.0
# 441055     1.0        1      6.0         5         2         2      3.0
# 441225     1.0        1      7.0         8         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3456         1.0         2         2
# ...

# %%
stroke = 0
for x in MMA2_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA2_S2 = ((stroke / len(MMA2_S2) * 100))

stroke_MMA2_S2
# Out:
# 1.701093560145808

# %%
HA = 0
for x in MMA2_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA2_S2 = ((HA / len(MMA2_S2) * 100))

HA_MMA2_S2
# Out:
# 4.374240583232078

# %%
HBP = 0
for x in MMA2_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA2_S2 = ((HBP / len(MMA2_S2) * 100))
HBP_MMA2_S2
# Out:
# 36.026731470230864

# %%
#female, single, below 35000, 39-59
FSB2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))]
FSB2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3476       2.0        2      1.0         8         2         2      1.0
# 3479       2.0        2      5.0         5         2         1      1.0
# 3487       2.0        2      2.0         7         2         2      3.0
# 3510       2.0        5      1.0         6         2         2      1.0
# 3540       2.0        3      2.0         8         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441379     2.0        2      3.0         8         2         2      1.0
# 441417     2.0        2      3.0         7         2         2      3.0
# 441425     2.0        5      2.0         5         2         2      3.0
# 441426     2.0        2      2.0         5         2         2      3.0
# 441427     2.0        2      4.0         6         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3476         1.0         2         1
# ...

# %%
#Stroke Chance FSB2
stroke = 0
for x in FSB2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB2 = ((stroke / len(FSB2) * 100))

stroke_FSB2
# Out:
# 6.138555977784273

# %%
#Heart Attack Chance FSB2
HA = 0
for x in FSB2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB2 = ((HA / len(FSB2) * 100))

HA_FSB2
# Out:
# 5.480853551593102

# %%
#High Blood pressure FSB2
HBP = 0
for x in FSB2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB2 = ((HBP / len(FSB2) * 100))

HBP_FSB2
# Out:
# 41.566793335282085

# %%
#FSB2_E1
FSB2_E1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 1)]
FSB2_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3476       2.0        2      1.0         8         2         2      1.0
# 3479       2.0        2      5.0         5         2         1      1.0
# 3559       2.0        5      3.0         8         2         2      1.0
# 3628       2.0        2      2.0         8         1         2      1.0
# 3651       2.0        3      2.0         8         1         1      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441270     2.0        2      1.0         6         1         1      1.0
# 441300     2.0        5      4.0         5         2         2      1.0
# 441371     2.0        2      5.0         5         2         2      3.0
# 441375     2.0        6      2.0         7         2         2      1.0
# 441425     2.0        5      2.0         5         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3476         1.0         2         1
# ...

# %%
#Stroke Chance FSB2_E1
stroke = 0
for x in FSB2_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB2_E1 = ((stroke / len(FSB2_E1) * 100))

stroke_FSB2_E1
# Out:
# 5.13161393246477

# %%
#Heart Attack Chance FSB2_E1
HA = 0
for x in FSB2_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB2_E1 = ((HA / len(FSB2_E1) * 100))

HA_FSB2_E1
# Out:
# 5.184791278915182

# %%
#High Blood pressure FSB2_E1
HBP = 0
for x in FSB2_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB2_E1 = ((HBP / len(FSB2_E1) * 100))

HBP_FSB2_E1
# Out:
# 38.633342196224405

# %%
#FSB2_E2
FSB2_E2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 2)]
FSB2_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3487       2.0        2      2.0         7         2         2      3.0
# 3510       2.0        5      1.0         6         2         2      1.0
# 3540       2.0        3      2.0         8         2         2      1.0
# 3557       2.0        2      3.0         6         2         2      3.0
# 3618       2.0        2      1.0         7         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441354     2.0        4      2.0         7         2         2      1.0
# 441379     2.0        2      3.0         8         2         2      1.0
# 441417     2.0        2      3.0         7         2         2      3.0
# 441426     2.0        2      2.0         5         2         2      3.0
# 441427     2.0        2      4.0         6         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3487         2.0         2         1
# ...

# %%
#Stroke Chance FSB2_E2
stroke = 0
for x in FSB2_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB2_E2 = ((stroke / len(FSB2_E2) * 100))

stroke_FSB2_E2
# Out:
# 7.244607244607244

# %%
#Heart Attack Chance FSB2_E2
HA = 0
for x in FSB2_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB2_E2 = ((HA / len(FSB2_E2) * 100))

HA_FSB2_E2
# Out:
# 5.982905982905983

# %%
#High Blood pressure FSB2_E2
HBP = 0
for x in FSB2_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB2_E2 = ((HBP / len(FSB2_E2) * 100))

HBP_FSB2_E2
# Out:
# 46.682946682946685

# %%
#FSB2_D1
FSB2_D1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 1)]
FSB2_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3479       2.0        2      5.0         5         2         1      1.0
# 3540       2.0        3      2.0         8         2         2      1.0
# 3618       2.0        2      1.0         7         2         2      3.0
# 3624       2.0        5      1.0         5         2         2      1.0
# 3628       2.0        2      2.0         8         1         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441149     2.0        2      1.0         6         2         2      3.0
# 441155     2.0        2      1.0         8         2         2      1.0
# 441221     2.0        5      3.0         6         2         2      1.0
# 441371     2.0        2      5.0         5         2         2      3.0
# 441426     2.0        2      2.0         5         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3479         1.0         1         1
# ...

# %%
#Stroke Chance FSB2_D1
stroke = 0
for x in FSB2_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB2_D1 = ((stroke / len(FSB2_D1) * 100))

stroke_FSB2_D1
# Out:
# 4.288747346072187

# %%
#Heart Attack Chance FSB2_D1
HA = 0
for x in FSB2_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB2_D1 = ((HA / len(FSB2_D1) * 100))

HA_FSB2_D1
# Out:
# 3.4394904458598727

# %%
#High Blood pressure FSB2_D1
HBP = 0
for x in FSB2_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB2_D1 = ((HBP / len(FSB2_D1) * 100))

HBP_FSB2_D1
# Out:
# 36.475583864118896

# %%
#FSB2_D2
FSB2_D2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 2)]
FSB2_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3476       2.0        2      1.0         8         2         2      1.0
# 3487       2.0        2      2.0         7         2         2      3.0
# 3510       2.0        5      1.0         6         2         2      1.0
# 3557       2.0        2      3.0         6         2         2      3.0
# 3559       2.0        5      3.0         8         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441375     2.0        6      2.0         7         2         2      1.0
# 441379     2.0        2      3.0         8         2         2      1.0
# 441417     2.0        2      3.0         7         2         2      3.0
# 441425     2.0        5      2.0         5         2         2      3.0
# 441427     2.0        2      4.0         6         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3476         1.0         2         1
# ...

# %%
#Stroke Chance FSB2_D2
stroke = 0
for x in FSB2_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB2_D2 = ((stroke / len(FSB2_D2) * 100))

stroke_FSB2_D2
# Out:
# 7.161489210339103

# %%
#Heart Attack Chance FSB2_D2
HA = 0
for x in FSB2_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB2_D2 = ((HA / len(FSB2_D2) * 100))

HA_FSB2_D2
# Out:
# 6.663504861275789

# %%
#High Blood pressure FSB2_D2
HBP = 0
for x in FSB2_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB2_D2 = ((HBP / len(FSB2_D2) * 100))

HBP_FSB2_D2
# Out:
# 44.51031539008774

# %%
#FSB2_S1
FSB2_S1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 1)]
FSB2_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3476       2.0        2      1.0         8         2         2      1.0
# 3479       2.0        2      5.0         5         2         1      1.0
# 3487       2.0        2      2.0         7         2         2      3.0
# 3557       2.0        2      3.0         6         2         2      3.0
# 3559       2.0        5      3.0         8         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441375     2.0        6      2.0         7         2         2      1.0
# 441379     2.0        2      3.0         8         2         2      1.0
# 441417     2.0        2      3.0         7         2         2      3.0
# 441425     2.0        5      2.0         5         2         2      3.0
# 441426     2.0        2      2.0         5         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3476         1.0         2         1
# ...

# %%
#Stroke Chance FSB2_S1
stroke = 0
for x in FSB2_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB2_S1 = ((stroke / len(FSB2_S1) * 100))

stroke_FSB2_S1
# Out:
# 5.0940798531436435

# %%
#Heart Attack Chance FSB2_S1
HA = 0
for x in FSB2_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB2_S1 = ((HA / len(FSB2_S1) * 100))

HA_FSB2_S1
# Out:
# 4.703992657182194

# %%
#High Blood pressure FSB2_S1
HBP = 0
for x in FSB2_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB2_S1 = ((HBP / len(FSB2_S1) * 100))

HBP_FSB2_S1
# Out:
# 41.32629646626893

# %%
#FSB2_S2
FSB2_S2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 2)]
FSB2_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3510       2.0        5      1.0         6         2         2      1.0
# 3540       2.0        3      2.0         8         2         2      1.0
# 3618       2.0        2      1.0         7         2         2      3.0
# 3638       2.0        2      3.0         6         2         2      1.0
# 3700       2.0        3      4.0         7         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440719     2.0        4      1.0         5         2         2      1.0
# 440945     2.0        6      1.0         6         2         2      3.0
# 441066     2.0        5      1.0         5         2         2      3.0
# 441308     2.0        5      1.0         6         2         2      3.0
# 441427     2.0        2      4.0         6         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3510         2.0         2         2
# ...

# %%
#Stroke Chance FSB2_S2
stroke = 0
for x in FSB2_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB2_S2 = ((stroke / len(FSB2_S2) * 100))

stroke_FSB2_S2
# Out:
# 8.158813263525305

# %%
#Heart Attack Chance FSB2_S2
HA = 0
for x in FSB2_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB2_S2 = ((HA / len(FSB2_S2) * 100))

HA_FSB2_S2
# Out:
# 6.980802792321117

# %%
#High Blood pressure FSB2_S2
HBP = 0
for x in FSB2_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB2_S2 = ((HBP / len(FSB2_S2) * 100))

HBP_FSB2_S2
# Out:
# 41.97207678883071

# %%
#male, single, below 35000, 39-59
MSB2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))]
MSB2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3473       1.0        2      4.0         6         2         1      1.0
# 3538       1.0        2      3.0         6         2         2      1.0
# 3580       1.0        3      4.0         8         2         2      1.0
# 3611       1.0        4      1.0         8         2         2      1.0
# 3632       1.0        2      1.0         6         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441359     1.0        5      4.0         6         2         2      3.0
# 441377     1.0        6      3.0         5         2         2      3.0
# 441401     1.0        4      1.0         5         2         2      3.0
# 441447     1.0        2      1.0         6         2         2      3.0
# 441454     1.0        5      1.0         7         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3473         2.0         2         1
# ...

# %%
stroke = 0
for x in MSB2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB2 = ((stroke / len(MSB2) * 100))

stroke_MSB2
# Out:
# 5.72695363014964

# %%
HA = 0
for x in MSB2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB2 = ((HA / len(MSB2) * 100))

HA_MSB2
# Out:
# 8.184001477923518

# %%
HBP = 0
for x in MSB2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB2 = ((HBP / len(MSB2) * 100))
HBP_MSB2
# Out:
# 46.12968778865694

# %%
#MSB2_E1
MSB2_E1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 1)]
MSB2_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3538       1.0        2      3.0         6         2         2      1.0
# 3611       1.0        4      1.0         8         2         2      1.0
# 3632       1.0        2      1.0         6         2         2      1.0
# 3642       1.0        6      3.0         7         2         1      1.0
# 3711       1.0        2      3.0         5         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441117     1.0        2      1.0         8         1         2      1.0
# 441126     1.0        6      5.0         5         2         2      3.0
# 441151     1.0        4      1.0         8         2         2      3.0
# 441173     1.0        5      1.0         5         2         2      3.0
# 441195     1.0        5      4.0         5         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3538         1.0         1         1
# ...

# %%
stroke = 0
for x in MSB2_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB2_E1 = ((stroke / len(MSB2_E1) * 100))

stroke_MSB2_E1
# Out:
# 5.098300566477841

# %%
HA = 0
for x in MSB2_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB2_E1 = ((HA / len(MSB2_E1) * 100))

HA_MSB2_E1
# Out:
# 7.597467510829723

# %%
HBP = 0
for x in MSB2_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB2_E1 = ((HBP / len(MSB2_E1) * 100))
HBP_MSB2_E1
# Out:
# 45.884705098300564

# %%
#MSB2_E2
MSB2_E2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 2)]
MSB2_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3473       1.0        2      4.0         6         2         1      1.0
# 3580       1.0        3      4.0         8         2         2      1.0
# 3683       1.0        2      2.0         8         2         2      3.0
# 3793       1.0        2      5.0         7         2         2      3.0
# 3850       1.0        2      4.0         6         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441135     1.0        4      4.0         8         2         2      1.0
# 441349     1.0        2      1.0         7         2         2      1.0
# 441401     1.0        4      1.0         5         2         2      3.0
# 441447     1.0        2      1.0         6         2         2      3.0
# 441454     1.0        5      1.0         7         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3473         2.0         2         1
# ...

# %%
stroke = 0
for x in MSB2_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB2_E2 = ((stroke / len(MSB2_E2) * 100))

stroke_MSB2_E2
# Out:
# 6.3561643835616435

# %%
HA = 0
for x in MSB2_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB2_E2 = ((HA / len(MSB2_E2) * 100))

HA_MSB2_E2
# Out:
# 9.205479452054794

# %%
HBP = 0
for x in MSB2_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB2_E2 = ((HBP / len(MSB2_E2) * 100))
HBP_MSB2_E2
# Out:
# 48.32876712328767

# %%
#MSB2_D1
MSB2_D1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 1)]
MSB2_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3538       1.0        2      3.0         6         2         2      1.0
# 3642       1.0        6      3.0         7         2         1      1.0
# 3818       1.0        2      4.0         7         2         2      1.0
# 3991       1.0        6      4.0         8         2         2      1.0
# 3993       1.0        2      1.0         7         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441195     1.0        5      4.0         5         2         2      3.0
# 441349     1.0        2      1.0         7         2         2      1.0
# 441377     1.0        6      3.0         5         2         2      3.0
# 441401     1.0        4      1.0         5         2         2      3.0
# 441447     1.0        2      1.0         6         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3538         1.0         1         1
# ...

# %%
stroke = 0
for x in MSB2_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB2_D1 = ((stroke / len(MSB2_D1) * 100))

stroke_MSB2_D1
# Out:
# 4.422310756972111

# %%
HA = 0
for x in MSB2_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB2_D1 = ((HA / len(MSB2_D1) * 100))

HA_MSB2_D1
# Out:
# 6.852589641434263

# %%
HBP = 0
for x in MSB2_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB2_D1 = ((HBP / len(MSB2_D1) * 100))
HBP_MSB2_D1
# Out:
# 44.18326693227092

# %%
#MSB2_D2
MSB2_D2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 2)]
MSB2_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3473       1.0        2      4.0         6         2         1      1.0
# 3580       1.0        3      4.0         8         2         2      1.0
# 3611       1.0        4      1.0         8         2         2      1.0
# 3632       1.0        2      1.0         6         2         2      1.0
# 3683       1.0        2      2.0         8         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441073     1.0        2      1.0         8         2         2      3.0
# 441117     1.0        2      1.0         8         1         2      1.0
# 441135     1.0        4      4.0         8         2         2      1.0
# 441359     1.0        5      4.0         6         2         2      3.0
# 441454     1.0        5      1.0         7         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3473         2.0         2         1
# ...

# %%
stroke = 0
for x in MSB2_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB2_D2 = ((stroke / len(MSB2_D2) * 100))

stroke_MSB2_D2
# Out:
# 6.8560606060606055

# %%
HA = 0
for x in MSB2_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB2_D2 = ((HA / len(MSB2_D2) * 100))

HA_MSB2_D2
# Out:
# 9.621212121212121

# %%
HBP = 0
for x in MSB2_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB2_D2 = ((HBP / len(MSB2_D2) * 100))
HBP_MSB2_D2
# Out:
# 48.03030303030303

# %%
#MSB2_S1
MSB2_S1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 1)]
MSB2_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3473       1.0        2      4.0         6         2         1      1.0
# 3538       1.0        2      3.0         6         2         2      1.0
# 3580       1.0        3      4.0         8         2         2      1.0
# 3611       1.0        4      1.0         8         2         2      1.0
# 3642       1.0        6      3.0         7         2         1      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441195     1.0        5      4.0         5         2         2      3.0
# 441349     1.0        2      1.0         7         2         2      1.0
# 441359     1.0        5      4.0         6         2         2      3.0
# 441401     1.0        4      1.0         5         2         2      3.0
# 441454     1.0        5      1.0         7         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3473         2.0         2         1
# ...

# %%
stroke = 0
for x in MSB2_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB2_S1 = ((stroke / len(MSB2_S1) * 100))

stroke_MSB2_S1
# Out:
# 4.922365378262306

# %%
HA = 0
for x in MSB2_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB2_S1 = ((HA / len(MSB2_S1) * 100))

HA_MSB2_S1
# Out:
# 6.838453914767097

# %%
HBP = 0
for x in MSB2_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB2_S1 = ((HBP / len(MSB2_S1) * 100))
HBP_MSB2_S1
# Out:
# 46.97720515361744

# %%
#MSB2_S2
MSB2_S2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 2)]
MSB2_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3632       1.0        2      1.0         6         2         2      1.0
# 3711       1.0        2      3.0         5         2         2      3.0
# 3793       1.0        2      5.0         7         2         2      3.0
# 3802       1.0        5      1.0         6         2         2      1.0
# 3956       1.0        6      1.0         7         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441073     1.0        2      1.0         8         2         2      3.0
# 441126     1.0        6      5.0         5         2         2      3.0
# 441151     1.0        4      1.0         8         2         2      3.0
# 441377     1.0        6      3.0         5         2         2      3.0
# 441447     1.0        2      1.0         6         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3632         1.0         2         2
# ...

# %%
stroke = 0
for x in MSB2_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB2_S2 = ((stroke / len(MSB2_S2) * 100))

stroke_MSB2_S2
# Out:
# 6.749311294765841

# %%
HA = 0
for x in MSB2_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB2_S2 = ((HA / len(MSB2_S2) * 100))

HA_MSB2_S2
# Out:
# 9.963269054178145

# %%
HBP = 0
for x in MSB2_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB2_S2 = ((HBP / len(MSB2_S2) * 100))
HBP_MSB2_S2
# Out:
# 45.04132231404959

# %%
#female, married, below 35000, 39-59
FMB2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))]
FMB2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3572       2.0        1      4.0         8         2         2      3.0
# 3630       2.0        1      1.0         8         2         2      3.0
# 3644       2.0        1      3.0         7         2         2      1.0
# 3694       2.0        1      5.0         5         2         2      3.0
# 3712       2.0        1      5.0         7         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441406     2.0        1      1.0         6         2         2      3.0
# 441419     2.0        1      1.0         6         2         2      3.0
# 441423     2.0        1      3.0         7         2         2      3.0
# 441428     2.0        1      1.0         5         2         2      3.0
# 441429     2.0        1      2.0         6         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3572         1.0         2         1
# ...

# %%
#Stroke Chance FMB2
stroke = 0
for x in FMB2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB2 = ((stroke / len(FMB2) * 100))

stroke_FMB2
# Out:
# 5.310280950910775

# %%
#Heart Attack Chance FMB2
HA = 0
for x in FMB2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB2 = ((HA / len(FMB2) * 100))

HA_FMB2
# Out:
# 4.908922506946588

# %%
#High Blood pressure FMB2
HBP = 0
for x in FMB2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB2 = ((HBP / len(FMB2) * 100))

HBP_FMB2
# Out:
# 39.73448595245446

# %%
#FMB2_E1
FMB2_E1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) &
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 1)]
FMB2_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3572       2.0        1      4.0         8         2         2      3.0
# 3712       2.0        1      5.0         7         2         2      1.0
# 3915       2.0        1      5.0         7         2         2      1.0
# 4023       2.0        1      3.0         5         1         2      1.0
# 4204       2.0        1      4.0         5         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441092     2.0        1      2.0         7         2         2      3.0
# 441110     2.0        1      4.0         7         2         2      1.0
# 441238     2.0        1      2.0         6         2         2      3.0
# 441392     2.0        1      2.0         8         2         2      1.0
# 441404     2.0        1      2.0         5         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3572         1.0         2         1
# ...

# %%
#Stroke Chance FMB2_E1
stroke = 0
for x in FMB2_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB2_E1 = ((stroke / len(FMB2_E1) * 100))

stroke_FMB2_E1
# Out:
# 4.485336400230017

# %%
#Heart Attack Chance FMB2_E1
HA = 0
for x in FMB2_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB2_E1 = ((HA / len(FMB2_E1) * 100))

HA_FMB2_E1
# Out:
# 4.140310523289246

# %%
#High Blood pressure FMB2_E1
HBP = 0
for x in FMB2_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB2_E1 = ((HBP / len(FMB2_E1) * 100))

HBP_FMB2_E1
# Out:
# 36.74525589419206

# %%
#FMB2_E2
FMB2_E2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) &
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 2)]
FMB2_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3644       2.0        1      3.0         7         2         2      1.0
# 4122       2.0        1      4.0         8         2         1      1.0
# 4306       2.0        1      5.0         8         2         2      1.0
# 4355       2.0        1      4.0         7         2         2      3.0
# 4442       2.0        1      1.0         6         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441406     2.0        1      1.0         6         2         2      3.0
# 441419     2.0        1      1.0         6         2         2      3.0
# 441423     2.0        1      3.0         7         2         2      3.0
# 441428     2.0        1      1.0         5         2         2      3.0
# 441429     2.0        1      2.0         6         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3644         2.0         1         2
# ...

# %%
#Stroke Chance FMB2_E2
stroke = 0
for x in FMB2_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB2_E2 = ((stroke / len(FMB2_E2) * 100))

stroke_FMB2_E2
# Out:
# 6.7669172932330826

# %%
#Heart Attack Chance FMB2_E2
HA = 0
for x in FMB2_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB2_E2 = ((HA / len(FMB2_E2) * 100))

HA_FMB2_E2
# Out:
# 6.265664160401002

# %%
#High Blood pressure FMB2_E2
HBP = 0
for x in FMB2_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB2_E2 = ((HBP / len(FMB2_E2) * 100))

HBP_FMB2_E2
# Out:
# 44.52798663324979

# %%
#FMB2_D1
FMB2_D1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) &
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 1)]
FMB2_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3630       2.0        1      1.0         8         2         2      3.0
# 3644       2.0        1      3.0         7         2         2      1.0
# 3915       2.0        1      5.0         7         2         2      1.0
# 3937       2.0        1      2.0         5         2         2      1.0
# 4228       2.0        1      5.0         6         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440526     2.0        1      5.0         8         2         2      1.0
# 440823     2.0        1      1.0         8         2         2      1.0
# 441163     2.0        1      2.0         8         2         2      3.0
# 441222     2.0        1      1.0         6         2         2      1.0
# 441238     2.0        1      2.0         6         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3630         NaN         1         2
# ...

# %%
#Stroke Chance FMB2_D1
stroke = 0
for x in FMB2_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB2_D1 = ((stroke / len(FMB2_D1) * 100))

stroke_FMB2_D1
# Out:
# 3.508771929824561

# %%
#Heart Attack Chance FMB2_D1
HA = 0
for x in FMB2_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB2_D1 = ((HA / len(FMB2_D1) * 100))

HA_FMB2_D1
# Out:
# 3.3918128654970756

# %%
#High Blood pressure FMB2_D1
HBP = 0
for x in FMB2_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB2_D1 = ((HBP / len(FMB2_D1) * 100))

HBP_FMB2_D1
# Out:
# 36.49122807017544

# %%
#FMB2_D2
FMB2_D2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) &
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 2)]
FMB2_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3572       2.0        1      4.0         8         2         2      3.0
# 3694       2.0        1      5.0         5         2         2      3.0
# 3712       2.0        1      5.0         7         2         2      1.0
# 4023       2.0        1      3.0         5         1         2      1.0
# 4122       2.0        1      4.0         8         2         1      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441406     2.0        1      1.0         6         2         2      3.0
# 441419     2.0        1      1.0         6         2         2      3.0
# 441423     2.0        1      3.0         7         2         2      3.0
# 441428     2.0        1      1.0         5         2         2      3.0
# 441429     2.0        1      2.0         6         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3572         1.0         2         1
# ...

# %%
#Stroke Chance FMB2_D2
stroke = 0
for x in FMB2_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB2_D2 = ((stroke / len(FMB2_D2) * 100))

stroke_FMB2_D2
# Out:
# 5.8770749214894575

# %%
#Heart Attack Chance FMB2_D2
HA = 0
for x in FMB2_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB2_D2 = ((HA / len(FMB2_D2) * 100))

HA_FMB2_D2
# Out:
# 5.607895917451772

# %%
#High Blood pressure FMB2_D2
HBP = 0
for x in FMB2_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB2_D2 = ((HBP / len(FMB2_D2) * 100))

HBP_FMB2_D2
# Out:
# 41.00493494840735

# %%
#FMB2_S1
FMB2_S1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) &
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 1)]
FMB2_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3572       2.0        1      4.0         8         2         2      3.0
# 3694       2.0        1      5.0         5         2         2      3.0
# 3712       2.0        1      5.0         7         2         2      1.0
# 4122       2.0        1      4.0         8         2         1      1.0
# 4228       2.0        1      5.0         6         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441406     2.0        1      1.0         6         2         2      3.0
# 441419     2.0        1      1.0         6         2         2      3.0
# 441423     2.0        1      3.0         7         2         2      3.0
# 441428     2.0        1      1.0         5         2         2      3.0
# 441429     2.0        1      2.0         6         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3572         1.0         2         1
# ...

# %%
#Stroke Chance FMB2_S1
stroke = 0
for x in FMB2_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB2_S1 = ((stroke / len(FMB2_S1) * 100))

stroke_FMB2_S1
# Out:
# 4.670912951167728

# %%
#Heart Attack Chance FMB2_S1
HA = 0
for x in FMB2_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB2_S1 = ((HA / len(FMB2_S1) * 100))

HA_FMB2_S1
# Out:
# 3.7367303609341826

# %%
#High Blood pressure FMB2_S1
HBP = 0
for x in FMB2_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB2_S1 = ((HBP / len(FMB2_S1) * 100))

HBP_FMB2_S1
# Out:
# 39.87261146496815

# %%
#FMB2_S2
FMB2_S2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) &
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 2)]
FMB2_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3630       2.0        1      1.0         8         2         2      3.0
# 3644       2.0        1      3.0         7         2         2      1.0
# 3915       2.0        1      5.0         7         2         2      1.0
# 3937       2.0        1      2.0         5         2         2      1.0
# 4023       2.0        1      3.0         5         1         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440131     2.0        1      1.0         8         2         2      1.0
# 440238     2.0        1      2.0         6         2         2      1.0
# 440374     2.0        1      5.0         6         2         2      3.0
# 440717     2.0        1      3.0         8         2         2      3.0
# 440991     2.0        1      1.0         6         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3630         NaN         1         2
# ...

# %%
#Stroke Chance FMB2_S2
stroke = 0
for x in FMB2_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB2_S2 = ((stroke / len(FMB2_S2) * 100))

stroke_FMB2_S2
# Out:
# 6.684141546526867

# %%
#Heart Attack Chance FMB2_S2
HA = 0
for x in FMB2_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB2_S2 = ((HA / len(FMB2_S2) * 100))

HA_FMB2_S2
# Out:
# 8.781127129750983

# %%
#High Blood pressure FMB2_S2
HBP = 0
for x in FMB2_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB2_S2 = ((HBP / len(FMB2_S2) * 100))

HBP_FMB2_S2
# Out:
# 39.31847968545216

# %%
#male, married, below 35000, 39-59
MMB2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))]
MMB2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3604       1.0        1      5.0         6         2         2      3.0
# 3665       1.0        1      1.0         8         2         1      1.0
# 3668       1.0        1      4.0         5         2         2      3.0
# 3783       1.0        1      4.0         8         2         2      1.0
# 3876       1.0        1      1.0         7         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441209     1.0        1      1.0         7         2         1      1.0
# 441256     1.0        1      4.0         7         2         2      3.0
# 441288     1.0        1      4.0         8         2         2      1.0
# 441435     1.0        1      4.0         6         2         2      3.0
# 441442     1.0        1      2.0         8         1         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3604         2.0         1         2
# ...

# %%
stroke = 0
for x in MMB2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB2 = ((stroke / len(MMB2) * 100))

stroke_MMB2
# Out:
# 4.297520661157025

# %%
HA = 0
for x in MMB2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB2 = ((HA / len(MMB2) * 100))

HA_MMB2
# Out:
# 8.0

# %%
HBP = 0
for x in MMB2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB2 = ((HBP / len(MMB2) * 100))
HBP_MMB2
# Out:
# 42.280991735537185

# %%
#MMB2_E1
MMB2_E1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) &
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 1)]
MMB2_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3876       1.0        1      1.0         7         2         2      3.0
# 3929       1.0        1      5.0         6         2         2      3.0
# 4124       1.0        1      4.0         6         2         2      3.0
# 4125       1.0        1      5.0         5         2         2      3.0
# 4403       1.0        1      3.0         8         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441132     1.0        1      5.0         8         2         2      1.0
# 441196     1.0        1      4.0         7         2         2      3.0
# 441209     1.0        1      1.0         7         2         1      1.0
# 441256     1.0        1      4.0         7         2         2      3.0
# 441288     1.0        1      4.0         8         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3876         1.0         2         1
# ...

# %%
stroke = 0
for x in MMB2_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB2_E1 = ((stroke / len(MMB2_E1) * 100))

stroke_MMB2_E1
# Out:
# 4.785894206549118

# %%
HA = 0
for x in MMB2_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB2_E1 = ((HA / len(MMB2_E1) * 100))

HA_MMB2_E1
# Out:
# 7.682619647355164

# %%
HBP = 0
for x in MMB2_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB2_E1 = ((HBP / len(MMB2_E1) * 100))
HBP_MMB2_E1
# Out:
# 42.56926952141058

# %%
#MMB2_E2
MMB2_E2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) &
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['EXERANY2'] == 2)]
MMB2_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3604       1.0        1      5.0         6         2         2      3.0
# 3668       1.0        1      4.0         5         2         2      3.0
# 3783       1.0        1      4.0         8         2         2      1.0
# 3890       1.0        1      3.0         6         2         2      3.0
# 3894       1.0        1      3.0         8         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441087     1.0        1      5.0         6         1         2      1.0
# 441137     1.0        1      3.0         5         2         2      1.0
# 441204     1.0        1      3.0         5         2         2      1.0
# 441435     1.0        1      4.0         6         2         2      3.0
# 441442     1.0        1      2.0         8         1         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3604         2.0         1         2
# ...

# %%
stroke = 0
for x in MMB2_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB2_E2 = ((stroke / len(MMB2_E2) * 100))

stroke_MMB2_E2
# Out:
# 4.521276595744681

# %%
HA = 0
for x in MMB2_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB2_E2 = ((HA / len(MMB2_E2) * 100))

HA_MMB2_E2
# Out:
# 8.953900709219859

# %%
HBP = 0
for x in MMB2_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB2_E2 = ((HBP / len(MMB2_E2) * 100))
HBP_MMB2_E2
# Out:
# 43.262411347517734

# %%
#MMB2_D1
MMB2_D1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) &
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 1)]
MMB2_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3604       1.0        1      5.0         6         2         2      3.0
# 3894       1.0        1      3.0         8         2         2      3.0
# 4112       1.0        1      3.0         8         2         2      4.0
# 4124       1.0        1      4.0         6         2         2      3.0
# 4125       1.0        1      5.0         5         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441031     1.0        1      3.0         5         2         2      1.0
# 441052     1.0        1      5.0         5         2         2      3.0
# 441084     1.0        1      3.0         8         2         1      3.0
# 441132     1.0        1      5.0         8         2         2      1.0
# 441435     1.0        1      4.0         6         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3604         2.0         1         2
# ...

# %%
stroke = 0
for x in MMB2_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB2_D1 = ((stroke / len(MMB2_D1) * 100))

stroke_MMB2_D1
# Out:
# 3.8950715421303657

# %%
HA = 0
for x in MMB2_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB2_D1 = ((HA / len(MMB2_D1) * 100))

HA_MMB2_D1
# Out:
# 5.5643879173290935

# %%
HBP = 0
for x in MMB2_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB2_D1 = ((HBP / len(MMB2_D1) * 100))
HBP_MMB2_D1
# Out:
# 40.14308426073132

# %%
#MMB2_D2
MMB2_D2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) &
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['DRNKANY5'] == 2)]
MMB2_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3665       1.0        1      1.0         8         2         1      1.0
# 3668       1.0        1      4.0         5         2         2      3.0
# 3783       1.0        1      4.0         8         2         2      1.0
# 3876       1.0        1      1.0         7         2         2      3.0
# 3890       1.0        1      3.0         6         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441204     1.0        1      3.0         5         2         2      1.0
# 441209     1.0        1      1.0         7         2         1      1.0
# 441256     1.0        1      4.0         7         2         2      3.0
# 441288     1.0        1      4.0         8         2         2      1.0
# 441442     1.0        1      2.0         8         1         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3665         NaN         2         2
# ...

# %%
stroke = 0
for x in MMB2_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB2_D2 = ((stroke / len(MMB2_D2) * 100))

stroke_MMB2_D2
# Out:
# 4.932182490752158

# %%
HA = 0
for x in MMB2_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB2_D2 = ((HA / len(MMB2_D2) * 100))

HA_MMB2_D2
# Out:
# 10.110974106041924

# %%
HBP = 0
for x in MMB2_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB2_D2 = ((HBP / len(MMB2_D2) * 100))
HBP_MMB2_D2
# Out:
# 44.081381011097406

# %%
#MMB2_S1
MMB2_S1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) &
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 1)]
MMB2_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3668       1.0        1      4.0         5         2         2      3.0
# 3783       1.0        1      4.0         8         2         2      1.0
# 3876       1.0        1      1.0         7         2         2      3.0
# 3890       1.0        1      3.0         6         2         2      3.0
# 3894       1.0        1      3.0         8         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441209     1.0        1      1.0         7         2         1      1.0
# 441256     1.0        1      4.0         7         2         2      3.0
# 441288     1.0        1      4.0         8         2         2      1.0
# 441435     1.0        1      4.0         6         2         2      3.0
# 441442     1.0        1      2.0         8         1         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3668         2.0         2         1
# ...

# %%
stroke = 0
for x in MMB2_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB2_S1 = ((stroke / len(MMB2_S1) * 100))

stroke_MMB2_S1
# Out:
# 3.8533834586466162

# %%
HA = 0
for x in MMB2_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB2_S1 = ((HA / len(MMB2_S1) * 100))

HA_MMB2_S1
# Out:
# 6.954887218045112

# %%
HBP = 0
for x in MMB2_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB2_S1 = ((HBP / len(MMB2_S1) * 100))
HBP_MMB2_S1
# Out:
# 41.91729323308271

# %%
#MMB2_S2
MMB2_S2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) &
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 5) | (rdf['_AGEG5YR'] == 6) | (rdf['_AGEG5YR'] == 7) | (rdf['_AGEG5YR'] == 8))&
           (rdf['_RFSMOK3'] == 2)]
MMB2_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3604       1.0        1      5.0         6         2         2      3.0
# 3665       1.0        1      1.0         8         2         1      1.0
# 3972       1.0        1      4.0         8         2         1      1.0
# 4015       1.0        1      5.0         7         2         2      3.0
# 4112       1.0        1      3.0         8         2         2      4.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439970     1.0        1      5.0         5         2         2      3.0
# 440139     1.0        1      1.0         5         2         2      1.0
# 440913     1.0        1      4.0         7         2         2      1.0
# 440923     1.0        1      2.0         5         2         2      1.0
# 441012     1.0        1      1.0         7         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3604         2.0         1         2
# ...

# %%
stroke = 0
for x in MMB2_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB2_S2 = ((stroke / len(MMB2_S2) * 100))

stroke_MMB2_S2
# Out:
# 6.041131105398458

# %%
HA = 0
for x in MMB2_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB2_S2 = ((HA / len(MMB2_S2) * 100))

HA_MMB2_S2
# Out:
# C:\Users\zacha\anaconda3\lib\site-packages\IPython\core\displayhook.py:275: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
# 11.568123393316196

# %%
HBP = 0
for x in MMB2_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB2_S2 = ((HBP / len(MMB2_S2) * 100))
HBP_MMB2_S2
# Out:
# 43.18766066838046

# %%
#Female, single, above 35000, 60+
FSA3 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))]
FSA3
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3467       2.0        3      6.0        10         2         2      3.0
# 3470       2.0        3      6.0         9         2         2      1.0
# 3674       2.0        2      7.0         9         2         2      1.0
# 3768       2.0        3      6.0        13         2         2      3.0
# 3779       2.0        3      8.0         9         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 436036     2.0        5      7.0        11         2         2      1.0
# 438787     2.0        6      7.0        10         2         2      1.0
# 439231     2.0        3      8.0        13         2         2      1.0
# 440205     2.0        5      6.0         9         2         2      1.0
# 441179     2.0        2      8.0         9         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3467         2.0         2         1
# ...

# %%
#Stroke Chance FSA3
stroke = 0
for x in FSA3['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA3 = ((stroke / len(FSA3) * 100))

stroke_FSA3
# Out:
# 3.5076323481649885

# %%
#Heart Attack Chance FSA3
HA = 0
for x in FSA3['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA3 = ((HA / len(FSA3) * 100))

HA_FSA3
# Out:
# 4.449496589801884

# %%
HBP = 0
for x in FSA3['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_FSA3 = ((HBP / len(FSA3) * 100))
HBP_FSA3
# Out:
# 51.57518674894446

# %%
#FSA3_E1
FSA3_E1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 1)]
FSA3_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3674       2.0        2      7.0         9         2         2      1.0
# 3779       2.0        3      8.0         9         2         2      1.0
# 3976       2.0        2      6.0        11         2         2      1.0
# 3983       2.0        3      6.0         9         2         2      3.0
# 4059       2.0        3      6.0        13         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 434264     2.0        3      6.0        13         2         2      3.0
# 435931     2.0        3      6.0         9         2         2      3.0
# 435994     2.0        2      8.0         9         2         2      3.0
# 436036     2.0        5      7.0        11         2         2      1.0
# 441179     2.0        2      8.0         9         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3674         1.0         1         1
# ...

# %%
#Stroke Chance FSA3_E1
stroke = 0
for x in FSA3_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA3_E1 = ((stroke / len(FSA3_E1) * 100))

stroke_FSA3_E1
# Out:
# 3.172475424486149

# %%
#Heart Attack Chance FSA3_E1
HA = 0
for x in FSA3_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA3_E1 = ((HA / len(FSA3_E1) * 100))

HA_FSA3_E1
# Out:
# 3.753351206434316

# %%
#High Blood pressure FSA3_E1
HBP = 0
for x in FSA3_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA3_E1 = ((HBP / len(FSA3_E1) * 100))

HBP_FSA3_E1
# Out:
# 48.257372654155496

# %%
#FSA3_E2
FSA3_E2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 2)]
FSA3_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3467       2.0        3      6.0        10         2         2      3.0
# 3470       2.0        3      6.0         9         2         2      1.0
# 3768       2.0        3      6.0        13         2         2      3.0
# 3959       2.0        3      6.0        10         2         2      1.0
# 3994       2.0        3      6.0         9         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 435987     2.0        3      6.0        11         2         2      1.0
# 436010     2.0        2      8.0        10         2         2      1.0
# 438787     2.0        6      7.0        10         2         2      1.0
# 439231     2.0        3      8.0        13         2         2      1.0
# 440205     2.0        5      6.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3467         2.0         2         1
# ...

# %%
#Stroke Chance FSA3_E2
stroke = 0
for x in FSA3_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA3_E2 = ((stroke / len(FSA3_E2) * 100))

stroke_FSA3_E2
# Out:
# 4.671532846715328

# %%
#Heart Attack Chance FSA3_E2
HA = 0
for x in FSA3_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA3_E2 = ((HA / len(FSA3_E2) * 100))

HA_FSA3_E2
# Out:
# 6.423357664233577

# %%
#High Blood pressure FSA3_E2
HBP = 0
for x in FSA3_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA3_E2 = ((HBP / len(FSA3_E2) * 100))

HBP_FSA3_E2
# Out:
# 61.16788321167883

# %%
#FSA3_D1
FSA3_D1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 1)]
FSA3_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3674       2.0        2      7.0         9         2         2      1.0
# 4059       2.0        3      6.0        13         2         2      3.0
# 4136       2.0        3      7.0        10         2         2      1.0
# 4307       2.0        2      6.0         9         2         2      3.0
# 4530       2.0        3      6.0        10         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 433864     2.0        3      7.0        10         2         2      3.0
# 435787     2.0        5      7.0        12         2         2      1.0
# 438787     2.0        6      7.0        10         2         2      1.0
# 440205     2.0        5      6.0         9         2         2      1.0
# 441179     2.0        2      8.0         9         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3674         1.0         1         1
# ...

# %%
#Stroke Chance FSA3_D1
stroke = 0
for x in FSA3_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA3_D1 = ((stroke / len(FSA3_D1) * 100))

stroke_FSA3_D1
# Out:
# 2.9356652092442226

# %%
#Heart Attack Chance FSA3_D1
HA = 0
for x in FSA3_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA3_D1 = ((HA / len(FSA3_D1) * 100))

HA_FSA3_D1
# Out:
# 2.873204247345409

# %%
#High Blood pressure FSA3_D1
HBP = 0
for x in FSA3_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA3_D1 = ((HBP / len(FSA3_D1) * 100))

HBP_FSA3_D1
# Out:
# 47.28294815740162

# %%
#FSA3_D2
FSA3_D2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 2)]
FSA3_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3467       2.0        3      6.0        10         2         2      3.0
# 3470       2.0        3      6.0         9         2         2      1.0
# 3768       2.0        3      6.0        13         2         2      3.0
# 3779       2.0        3      8.0         9         2         2      1.0
# 3834       2.0        2      6.0         9         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 435987     2.0        3      6.0        11         2         2      1.0
# 435994     2.0        2      8.0         9         2         2      3.0
# 436010     2.0        2      8.0        10         2         2      1.0
# 436036     2.0        5      7.0        11         2         2      1.0
# 439231     2.0        3      8.0        13         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3467         2.0         2         1
# ...

# %%
#Stroke Chance FSA3_D2
stroke = 0
for x in FSA3_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA3_D2 = ((stroke / len(FSA3_D2) * 100))

stroke_FSA3_D2
# Out:
# 4.3478260869565215

# %%
#Heart Attack Chance FSA3_D2
HA = 0
for x in FSA3_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA3_D2 = ((HA / len(FSA3_D2) * 100))

HA_FSA3_D2
# Out:
# 6.129722024233785

# %%
#High Blood pressure FSA3_D2
HBP = 0
for x in FSA3_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA3_D2 = ((HBP / len(FSA3_D2) * 100))

HBP_FSA3_D2
# Out:
# 56.02280826799715

# %%
#FSA3_S1
FSA3_S1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 1)]
FSA3_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3467       2.0        3      6.0        10         2         2      3.0
# 3470       2.0        3      6.0         9         2         2      1.0
# 3674       2.0        2      7.0         9         2         2      1.0
# 3768       2.0        3      6.0        13         2         2      3.0
# 3779       2.0        3      8.0         9         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 436036     2.0        5      7.0        11         2         2      1.0
# 438787     2.0        6      7.0        10         2         2      1.0
# 439231     2.0        3      8.0        13         2         2      1.0
# 440205     2.0        5      6.0         9         2         2      1.0
# 441179     2.0        2      8.0         9         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3467         2.0         2         1
# ...

# %%
#Stroke Chance FSA3_S1
stroke = 0
for x in FSA3_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA3_S1 = ((stroke / len(FSA3_S1) * 100))

stroke_FSA3_S1
# Out:
# 3.6996336996337

# %%
#Heart Attack Chance FSA3_S1
HA = 0
for x in FSA3_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA3_S1 = ((HA / len(FSA3_S1) * 100))

HA_FSA3_S1
# Out:
# 4.065934065934066

# %%
#High Blood pressure FSA3_S1
HBP = 0
for x in FSA3_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA3_S1 = ((HBP / len(FSA3_S1) * 100))

HBP_FSA3_S1
# Out:
# 51.02564102564102

# %%
#FSA3_S2
FSA3_S2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 2)]
FSA3_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 4530       2.0        3      6.0        10         2         2      1.0
# 6667       2.0        3      6.0         9         1         2      2.0
# 7197       2.0        6      7.0        10         2         2      1.0
# 7202       2.0        2      7.0         9         2         2      1.0
# 10512      2.0        2      8.0         9         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 422257     2.0        5      6.0         9         2         2      1.0
# 433168     2.0        3      6.0        10         2         2      1.0
# 433225     2.0        3      7.0        11         2         2      3.0
# 433864     2.0        3      7.0        10         2         2      3.0
# 433960     2.0        3      7.0        11         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 4530         2.0         1         2
# ...

# %%
#Stroke Chance FSA3_S2
stroke = 0
for x in FSA3_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSA3_S2 = ((stroke / len(FSA3_S2) * 100))

stroke_FSA3_S2
# Out:
# 2.1505376344086025

# %%
#Heart Attack Chance FSA3_S2
HA = 0
for x in FSA3_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSA3_S2 = ((HA / len(FSA3_S2) * 100))

HA_FSA3_S2
# Out:
# 7.526881720430108

# %%
#High Blood pressure FSA3_S2
HBP = 0
for x in FSA3_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSA3_S2 = ((HBP / len(FSA3_S2) * 100))

HBP_FSA3_S2
# Out:
# 54.48028673835126

# %%
#male, single, above 35000, 60+
MSA3 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))]
MSA3
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3485       1.0        3      6.0        11         2         2      1.0
# 3741       1.0        2      7.0        12         2         2      1.0
# 3833       1.0        3      8.0        10         2         2      3.0
# 4025       1.0        4      6.0         9         2         2      1.0
# 4194       1.0        2      7.0         9         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439506     1.0        2      6.0         9         2         2      1.0
# 439809     1.0        2      6.0        10         2         2      3.0
# 440450     1.0        6      8.0         9         2         2      1.0
# 440632     1.0        2      8.0        10         2         2      1.0
# 441432     1.0        2      6.0        10         2         1      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3485         1.0         2         1
# ...

# %%
stroke = 0
for x in MSA3['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA3 = ((stroke / len(MSA3) * 100))

stroke_MSA3
# Out:
# 5.6735120083536374

# %%
HA = 0
for x in MSA3['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA3 = ((HA / len(MSA3) * 100))

HA_MSA3
# Out:
# 12.600069613644274

# %%
HBP = 0
for x in MSA3['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA3 = ((HBP / len(MSA3) * 100))
HBP_MSA3
# Out:
# 53.9853811347024

# %%
#MSA3_E1
MSA3_E1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 1)]
MSA3_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3485       1.0        3      6.0        11         2         2      1.0
# 3833       1.0        3      8.0        10         2         2      3.0
# 4025       1.0        4      6.0         9         2         2      1.0
# 4194       1.0        2      7.0         9         2         2      1.0
# 4249       1.0        3      6.0        12         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439499     1.0        2      7.0        10         2         2      1.0
# 439506     1.0        2      6.0         9         2         2      1.0
# 439809     1.0        2      6.0        10         2         2      3.0
# 440450     1.0        6      8.0         9         2         2      1.0
# 440632     1.0        2      8.0        10         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3485         1.0         2         1
# ...

# %%
stroke = 0
for x in MSA3_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA3_E1 = ((stroke / len(MSA3_E1) * 100))

stroke_MSA3_E1
# Out:
# 5.345757724374693

# %%
HA = 0
for x in MSA3_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA3_E1 = ((HA / len(MSA3_E1) * 100))

HA_MSA3_E1
# Out:
# 11.230995586071604

# %%
HBP = 0
for x in MSA3_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA3_E1 = ((HBP / len(MSA3_E1) * 100))
HBP_MSA3_E1
# Out:
# 52.672878862187346

# %%
#MSA3_E2
MSA3_E2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 2)]
MSA3_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3741       1.0        2      7.0        12         2         2      1.0
# 4232       1.0        3      6.0         9         2         2      1.0
# 4636       1.0        2      8.0        10         2         2      1.0
# 4794       1.0        2      7.0         9         2         2      1.0
# 4915       1.0        3      6.0         9         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 433497     1.0        2      8.0         9         2         2      1.0
# 433714     1.0        5      8.0         9         1         1      1.0
# 433773     1.0        3      6.0        13         2         2      1.0
# 438734     1.0        2      7.0         9         2         2      1.0
# 441432     1.0        2      6.0        10         2         1      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3741         2.0         2         2
# ...

# %%
stroke = 0
for x in MSA3_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA3_E2 = ((stroke / len(MSA3_E2) * 100))

stroke_MSA3_E2
# Out:
# 7.164634146341463

# %%
HA = 0
for x in MSA3_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA3_E2 = ((HA / len(MSA3_E2) * 100))

HA_MSA3_E2
# Out:
# 16.920731707317074

# %%
HBP = 0
for x in MSA3_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA3_E2 = ((HBP / len(MSA3_E2) * 100))
HBP_MSA3_E2
# Out:
# 60.36585365853659

# %%
#MSA3_D1
MSA3_D1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 1)]
MSA3_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 4025       1.0        4      6.0         9         2         2      1.0
# 4232       1.0        3      6.0         9         2         2      1.0
# 4439       1.0        2      7.0        11         2         2      3.0
# 4636       1.0        2      8.0        10         2         2      1.0
# 4713       1.0        2      6.0        11         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 438734     1.0        2      7.0         9         2         2      1.0
# 439349     1.0        2      8.0         9         2         2      1.0
# 439351     1.0        5      8.0         9         2         2      1.0
# 439499     1.0        2      7.0        10         2         2      1.0
# 440450     1.0        6      8.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 4025         1.0         1         2
# ...

# %%
stroke = 0
for x in MSA3_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA3_D1 = ((stroke / len(MSA3_D1) * 100))

stroke_MSA3_D1
# Out:
# 3.974284044418469

# %%
HA = 0
for x in MSA3_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA3_D1 = ((HA / len(MSA3_D1) * 100))

HA_MSA3_D1
# Out:
# 10.753945061367622

# %%
HBP = 0
for x in MSA3_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA3_D1 = ((HBP / len(MSA3_D1) * 100))
HBP_MSA3_D1
# Out:
# 53.477498538866165

# %%
#MSA3_D2
MSA3_D2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 2)]
MSA3_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3485       1.0        3      6.0        11         2         2      1.0
# 3741       1.0        2      7.0        12         2         2      1.0
# 3833       1.0        3      8.0        10         2         2      3.0
# 4194       1.0        2      7.0         9         2         2      1.0
# 4249       1.0        3      6.0        12         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439330     1.0        4      7.0        10         2         2      1.0
# 439506     1.0        2      6.0         9         2         2      1.0
# 439809     1.0        2      6.0        10         2         2      3.0
# 440632     1.0        2      8.0        10         2         2      1.0
# 441432     1.0        2      6.0        10         2         1      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3485         1.0         2         1
# ...

# %%
stroke = 0
for x in MSA3_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA3_D2 = ((stroke / len(MSA3_D2) * 100))

stroke_MSA3_D2
# Out:
# 8.192090395480225

# %%
HA = 0
for x in MSA3_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA3_D2 = ((HA / len(MSA3_D2) * 100))

HA_MSA3_D2
# Out:
# 15.34839924670433

# %%
HBP = 0
for x in MSA3_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA3_D2 = ((HBP / len(MSA3_D2) * 100))
HBP_MSA3_D2
# Out:
# 54.99058380414312

# %%
#MSA3_S1
MSA3_S1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 1)]
MSA3_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3485       1.0        3      6.0        11         2         2      1.0
# 3833       1.0        3      8.0        10         2         2      3.0
# 4194       1.0        2      7.0         9         2         2      1.0
# 4249       1.0        3      6.0        12         2         2      3.0
# 4439       1.0        2      7.0        11         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439351     1.0        5      8.0         9         2         2      1.0
# 439499     1.0        2      7.0        10         2         2      1.0
# 439506     1.0        2      6.0         9         2         2      1.0
# 440450     1.0        6      8.0         9         2         2      1.0
# 440632     1.0        2      8.0        10         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3485         1.0         2         1
# ...

# %%
stroke = 0
for x in MSA3_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA3_S1 = ((stroke / len(MSA3_S1) * 100))

stroke_MSA3_S1
# Out:
# 5.469078670593184

# %%
HA = 0
for x in MSA3_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA3_S1 = ((HA / len(MSA3_S1) * 100))

HA_MSA3_S1
# Out:
# 11.947833403449728

# %%
HBP = 0
for x in MSA3_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA3_S1 = ((HBP / len(MSA3_S1) * 100))
HBP_MSA3_S1
# Out:
# 54.60664703407657

# %%
#MSA3_S2
MSA3_S2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 2)]
MSA3_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3741       1.0        2      7.0        12         2         2      1.0
# 4025       1.0        4      6.0         9         2         2      1.0
# 4232       1.0        3      6.0         9         2         2      1.0
# 4713       1.0        2      6.0        11         2         2      1.0
# 4794       1.0        2      7.0         9         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 433240     1.0        2      6.0         9         2         2      3.0
# 433495     1.0        3      6.0         9         2         2      1.0
# 434209     1.0        2      6.0        10         2         2      4.0
# 439809     1.0        2      6.0        10         2         2      3.0
# 441432     1.0        2      6.0        10         2         1      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3741         2.0         2         2
# ...

# %%
stroke = 0
for x in MSA3_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSA3_S2 = ((stroke / len(MSA3_S2) * 100))

stroke_MSA3_S2
# Out:
# 6.65083135391924

# %%
HA = 0
for x in MSA3_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSA3_S2 = ((HA / len(MSA3_S2) * 100))

HA_MSA3_S2
# Out:
# 15.439429928741092

# %%
HBP = 0
for x in MSA3_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSA3_S2 = ((HBP / len(MSA3_S2) * 100))
HBP_MSA3_S2
# Out:
# 51.78147268408551

# %%
#female, married, above 35000, 60+
FMA3 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))]
FMA3
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3457       2.0        1      6.0         9         2         2      1.0
# 3478       2.0        1      7.0         9         2         2      3.0
# 3489       2.0        1      8.0         9         2         2      1.0
# 3528       2.0        1      8.0        10         2         2      3.0
# 3545       2.0        1      8.0        10         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440875     2.0        1      8.0        10         2         2      1.0
# 441088     2.0        1      7.0        10         2         2      3.0
# 441099     2.0        1      7.0        10         2         2      3.0
# 441343     2.0        1      7.0         9         2         2      1.0
# 441431     2.0        1      7.0        11         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3457         2.0         2         1
# ...

# %%
#Stroke Chance FMA3
stroke = 0
for x in FMA3['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA3 = ((stroke / len(FMA3) * 100))

stroke_FMA3
# Out:
# 3.0256606664113366

# %%
#Heart Attack Chance FMA3
HA = 0
for x in FMA3['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA3 = ((HA / len(FMA3) * 100))

HA_FMA3
# Out:
# 3.1405591727307542

# %%
#High Blood pressure FMA3
HBP = 0
for x in FMA3['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA3 = ((HBP / len(FMA3) * 100))

HBP_FMA3
# Out:
# 46.214732541810285

# %%
#FMA3_E1
FMA3_E1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 1)]
FMA3_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3528       2.0        1      8.0        10         2         2      3.0
# 3561       2.0        1      7.0        10         2         2      1.0
# 3595       2.0        1      8.0        11         2         1      1.0
# 3639       2.0        1      6.0        11         2         2      1.0
# 3679       2.0        1      7.0        10         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440444     2.0        1      8.0         9         2         1      3.0
# 440635     2.0        1      6.0         9         2         2      1.0
# 441088     2.0        1      7.0        10         2         2      3.0
# 441099     2.0        1      7.0        10         2         2      3.0
# 441343     2.0        1      7.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3528         1.0         1         1
# ...

# %%
#Stroke Chance FMA3_E1
stroke = 0
for x in FMA3_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA3_E1 = ((stroke / len(FMA3_E1) * 100))

stroke_FMA3_E1
# Out:
# 2.5314305130818893

# %%
#Heart Attack Chance FMA3_E1
HA = 0
for x in FMA3_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA3_E1 = ((HA / len(FMA3_E1) * 100))

HA_FMA3_E1
# Out:
# 2.7013251783893986

# %%
#High Blood pressure FMA3_E1
HBP = 0
for x in FMA3_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA3_E1 = ((HBP / len(FMA3_E1) * 100))

HBP_FMA3_E1
# Out:
# 43.5609921848454

# %%
#FMA3_E2
FMA3_E2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 2)]
FMA3_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3457       2.0        1      6.0         9         2         2      1.0
# 3478       2.0        1      7.0         9         2         2      3.0
# 3489       2.0        1      8.0         9         2         2      1.0
# 3560       2.0        1      7.0         9         2         2      3.0
# 3576       2.0        1      6.0        10         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440176     2.0        1      6.0        12         2         2      1.0
# 440356     2.0        1      6.0        11         2         2      1.0
# 440673     2.0        1      7.0        11         2         2      1.0
# 440875     2.0        1      8.0        10         2         2      1.0
# 441431     2.0        1      7.0        11         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3457         2.0         2         1
# ...

# %%
#Stroke Chance FMA3_E2
stroke = 0
for x in FMA3_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA3_E2 = ((stroke / len(FMA3_E2) * 100))

stroke_FMA3_E2
# Out:
# 5.277044854881266

# %%
#Heart Attack Chance FMA3_E2
HA = 0
for x in FMA3_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA3_E2 = ((HA / len(FMA3_E2) * 100))

HA_FMA3_E2
# Out:
# 4.749340369393139

# %%
#High Blood pressure FMA3_E2
HBP = 0
for x in FMA3_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA3_E2 = ((HBP / len(FMA3_E2) * 100))

HBP_FMA3_E2
# Out:
# 56.39841688654354

# %%
#FMA3_D1
FMA3_D1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 1)]
FMA3_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3478       2.0        1      7.0         9         2         2      3.0
# 3489       2.0        1      8.0         9         2         2      1.0
# 3528       2.0        1      8.0        10         2         2      3.0
# 3545       2.0        1      8.0        10         2         2      3.0
# 3595       2.0        1      8.0        11         2         1      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439655     2.0        1      6.0         9         2         2      3.0
# 439966     2.0        1      8.0        10         2         2      1.0
# 440176     2.0        1      6.0        12         2         2      1.0
# 440444     2.0        1      8.0         9         2         1      3.0
# 441431     2.0        1      7.0        11         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3478         2.0         1         1
# ...

# %%
#Stroke Chance FMA3_D1
stroke = 0
for x in FMA3_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA3_D1 = ((stroke / len(FMA3_D1) * 100))

stroke_FMA3_D1
# Out:
# 2.0265379975874547

# %%
#Heart Attack Chance FMA3_D1
HA = 0
for x in FMA3_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA3_D1 = ((HA / len(FMA3_D1) * 100))

HA_FMA3_D1
# Out:
# 2.4125452352231602

# %%
#High Blood pressure FMA3_D1
HBP = 0
for x in FMA3_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA3_D1 = ((HBP / len(FMA3_D1) * 100))

HBP_FMA3_D1
# Out:
# 42.87092882991556

# %%
#FMA3_D2
FMA3_D2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 2)]
FMA3_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3457       2.0        1      6.0         9         2         2      1.0
# 3560       2.0        1      7.0         9         2         2      3.0
# 3561       2.0        1      7.0        10         2         2      1.0
# 3576       2.0        1      6.0        10         2         2      3.0
# 3679       2.0        1      7.0        10         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440673     2.0        1      7.0        11         2         2      1.0
# 440875     2.0        1      8.0        10         2         2      1.0
# 441088     2.0        1      7.0        10         2         2      3.0
# 441099     2.0        1      7.0        10         2         2      3.0
# 441343     2.0        1      7.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3457         2.0         2         1
# ...

# %%
#Stroke Chance FMA3_D2
stroke = 0
for x in FMA3_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA3_D2 = ((stroke / len(FMA3_D2) * 100))

stroke_FMA3_D2
# Out:
# 4.329128440366972

# %%
#Heart Attack Chance FMA3_D2
HA = 0
for x in FMA3_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA3_D2 = ((HA / len(FMA3_D2) * 100))

HA_FMA3_D2
# Out:
# 4.013761467889909

# %%
#High Blood pressure FMA3_D2
HBP = 0
for x in FMA3_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA3_D2 = ((HBP / len(FMA3_D2) * 100))

HBP_FMA3_D2
# Out:
# 50.45871559633027

# %%
#FMA3_S1
FMA3_S1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 1)]
FMA3_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3457       2.0        1      6.0         9         2         2      1.0
# 3478       2.0        1      7.0         9         2         2      3.0
# 3489       2.0        1      8.0         9         2         2      1.0
# 3528       2.0        1      8.0        10         2         2      3.0
# 3545       2.0        1      8.0        10         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440875     2.0        1      8.0        10         2         2      1.0
# 441088     2.0        1      7.0        10         2         2      3.0
# 441099     2.0        1      7.0        10         2         2      3.0
# 441343     2.0        1      7.0         9         2         2      1.0
# 441431     2.0        1      7.0        11         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3457         2.0         2         1
# ...

# %%
#Stroke Chance FMA3_S1
stroke = 0
for x in FMA3_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA3_S1 = ((stroke / len(FMA3_S1) * 100))

stroke_FMA3_S1
# Out:
# 2.8343423225096314

# %%
#Heart Attack Chance FMA3_S1
HA = 0
for x in FMA3_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA3_S1 = ((HA / len(FMA3_S1) * 100))

HA_FMA3_S1
# Out:
# 2.958172812328013

# %%
#High Blood pressure FMA3_S1
HBP = 0
for x in FMA3_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA3_S1 = ((HBP / len(FMA3_S1) * 100))

HBP_FMA3_S1
# Out:
# 46.257567418822234

# %%
#FMA3_S2
FMA3_S2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 2)]
FMA3_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3561       2.0        1      7.0        10         2         2      1.0
# 3636       2.0        1      7.0        10         2         2      1.0
# 3732       2.0        1      6.0        10         1         2      3.0
# 3917       2.0        1      6.0        10         2         2      3.0
# 4269       2.0        1      7.0        10         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 434296     2.0        1      8.0         9         2         2      3.0
# 435962     2.0        1      8.0         9         2         2      1.0
# 438872     2.0        1      8.0        10         2         2      1.0
# 439655     2.0        1      6.0         9         2         2      3.0
# 440635     2.0        1      6.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3561         1.0         2         2
# ...

# %%
#Stroke Chance FMA3_S2
stroke = 0
for x in FMA3_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMA3_S2 = ((stroke / len(FMA3_S2) * 100))

stroke_FMA3_S2
# Out:
# 7.142857142857142

# %%
#Heart Attack Chance FMA3_S2
HA = 0
for x in FMA3_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMA3_S2 = ((HA / len(FMA3_S2) * 100))

HA_FMA3_S2
# Out:
# 6.65024630541872

# %%
#High Blood pressure FMA3_S2
HBP = 0
for x in FMA3_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMA3_S2 = ((HBP / len(FMA3_S2) * 100))

HBP_FMA3_S2
# Out:
# 47.29064039408867

# %%
#male, married, above 35000, 60+
MMA3 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))]
MMA3
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3455       1.0        1      8.0         9         2         2      3.0
# 3492       1.0        1      8.0         9         2         2      1.0
# 3517       1.0        1      8.0         9         2         2      1.0
# 3519       1.0        1      6.0         9         2         2      3.0
# 3534       1.0        1      8.0        11         1         1      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441171     1.0        1      7.0         9         2         2      1.0
# 441191     1.0        1      7.0         9         2         2      1.0
# 441255     1.0        1      8.0        10         2         2      1.0
# 441319     1.0        1      7.0        11         2         2      1.0
# 441414     1.0        1      6.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3455         2.0         1         1
# ...

# %%
stroke = 0
for x in MMA3['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA3 = ((stroke / len(MMA3) * 100))

stroke_MMA3
# Out:
# 4.178027970797784

# %%
HA = 0
for x in MMA3['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA3 = ((HA / len(MMA3) * 100))

HA_MMA3
# Out:
# 10.115225613510423

# %%
HBP = 0
for x in MMA3['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA3 = ((HBP / len(MMA3) * 100))
HBP_MMA3
# Out:
# 54.56064737443926

# %%
#MMA3_E1
MMA3_E1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 1)]
MMA3_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3573       1.0        1      8.0         9         2         2      1.0
# 3578       1.0        1      8.0         9         2         2      3.0
# 3584       1.0        1      8.0         9         2         2      3.0
# 3606       1.0        1      8.0         9         2         2      3.0
# 3626       1.0        1      7.0         9         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441104     1.0        1      6.0         9         2         2      1.0
# 441171     1.0        1      7.0         9         2         2      1.0
# 441191     1.0        1      7.0         9         2         2      1.0
# 441255     1.0        1      8.0        10         2         2      1.0
# 441414     1.0        1      6.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3573         1.0         2         1
# ...

# %%
stroke = 0
for x in MMA3_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA3_E1 = ((stroke / len(MMA3_E1) * 100))

stroke_MMA3_E1
# Out:
# 3.859690286250587

# %%
HA = 0
for x in MMA3_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA3_E1 = ((HA / len(MMA3_E1) * 100))

HA_MMA3_E1
# Out:
# 9.396996715157204

# %%
HBP = 0
for x in MMA3_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA3_E1 = ((HBP / len(MMA3_E1) * 100))
HBP_MMA3_E1
# Out:
# 53.366963866729236

# %%
#MMA3_E2
MMA3_E2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 2)]
MMA3_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3455       1.0        1      8.0         9         2         2      3.0
# 3492       1.0        1      8.0         9         2         2      1.0
# 3517       1.0        1      8.0         9         2         2      1.0
# 3519       1.0        1      6.0         9         2         2      3.0
# 3534       1.0        1      8.0        11         1         1      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440747     1.0        1      6.0         9         2         1      1.0
# 440770     1.0        1      6.0         9         2         2      1.0
# 440843     1.0        1      6.0        11         1         2      1.0
# 440973     1.0        1      6.0         9         2         2      1.0
# 441319     1.0        1      7.0        11         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3455         2.0         1         1
# ...

# %%
stroke = 0
for x in MMA3_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA3_E2 = ((stroke / len(MMA3_E2) * 100))

stroke_MMA3_E2
# Out:
# 5.525846702317291

# %%
HA = 0
for x in MMA3_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA3_E2 = ((HA / len(MMA3_E2) * 100))

HA_MMA3_E2
# Out:
# 12.745098039215685

# %%
HBP = 0
for x in MMA3_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA3_E2 = ((HBP / len(MMA3_E2) * 100))
HBP_MMA3_E2
# Out:
# 59.67023172905526

# %%
#MMA3_D1
MMA3_D1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 1)]
MMA3_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3455       1.0        1      8.0         9         2         2      3.0
# 3519       1.0        1      6.0         9         2         2      3.0
# 3534       1.0        1      8.0        11         1         1      3.0
# 3578       1.0        1      8.0         9         2         2      3.0
# 3584       1.0        1      8.0         9         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441070     1.0        1      6.0         9         2         2      3.0
# 441191     1.0        1      7.0         9         2         2      1.0
# 441255     1.0        1      8.0        10         2         2      1.0
# 441319     1.0        1      7.0        11         2         2      1.0
# 441414     1.0        1      6.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3455         2.0         1         1
# ...

# %%
stroke = 0
for x in MMA3_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA3_D1 = ((stroke / len(MMA3_D1) * 100))

stroke_MMA3_D1
# Out:
# 3.3871432689535887

# %%
HA = 0
for x in MMA3_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA3_D1 = ((HA / len(MMA3_D1) * 100))

HA_MMA3_D1
# Out:
# 8.460651484577689

# %%
HBP = 0
for x in MMA3_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA3_D1 = ((HBP / len(MMA3_D1) * 100))
HBP_MMA3_D1
# Out:
# 53.64658402997981

# %%
#MMA3_D2
MMA3_D2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 2)]
MMA3_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3492       1.0        1      8.0         9         2         2      1.0
# 3517       1.0        1      8.0         9         2         2      1.0
# 3573       1.0        1      8.0         9         2         2      1.0
# 3600       1.0        1      6.0        10         1         2      1.0
# 3626       1.0        1      7.0         9         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440411     1.0        1      8.0        10         2         2      1.0
# 440540     1.0        1      7.0        10         1         2      1.0
# 440597     1.0        1      7.0        10         2         2      3.0
# 441104     1.0        1      6.0         9         2         2      1.0
# 441171     1.0        1      7.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3492         2.0         2         1
# ...

# %%
stroke = 0
for x in MMA3_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA3_D2 = ((stroke / len(MMA3_D2) * 100))

stroke_MMA3_D2
# Out:
# 5.630739487675205

# %%
HA = 0
for x in MMA3_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA3_D2 = ((HA / len(MMA3_D2) * 100))

HA_MMA3_D2
# Out:
# 12.977283711938133

# %%
HBP = 0
for x in MMA3_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA3_D2 = ((HBP / len(MMA3_D2) * 100))
HBP_MMA3_D2
# Out:
# 56.42822619623006

# %%
#MMA3_S1
MMA3_S1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 1)]
MMA3_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3455       1.0        1      8.0         9         2         2      3.0
# 3492       1.0        1      8.0         9         2         2      1.0
# 3517       1.0        1      8.0         9         2         2      1.0
# 3573       1.0        1      8.0         9         2         2      1.0
# 3578       1.0        1      8.0         9         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441171     1.0        1      7.0         9         2         2      1.0
# 441191     1.0        1      7.0         9         2         2      1.0
# 441255     1.0        1      8.0        10         2         2      1.0
# 441319     1.0        1      7.0        11         2         2      1.0
# 441414     1.0        1      6.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3455         2.0         1         1
# ...

# %%
stroke = 0
for x in MMA3_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA3_S1 = ((stroke / len(MMA3_S1) * 100))

stroke_MMA3_S1
# Out:
# 4.184424641611778

# %%
HA = 0
for x in MMA3_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA3_S1 = ((HA / len(MMA3_S1) * 100))

HA_MMA3_S1
# Out:
# 9.821774506005426

# %%
HBP = 0
for x in MMA3_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA3_S1 = ((HBP / len(MMA3_S1) * 100))
HBP_MMA3_S1
# Out:
# 54.73653622626888

# %%
#MMA3_S2
MMA3_S2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 6) | (rdf['INCOME2'] == 7) | (rdf['INCOME2'] == 8)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 2)]
MMA3_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3519       1.0        1      6.0         9         2         2      3.0
# 3534       1.0        1      8.0        11         1         1      3.0
# 3749       1.0        1      7.0         9         2         2      1.0
# 3904       1.0        1      6.0         9         2         2      3.0
# 3960       1.0        1      8.0         9         2         1      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 434087     1.0        1      8.0        10         2         2      3.0
# 434283     1.0        1      6.0        11         2         1      1.0
# 435732     1.0        1      6.0        10         2         2      3.0
# 435737     1.0        1      6.0         9         2         2      3.0
# 440770     1.0        1      6.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3519         2.0         1         2
# ...

# %%
stroke = 0
for x in MMA3_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMA3_S2 = ((stroke / len(MMA3_S2) * 100))

stroke_MMA3_S2
# Out:
# 4.182041820418204

# %%
HA = 0
for x in MMA3_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMA3_S2 = ((HA / len(MMA3_S2) * 100))

HA_MMA3_S2
# Out:
# 14.268142681426815

# %%
HBP = 0
for x in MMA3_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMA3_S2 = ((HBP / len(MMA3_S2) * 100))
HBP_MMA3_S2
# Out:
# 53.25953259532595

# %%
#female, single, below 35000, 60+
FSB3 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))]
FSB3
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3462       2.0        4      1.0         9         7         2      1.0
# 3466       2.0        3      3.0        13         2         2      3.0
# 3484       2.0        3      1.0        11         1         1      1.0
# 3525       2.0        2      2.0         9         2         2      3.0
# 3530       2.0        3      5.0         9         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441358     2.0        5      1.0         9         2         2      1.0
# 441373     2.0        5      4.0         9         2         2      1.0
# 441388     2.0        2      4.0        12         2         2      3.0
# 441400     2.0        3      1.0         9         2         2      1.0
# 441451     2.0        3      4.0        11         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3462         2.0         2         1
# ...

# %%
#Stroke Chance FSB3
stroke = 0
for x in FSB3['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB3 = ((stroke / len(FSB3) * 100))

stroke_FSB3
# Out:
# 8.910235177210996

# %%
#Heart Attack Chance FSB3
HA = 0
for x in FSB3['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB3 = ((HA / len(FSB3) * 100))

HA_FSB3
# Out:
# 10.384233189797946

# %%
#High Blood pressure FSB3
HBP = 0
for x in FSB3['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB3 = ((HBP / len(FSB3) * 100))

HBP_FSB3
# Out:
# 62.437893342166284

# %%
#FSB3_E1
FSB3_E1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 1)]
FSB3_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3525       2.0        2      2.0         9         2         2      3.0
# 3535       2.0        2      5.0        10         2         2      1.0
# 3569       2.0        3      3.0        11         2         2      1.0
# 3650       2.0        5      5.0         9         2         2      3.0
# 3662       2.0        3      3.0        13         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441062     2.0        3      1.0        13         2         2      1.0
# 441121     2.0        2      4.0        11         2         2      1.0
# 441181     2.0        2      3.0         9         2         2      1.0
# 441219     2.0        2      4.0         9         2         2      3.0
# 441293     2.0        3      1.0        11         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3525         1.0         1         1
# ...

# %%
#Stroke Chance FSB3_E1
stroke = 0
for x in FSB3_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB3_E1 = ((stroke / len(FSB3_E1) * 100))

stroke_FSB3_E1
# Out:
# 7.815126050420168

# %%
#Heart Attack Chance FSB3_E1
HA = 0
for x in FSB3_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB3_E1 = ((HA / len(FSB3_E1) * 100))

HA_FSB3_E1
# Out:
# 9.27170868347339

# %%
#High Blood pressure FSB3_E1
HBP = 0
for x in FSB3_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB3_E1 = ((HBP / len(FSB3_E1) * 100))

HBP_FSB3_E1
# Out:
# 59.27170868347339

# %%
#FSB3_E2
FSB3_E2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 2)]
FSB3_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3462       2.0        4      1.0         9         7         2      1.0
# 3466       2.0        3      3.0        13         2         2      3.0
# 3484       2.0        3      1.0        11         1         1      1.0
# 3530       2.0        3      5.0         9         2         2      1.0
# 3671       2.0        5      3.0         9         2         1      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441358     2.0        5      1.0         9         2         2      1.0
# 441373     2.0        5      4.0         9         2         2      1.0
# 441388     2.0        2      4.0        12         2         2      3.0
# 441400     2.0        3      1.0         9         2         2      1.0
# 441451     2.0        3      4.0        11         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3462         2.0         2         1
# ...

# %%
#Stroke Chance FSB3_E2
stroke = 0
for x in FSB3_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB3_E2 = ((stroke / len(FSB3_E2) * 100))

stroke_FSB3_E2
# Out:
# 10.592808551992224

# %%
#Heart Attack Chance FSB3_E2
HA = 0
for x in FSB3_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB3_E2 = ((HA / len(FSB3_E2) * 100))

HA_FSB3_E2
# Out:
# 12.293488824101068

# %%
#High Blood pressure FSB3_E2
HBP = 0
for x in FSB3_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB3_E2 = ((HBP / len(FSB3_E2) * 100))

HBP_FSB3_E2
# Out:
# 68.27016520894071

# %%
#FSB3_D1
FSB3_D1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 1)]
FSB3_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3525       2.0        2      2.0         9         2         2      3.0
# 3530       2.0        3      5.0         9         2         2      1.0
# 3650       2.0        5      5.0         9         2         2      3.0
# 3751       2.0        3      5.0        11         2         2      1.0
# 3770       2.0        3      3.0        10         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441121     2.0        2      4.0        11         2         2      1.0
# 441181     2.0        2      3.0         9         2         2      1.0
# 441230     2.0        3      3.0         9         2         2      3.0
# 441239     2.0        3      4.0        10         2         2      3.0
# 441358     2.0        5      1.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3525         1.0         1         1
# ...

# %%
#Stroke Chance FSB3_D1
stroke = 0
for x in FSB3_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB3_D1 = ((stroke / len(FSB3_D1) * 100))

stroke_FSB3_D1
# Out:
# 6.015485407980941

# %%
#Heart Attack Chance FSB3_D1
HA = 0
for x in FSB3_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB3_D1 = ((HA / len(FSB3_D1) * 100))

HA_FSB3_D1
# Out:
# 6.611078022632519

# %%
#High Blood pressure FSB3_D1
HBP = 0
for x in FSB3_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB3_D1 = ((HBP / len(FSB3_D1) * 100))

HBP_FSB3_D1
# Out:
# 55.62835020845741

# %%
#FSB3_D2
FSB3_D2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 2)]
FSB3_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3462       2.0        4      1.0         9         7         2      1.0
# 3466       2.0        3      3.0        13         2         2      3.0
# 3484       2.0        3      1.0        11         1         1      1.0
# 3535       2.0        2      5.0        10         2         2      1.0
# 3552       2.0        3      2.0        13         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441355     2.0        3      1.0         9         2         2      1.0
# 441373     2.0        5      4.0         9         2         2      1.0
# 441388     2.0        2      4.0        12         2         2      3.0
# 441400     2.0        3      1.0         9         2         2      1.0
# 441451     2.0        3      4.0        11         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3462         2.0         2         1
# ...

# %%
#Stroke Chance FSB3_D2
stroke = 0
for x in FSB3_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB3_D2 = ((stroke / len(FSB3_D2) * 100))

stroke_FSB3_D2
# Out:
# 10.019175455417066

# %%
#Heart Attack Chance FSB3_D2
HA = 0
for x in FSB3_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB3_D2 = ((HA / len(FSB3_D2) * 100))

HA_FSB3_D2
# Out:
# 11.960690316395015

# %%
#High Blood pressure FSB3_D2
HBP = 0
for x in FSB3_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB3_D2 = ((HBP / len(FSB3_D2) * 100))

HBP_FSB3_D2
# Out:
# 65.22051773729626

# %%
#FSB3_S1
FSB3_S1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 1)]
FSB3_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3462       2.0        4      1.0         9         7         2      1.0
# 3466       2.0        3      3.0        13         2         2      3.0
# 3484       2.0        3      1.0        11         1         1      1.0
# 3525       2.0        2      2.0         9         2         2      3.0
# 3530       2.0        3      5.0         9         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441358     2.0        5      1.0         9         2         2      1.0
# 441373     2.0        5      4.0         9         2         2      1.0
# 441388     2.0        2      4.0        12         2         2      3.0
# 441400     2.0        3      1.0         9         2         2      1.0
# 441451     2.0        3      4.0        11         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3462         2.0         2         1
# ...

# %%
#Stroke Chance FSB3_S1
stroke = 0
for x in FSB3_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB3_S1 = ((stroke / len(FSB3_S1) * 100))

stroke_FSB3_S1
# Out:
# 8.727719729563614

# %%
#Heart Attack Chance FSB3_S1
HA = 0
for x in FSB3_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB3_S1 = ((HA / len(FSB3_S1) * 100))

HA_FSB3_S1
# Out:
# 10.038926449498053

# %%
#High Blood pressure FSB3_S1
HBP = 0
for x in FSB3_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB3_S1 = ((HBP / len(FSB3_S1) * 100))

HBP_FSB3_S1
# Out:
# 63.49108789182545

# %%
#FSB3_S2
FSB3_S2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 2)]
FSB3_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3902       2.0        2      3.0        11         2         2      1.0
# 3906       2.0        3      3.0         9         2         2      1.0
# 3996       2.0        4      4.0        10         2         1      1.0
# 4187       2.0        2      1.0         9         2         2      1.0
# 4334       2.0        4      2.0        10         1         1      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440634     2.0        2      1.0         9         2         2      3.0
# 440827     2.0        2      2.0        10         2         2      3.0
# 440828     2.0        3      1.0        10         2         2      3.0
# 440853     2.0        3      2.0         9         2         2      3.0
# 441323     2.0        4      3.0        10         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3902         1.0         1         2
# ...

# %%
#Stroke Chance FSB3_S2
stroke = 0
for x in FSB3_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FSB3_S2 = ((stroke / len(FSB3_S2) * 100))

stroke_FSB3_S2
# Out:
# 9.667673716012084

# %%
#Heart Attack Chance FSB3_S2
HA = 0
for x in FSB3_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FSB3_S2 = ((HA / len(FSB3_S2) * 100))

HA_FSB3_S2
# Out:
# 12.28600201409869

# %%
#High Blood pressure FSB3_S2
HBP = 0
for x in FSB3_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FSB3_S2 = ((HBP / len(FSB3_S2) * 100))

HBP_FSB3_S2
# Out:
# 58.006042296072515

# %%
#male, single, below 35000, 60+
MSB3 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))]
MSB3
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3459       1.0        3      3.0        12         1         2      1.0
# 3465       1.0        2      3.0        11         2         2      1.0
# 3469       1.0        2      5.0        10         2         2      1.0
# 3496       1.0        2      5.0         9         2         2      1.0
# 3518       1.0        5      3.0         9         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441346     1.0        2      1.0        10         2         2      1.0
# 441365     1.0        6      5.0         9         2         2      1.0
# 441387     1.0        3      4.0        11         2         2      3.0
# 441407     1.0        2      3.0        11         2         2      3.0
# 441440     1.0        6      1.0         9         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3459         1.0         2         1
# ...

# %%
stroke = 0
for x in MSB3['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB3 = ((stroke / len(MSB3) * 100))

stroke_MSB3
# Out:
# 11.293886570095752

# %%
HA = 0
for x in MSB3['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB3 = ((HA / len(MSB3) * 100))

HA_MSB3
# Out:
# 18.65946476798429

# %%
HBP = 0
for x in MSB3['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB3 = ((HBP / len(MSB3) * 100))
HBP_MSB3
# Out:
# 62.41099926344218

# %%
#MSB3_E1
MSB3_E1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 1)]
MSB3_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3459       1.0        3      3.0        12         1         2      1.0
# 3496       1.0        2      5.0         9         2         2      1.0
# 3518       1.0        5      3.0         9         2         2      3.0
# 3663       1.0        2      3.0         9         2         2      1.0
# 3709       1.0        3      1.0        11         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441311     1.0        4      4.0         9         2         2      3.0
# 441336     1.0        4      2.0         9         2         2      3.0
# 441346     1.0        2      1.0        10         2         2      1.0
# 441365     1.0        6      5.0         9         2         2      1.0
# 441407     1.0        2      3.0        11         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3459         1.0         2         1
# ...

# %%
stroke = 0
for x in MSB3_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB3_E1 = ((stroke / len(MSB3_E1) * 100))

stroke_MSB3_E1
# Out:
# 11.097204839382561

# %%
HA = 0
for x in MSB3_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB3_E1 = ((HA / len(MSB3_E1) * 100))

HA_MSB3_E1
# Out:
# 16.312056737588655

# %%
HBP = 0
for x in MSB3_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB3_E1 = ((HBP / len(MSB3_E1) * 100))
HBP_MSB3_E1
# Out:
# 61.45181476846058

# %%
#MSB3_E2
MSB3_E2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 2)]
MSB3_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3465       1.0        2      3.0        11         2         2      1.0
# 3469       1.0        2      5.0        10         2         2      1.0
# 3526       1.0        2      5.0         9         2         2      3.0
# 3691       1.0        3      3.0        11         2         1      1.0
# 3811       1.0        2      2.0        12         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441005     1.0        6      1.0        12         2         2      1.0
# 441124     1.0        3      3.0        11         2         1      3.0
# 441220     1.0        4      2.0        11         2         2      1.0
# 441345     1.0        4      1.0         9         1         2      1.0
# 441440     1.0        6      1.0         9         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3465         2.0         2         1
# ...

# %%
stroke = 0
for x in MSB3_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB3_E2 = ((stroke / len(MSB3_E2) * 100))

stroke_MSB3_E2
# Out:
# 11.009174311926607

# %%
HA = 0
for x in MSB3_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB3_E2 = ((HA / len(MSB3_E2) * 100))

HA_MSB3_E2
# Out:
# 22.553516819571865

# %%
HBP = 0
for x in MSB3_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB3_E2 = ((HBP / len(MSB3_E2) * 100))
HBP_MSB3_E2
# Out:
# 64.90825688073394

# %%
#MSB3_D1
MSB3_D1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 1)]
MSB3_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3518       1.0        5      3.0         9         2         2      3.0
# 3526       1.0        2      5.0         9         2         2      3.0
# 3663       1.0        2      3.0         9         2         2      1.0
# 3691       1.0        3      3.0        11         2         1      1.0
# 3831       1.0        3      2.0        13         2         1      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441220     1.0        4      2.0        11         2         2      1.0
# 441268     1.0        2      3.0         9         2         2      1.0
# 441311     1.0        4      4.0         9         2         2      3.0
# 441336     1.0        4      2.0         9         2         2      3.0
# 441440     1.0        6      1.0         9         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3518         1.0         1         2
# ...

# %%
stroke = 0
for x in MSB3_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB3_D1 = ((stroke / len(MSB3_D1) * 100))

stroke_MSB3_D1
# Out:
# 8.753799392097264

# %%
HA = 0
for x in MSB3_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB3_D1 = ((HA / len(MSB3_D1) * 100))

HA_MSB3_D1
# Out:
# 15.379939209726443

# %%
HBP = 0
for x in MSB3_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB3_D1 = ((HBP / len(MSB3_D1) * 100))
HBP_MSB3_D1
# Out:
# 62.61398176291794

# %%
#MSB3_D2
MSB3_D2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 2)]
MSB3_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3459       1.0        3      3.0        12         1         2      1.0
# 3465       1.0        2      3.0        11         2         2      1.0
# 3469       1.0        2      5.0        10         2         2      1.0
# 3496       1.0        2      5.0         9         2         2      1.0
# 3709       1.0        3      1.0        11         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441241     1.0        3      1.0        12         2         2      3.0
# 441345     1.0        4      1.0         9         1         2      1.0
# 441346     1.0        2      1.0        10         2         2      1.0
# 441365     1.0        6      5.0         9         2         2      1.0
# 441407     1.0        2      3.0        11         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3459         1.0         2         1
# ...

# %%
stroke = 0
for x in MSB3_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB3_D2 = ((stroke / len(MSB3_D2) * 100))

stroke_MSB3_D2
# Out:
# 13.035714285714286

# %%
HA = 0
for x in MSB3_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB3_D2 = ((HA / len(MSB3_D2) * 100))

HA_MSB3_D2
# Out:
# 21.160714285714285

# %%
HBP = 0
for x in MSB3_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB3_D2 = ((HBP / len(MSB3_D2) * 100))
HBP_MSB3_D2
# Out:
# 62.54464285714286

# %%
#MSB3_S1
MSB3_S1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 1)]
MSB3_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3459       1.0        3      3.0        12         1         2      1.0
# 3465       1.0        2      3.0        11         2         2      1.0
# 3496       1.0        2      5.0         9         2         2      1.0
# 3526       1.0        2      5.0         9         2         2      3.0
# 3663       1.0        2      3.0         9         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441336     1.0        4      2.0         9         2         2      3.0
# 441345     1.0        4      1.0         9         1         2      1.0
# 441346     1.0        2      1.0        10         2         2      1.0
# 441365     1.0        6      5.0         9         2         2      1.0
# 441407     1.0        2      3.0        11         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3459         1.0         2         1
# ...

# %%
stroke = 0
for x in MSB3_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB3_S1 = ((stroke / len(MSB3_S1) * 100))

stroke_MSB3_S1
# Out:
# 10.315284441398218

# %%
HA = 0
for x in MSB3_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB3_S1 = ((HA / len(MSB3_S1) * 100))

HA_MSB3_S1
# Out:
# 17.751884852638796

# %%
HBP = 0
for x in MSB3_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB3_S1 = ((HBP / len(MSB3_S1) * 100))
HBP_MSB3_S1
# Out:
# 62.78272789581906

# %%
#MSB3_S2
MSB3_S2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 2) | (rdf['MARITAL'] == 3) | (rdf['MARITAL'] == 4) | (rdf['MARITAL'] == 5) | (rdf['MARITAL'] == 6)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 2)]
MSB3_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3469       1.0        2      5.0        10         2         2      1.0
# 3518       1.0        5      3.0         9         2         2      3.0
# 3847       1.0        3      5.0         9         2         2      3.0
# 3854       1.0        2      2.0         9         2         2      1.0
# 3927       1.0        2      2.0        10         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439611     1.0        5      3.0         9         2         2      3.0
# 440308     1.0        6      1.0         9         2         2      3.0
# 440553     1.0        2      3.0        10         2         2      1.0
# 441220     1.0        4      2.0        11         2         2      1.0
# 441440     1.0        6      1.0         9         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3469         2.0         2         2
# ...

# %%
stroke = 0
for x in MSB3_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MSB3_S2 = ((stroke / len(MSB3_S2) * 100))

stroke_MSB3_S2
# Out:
# 14.175506268081003

# %%
HA = 0
for x in MSB3_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MSB3_S2 = ((HA / len(MSB3_S2) * 100))

HA_MSB3_S2
# Out:
# 21.793635486981678

# %%
HBP = 0
for x in MSB3_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MSB3_S2 = ((HBP / len(MSB3_S2) * 100))
HBP_MSB3_S2
# Out:
# 61.620057859209254

# %%
#female, married, below 35000, 60+
FMB3 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))]
FMB3
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3498       2.0        1      1.0        11         2         2      1.0
# 3562       2.0        1      2.0        10         2         2      1.0
# 3594       2.0        1      3.0        10         2         2      1.0
# 3596       2.0        1      4.0        11         2         2      1.0
# 3609       2.0        1      3.0        10         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441337     2.0        1      1.0        10         2         2      1.0
# 441360     2.0        1      3.0        10         2         2      1.0
# 441436     2.0        1      4.0        13         2         1      1.0
# 441453     2.0        1      5.0        11         2         2      1.0
# 441455     2.0        1      2.0         9         2         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3498         NaN         9         9
# ...

# %%
#Stroke Chance FMB3
stroke = 0
for x in FMB3['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB3 = ((stroke / len(FMB3) * 100))

stroke_FMB3
# Out:
# 6.823266219239374

# %%
#Heart Attack Chance FMB3
HA = 0
for x in FMB3['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB3 = ((HA / len(FMB3) * 100))

HA_FMB3
# Out:
# 9.13497390007457

# %%
#High Blood pressure FMB3
HBP = 0
for x in FMB3['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB3 = ((HBP / len(FMB3) * 100))

HBP_FMB3
# Out:
# 59.023117076808354

# %%
#FMB3_E1
FMB3_E1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 1)]
FMB3_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3594       2.0        1      3.0        10         2         2      1.0
# 3640       2.0        1      4.0        10         2         2      3.0
# 3835       2.0        1      4.0        11         1         2      3.0
# 3940       2.0        1      3.0         9         2         2      3.0
# 3970       2.0        1      3.0        10         2         1      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441199     2.0        1      2.0         9         2         2      1.0
# 441229     2.0        1      2.0        11         2         2      1.0
# 441265     2.0        1      2.0        11         2         2      1.0
# 441333     2.0        1      2.0        11         2         2      1.0
# 441455     2.0        1      2.0         9         2         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3594         1.0         2         1
# ...

# %%
#Stroke Chance FMB3_E1
stroke = 0
for x in FMB3_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB3_E1 = ((stroke / len(FMB3_E1) * 100))

stroke_FMB3_E1
# Out:
# 5.625

# %%
#Heart Attack Chance FMB3_E1
HA = 0
for x in FMB3_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB3_E1 = ((HA / len(FMB3_E1) * 100))

HA_FMB3_E1
# Out:
# 8.125

# %%
#High Blood pressure FMB3_E1
HBP = 0
for x in FMB3_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB3_E1 = ((HBP / len(FMB3_E1) * 100))

HBP_FMB3_E1
# Out:
# 54.50000000000001

# %%
#FMB3_E2
FMB3_E2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 2)]
FMB3_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3562       2.0        1      2.0        10         2         2      1.0
# 3596       2.0        1      4.0        11         2         2      1.0
# 3609       2.0        1      3.0        10         2         2      1.0
# 3687       2.0        1      3.0        10         2         2      1.0
# 3797       2.0        1      4.0        13         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441202     2.0        1      1.0        11         2         2      3.0
# 441271     2.0        1      3.0        11         2         2      3.0
# 441337     2.0        1      1.0        10         2         2      1.0
# 441360     2.0        1      3.0        10         2         2      1.0
# 441436     2.0        1      4.0        13         2         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3562         2.0         2         1
# ...

# %%
#Stroke Chance FMB3_E2
stroke = 0
for x in FMB3_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB3_E2 = ((stroke / len(FMB3_E2) * 100))

stroke_FMB3_E2
# Out:
# 8.771929824561402

# %%
#Heart Attack Chance FMB3_E2
HA = 0
for x in FMB3_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB3_E2 = ((HA / len(FMB3_E2) * 100))

HA_FMB3_E2
# Out:
# 10.760233918128655

# %%
#High Blood pressure FMB3_E2
HBP = 0
for x in FMB3_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB3_E2 = ((HBP / len(FMB3_E2) * 100))

HBP_FMB3_E2
# Out:
# 66.78362573099416

# %%
#FMB3_D1
FMB3_D1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 1)]
FMB3_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 4048       2.0        1      1.0         9         2         2      3.0
# 4292       2.0        1      5.0        11         2         2      1.0
# 4369       2.0        1      5.0        11         2         2      3.0
# 4685       2.0        1      4.0         9         2         2      1.0
# 4801       2.0        1      4.0         9         1         1      2.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 439142     2.0        1      4.0         9         2         2      1.0
# 439688     2.0        1      1.0        10         2         2      1.0
# 440405     2.0        1      5.0         9         2         2      3.0
# 441027     2.0        1      1.0        11         2         2      1.0
# 441453     2.0        1      5.0        11         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 4048         1.0         1         1
# ...

# %%
#Stroke Chance FMB3_D1
stroke = 0
for x in FMB3_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB3_D1 = ((stroke / len(FMB3_D1) * 100))

stroke_FMB3_D1
# Out:
# 4.497751124437781

# %%
#Heart Attack Chance FMB3_D1
HA = 0
for x in FMB3_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB3_D1 = ((HA / len(FMB3_D1) * 100))

HA_FMB3_D1
# Out:
# 7.04647676161919

# %%
#High Blood pressure FMB3_D1
HBP = 0
for x in FMB3_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB3_D1 = ((HBP / len(FMB3_D1) * 100))

HBP_FMB3_D1
# Out:
# 49.32533733133433

# %%
#FMB3_D2
FMB3_D2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 2)]
FMB3_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3562       2.0        1      2.0        10         2         2      1.0
# 3594       2.0        1      3.0        10         2         2      1.0
# 3596       2.0        1      4.0        11         2         2      1.0
# 3609       2.0        1      3.0        10         2         2      1.0
# 3640       2.0        1      4.0        10         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441333     2.0        1      2.0        11         2         2      1.0
# 441337     2.0        1      1.0        10         2         2      1.0
# 441360     2.0        1      3.0        10         2         2      1.0
# 441436     2.0        1      4.0        13         2         1      1.0
# 441455     2.0        1      2.0         9         2         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3562         2.0         2         1
# ...

# %%
#Stroke Chance FMB3_D2
stroke = 0
for x in FMB3_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB3_D2 = ((stroke / len(FMB3_D2) * 100))

stroke_FMB3_D2
# Out:
# 7.647983237297014

# %%
#Heart Attack Chance FMB3_D2
HA = 0
for x in FMB3_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB3_D2 = ((HA / len(FMB3_D2) * 100))

HA_FMB3_D2
# Out:
# 10.00523834468308

# %%
#High Blood pressure FMB3_D2
HBP = 0
for x in FMB3_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB3_D2 = ((HBP / len(FMB3_D2) * 100))

HBP_FMB3_D2
# Out:
# 62.28391828182295

# %%
#FMB3_S1
FMB3_S1 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 1)]
FMB3_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3562       2.0        1      2.0        10         2         2      1.0
# 3594       2.0        1      3.0        10         2         2      1.0
# 3596       2.0        1      4.0        11         2         2      1.0
# 3609       2.0        1      3.0        10         2         2      1.0
# 3640       2.0        1      4.0        10         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441337     2.0        1      1.0        10         2         2      1.0
# 441360     2.0        1      3.0        10         2         2      1.0
# 441436     2.0        1      4.0        13         2         1      1.0
# 441453     2.0        1      5.0        11         2         2      1.0
# 441455     2.0        1      2.0         9         2         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3562         2.0         2         1
# ...

# %%
#Stroke Chance FMB3_S1
stroke = 0
for x in FMB3_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB3_S1 = ((stroke / len(FMB3_S1) * 100))

stroke_FMB3_S1
# Out:
# 6.120689655172414

# %%
#Heart Attack Chance FMB3_S1
HA = 0
for x in FMB3_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB3_S1 = ((HA / len(FMB3_S1) * 100))

HA_FMB3_S1
# Out:
# 8.663793103448276

# %%
#High Blood pressure FMB3_S1
HBP = 0
for x in FMB3_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB3_S1 = ((HBP / len(FMB3_S1) * 100))

HBP_FMB3_S1
# Out:
# 58.4051724137931

# %%
#FMB3_S2
FMB3_S2 = rdf[(rdf['CADULT'] == 2) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 2)]
FMB3_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3804       2.0        1      5.0        10         2         1      3.0
# 4408       2.0        1      5.0         9         2         2      1.0
# 4685       2.0        1      4.0         9         2         2      1.0
# 4851       2.0        1      4.0        10         2         2      1.0
# 5074       2.0        1      3.0         9         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 433450     2.0        1      4.0        11         2         2      1.0
# 434096     2.0        1      5.0        10         2         2      1.0
# 434305     2.0        1      2.0         9         2         2      1.0
# 438697     2.0        1      4.0         9         2         2      1.0
# 438842     2.0        1      5.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3804         9.0         2         2
# ...

# %%
#Stroke Chance FMB3_S2
stroke = 0
for x in FMB3_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_FMB3_S2 = ((stroke / len(FMB3_S2) * 100))

stroke_FMB3_S2
# Out:
# 12.363636363636363

# %%
#Heart Attack Chance FMB3_S2
HA = 0
for x in FMB3_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1

HA_FMB3_S2 = ((HA / len(FMB3_S2) * 100))

HA_FMB3_S2
# Out:
# 13.454545454545455

# %%
#High Blood pressure FMB3_S2
HBP = 0
for x in FMB3_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1

HBP_FMB3_S2 = ((HBP / len(FMB3_S2) * 100))

HBP_FMB3_S2
# Out:
# 61.81818181818181

# %%
#male, married, below 35000, 60+
MMB3 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))]
MMB3
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3464       1.0        1      3.0        10         2         1      1.0
# 3577       1.0        1      4.0        11         2         1      1.0
# 3619       1.0        1      5.0        13         2         2      1.0
# 3627       1.0        1      4.0        11         2         2      3.0
# 3796       1.0        1      4.0        11         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441399     1.0        1      2.0        13         2         2      3.0
# 441408     1.0        1      3.0        10         2         2      3.0
# 441409     1.0        1      4.0        11         2         2      3.0
# 441441     1.0        1      3.0         9         2         2      1.0
# 441446     1.0        1      1.0        12         2         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3464         2.0         1         1
# ...

# %%
stroke = 0
for x in MMB3['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB3 = ((stroke / len(MMB3) * 100))

stroke_MMB3
# Out:
# 9.689677010766308

# %%
HA = 0
for x in MMB3['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB3 = ((HA / len(MMB3) * 100))

HA_MMB3
# Out:
# C:\Users\zacha\anaconda3\lib\site-packages\IPython\core\displayhook.py:275: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
# 17.00443318556048

# %%
HBP = 0
for x in MMB3['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB3 = ((HBP / len(MMB3) * 100))
HBP_MMB3
# Out:
# 61.526282457251426

# %%
#MMB3_E1
MMB3_E1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 1)]
MMB3_E1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3619       1.0        1      5.0        13         2         2      1.0
# 3627       1.0        1      4.0        11         2         2      3.0
# 4191       1.0        1      4.0        11         2         2      3.0
# 4258       1.0        1      3.0        11         2         2      1.0
# 4337       1.0        1      1.0        11         2         2      1.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441320     1.0        1      2.0        11         2         2      1.0
# 441368     1.0        1      3.0         9         2         1      3.0
# 441382     1.0        1      3.0         9         2         2      1.0
# 441409     1.0        1      4.0        11         2         2      3.0
# 441446     1.0        1      1.0        12         2         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3619         1.0         2         1
# ...

# %%
stroke = 0
for x in MMB3_E1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB3_E1 = ((stroke / len(MMB3_E1) * 100))

stroke_MMB3_E1
# Out:
# 8.975039830058417

# %%
HA = 0
for x in MMB3_E1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB3_E1 = ((HA / len(MMB3_E1) * 100))

HA_MMB3_E1
# Out:
# 15.454062665958576

# %%
HBP = 0
for x in MMB3_E1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB3_E1 = ((HBP / len(MMB3_E1) * 100))
HBP_MMB3_E1
# Out:
# 60.38236856080722

# %%
#MMB3_E2
MMB3_E2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['EXERANY2'] == 2)]
MMB3_E2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3464       1.0        1      3.0        10         2         1      1.0
# 3577       1.0        1      4.0        11         2         1      1.0
# 3796       1.0        1      4.0        11         2         2      3.0
# 3866       1.0        1      5.0         9         2         2      3.0
# 3871       1.0        1      3.0        11         1         1      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441299     1.0        1      2.0         9         2         2      1.0
# 441313     1.0        1      3.0        12         2         2      1.0
# 441399     1.0        1      2.0        13         2         2      3.0
# 441408     1.0        1      3.0        10         2         2      3.0
# 441441     1.0        1      3.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3464         2.0         1         1
# ...

# %%
stroke = 0
for x in MMB3_E2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB3_E2 = ((stroke / len(MMB3_E2) * 100))

stroke_MMB3_E2
# Out:
# 11.190233977619531

# %%
HA = 0
for x in MMB3_E2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB3_E2 = ((HA / len(MMB3_E2) * 100))

HA_MMB3_E2
# Out:
# 20.345879959308242

# %%
HBP = 0
for x in MMB3_E2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB3_E2 = ((HBP / len(MMB3_E2) * 100))
HBP_MMB3_E2
# Out:
# 64.1912512716175

# %%
#MMB3_D1
MMB3_D1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 1)]
MMB3_D1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3464       1.0        1      3.0        10         2         1      1.0
# 3871       1.0        1      3.0        11         1         1      3.0
# 4394       1.0        1      4.0         9         2         2      1.0
# 4432       1.0        1      4.0         9         2         2      3.0
# 4542       1.0        1      4.0         9         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441002     1.0        1      5.0         9         2         2      1.0
# 441008     1.0        1      4.0        11         2         2      3.0
# 441078     1.0        1      4.0        10         2         2      1.0
# 441093     1.0        1      2.0         9         2         2      1.0
# 441178     1.0        1      5.0         9         2         2      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3464         2.0         1         1
# ...

# %%
stroke = 0
for x in MMB3_D1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB3_D1 = ((stroke / len(MMB3_D1) * 100))

stroke_MMB3_D1
# Out:
# 8.710503842869342

# %%
HA = 0
for x in MMB3_D1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB3_D1 = ((HA / len(MMB3_D1) * 100))

HA_MMB3_D1
# Out:
# 15.627668659265584

# %%
HBP = 0
for x in MMB3_D1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB3_D1 = ((HBP / len(MMB3_D1) * 100))
HBP_MMB3_D1
# Out:
# 59.86336464560205

# %%
#MMB3_D2
MMB3_D2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['DRNKANY5'] == 2)]
MMB3_D2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3577       1.0        1      4.0        11         2         1      1.0
# 3619       1.0        1      5.0        13         2         2      1.0
# 3627       1.0        1      4.0        11         2         2      3.0
# 3796       1.0        1      4.0        11         2         2      3.0
# 3866       1.0        1      5.0         9         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441399     1.0        1      2.0        13         2         2      3.0
# 441408     1.0        1      3.0        10         2         2      3.0
# 441409     1.0        1      4.0        11         2         2      3.0
# 441441     1.0        1      3.0         9         2         2      1.0
# 441446     1.0        1      1.0        12         2         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3577         2.0         2         1
# ...

# %%
stroke = 0
for x in MMB3_D2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB3_D2 = ((stroke / len(MMB3_D2) * 100))

stroke_MMB3_D2
# Out:
# 10.55495103373232

# %%
HA = 0
for x in MMB3_D2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB3_D2 = ((HA / len(MMB3_D2) * 100))

HA_MMB3_D2
# Out:
# 18.389553862894452

# %%
HBP = 0
for x in MMB3_D2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB3_D2 = ((HBP / len(MMB3_D2) * 100))
HBP_MMB3_D2
# Out:
# 63.16648531011969

# %%
#MMB3_S1
MMB3_S1 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 1)]
MMB3_S1
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3464       1.0        1      3.0        10         2         1      1.0
# 3577       1.0        1      4.0        11         2         1      1.0
# 3619       1.0        1      5.0        13         2         2      1.0
# 3627       1.0        1      4.0        11         2         2      3.0
# 3796       1.0        1      4.0        11         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 441399     1.0        1      2.0        13         2         2      3.0
# 441408     1.0        1      3.0        10         2         2      3.0
# 441409     1.0        1      4.0        11         2         2      3.0
# 441441     1.0        1      3.0         9         2         2      1.0
# 441446     1.0        1      1.0        12         2         1      1.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3464         2.0         1         1
# ...

# %%
stroke = 0
for x in MMB3_S1['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB3_S1 = ((stroke / len(MMB3_S1) * 100))

stroke_MMB3_S1
# Out:
# 9.39977349943375

# %%
HA = 0
for x in MMB3_S1['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB3_S1 = ((HA / len(MMB3_S1) * 100))

HA_MMB3_S1
# Out:
# 17.02529256323141

# %%
HBP = 0
for x in MMB3_S1['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB3_S1 = ((HBP / len(MMB3_S1) * 100))
HBP_MMB3_S1
# Out:
# 62.62740656851642

# %%
#MMB3_S2
MMB3_S2 = rdf[(rdf['CADULT'] == 1) &
           ((rdf['MARITAL'] == 1)) & 
           ((rdf['INCOME2'] == 1) | (rdf['INCOME2'] == 2) | (rdf['INCOME2'] == 3) | (rdf['INCOME2'] == 4) | (rdf['INCOME2'] == 5)) &
           ((rdf['_AGEG5YR'] == 9) | (rdf['_AGEG5YR'] == 10) | (rdf['_AGEG5YR'] == 11) | (rdf['_AGEG5YR'] == 12) | (rdf['_AGEG5YR'] == 13))&
           (rdf['_RFSMOK3'] == 2)]
MMB3_S2
# Out:
#         CADULT  MARITAL  INCOME2  _AGEG5YR  CVDSTRK3  CVDINFR4  BPHIGH4  \
# 3866       1.0        1      5.0         9         2         2      3.0
# 4394       1.0        1      4.0         9         2         2      1.0
# 4626       1.0        1      2.0        10         2         1      1.0
# 4704       1.0        1      4.0        10         2         2      1.0
# 5248       1.0        1      3.0        10         2         2      3.0
# ...        ...      ...      ...       ...       ...       ...      ...
# 440600     1.0        1      5.0         9         2         2      3.0
# 440805     1.0        1      1.0         9         2         2      1.0
# 440888     1.0        1      3.0        11         2         2      1.0
# 441078     1.0        1      4.0        10         2         2      1.0
# 441263     1.0        1      1.0        11         2         2      3.0
#
#         EXERANY2  DRNKANY5  _RFSMOK3
# 3866         2.0         2         2
# ...

# %%
stroke = 0
for x in MMB3_S2['CVDSTRK3']:
    if x == 1:
        stroke = stroke + 1

stroke_MMB3_S2 = ((stroke / len(MMB3_S2) * 100))

stroke_MMB3_S2
# Out:
# 12.144702842377262

# %%
HA = 0
for x in MMB3_S2['CVDINFR4']:
    if x == 1:
        HA = HA + 1
HA_MMB3_S2 = ((HA / len(MMB3_S2) * 100))

HA_MMB3_S2
# Out:
# 18.087855297157624

# %%
HBP = 0
for x in MMB3_S2['BPHIGH4']:
    if x == 1:
        HBP = HBP + 1
HBP_MMB3_S2 = ((HBP / len(MMB3_S2) * 100))
HBP_MMB3_S2
# Out:
# 56.33074935400517

# %%
dictionary = {'MSA1': [stroke_MSA1, HA_MSA1, HBP_MSA1], 'MMA1': [stroke_MMA1, HA_MMA1, HBP_MMA1], 'MSB1': [stroke_MSB1, HA_MSB1, HBP_MSB1], 
              'MMB1': [stroke_MMB1, HA_MMB1, HBP_MMB1], 'MSA2': [stroke_MSA2, HA_MSA2, HBP_MSA2], 'MMA2': [stroke_MMA2, HA_MMA2, HBP_MMA2], 
              'MSB2': [stroke_MSB2, HA_MSB2, HBP_MSB2], 'MMB2': [stroke_MMB2, HA_MMB2, HBP_MMB2], 'MSA3': [stroke_MSA3, HA_MSA3, HBP_MSA3], 
              'MMA3': [stroke_MMA3, HA_MMA3, HBP_MMA3], 'MSB3': [stroke_MSB3, HA_MSB3, HBP_MSB3], 'MMB3': [stroke_MMB3, HA_MMB3, HBP_MMB3],
              'Health Issues': ['Percent Chance of Stroke', 'Percent Chance of Heart Attack', 'Percent Chance of High Blood Pressure'],
              'FSA1': [stroke_FSA1, HA_FSA1, HBP_FSA1], 'FMA1': [stroke_FMA1, HA_FMA1, HBP_FMA1], 'FSB1': [stroke_FSB1, HA_FSB1, HBP_FSB1], 
              'FMB1': [stroke_FMB1, HA_FMB1, HBP_FMB1], 'FSA2': [stroke_FSA2, HA_FSA2, HBP_FSA2], 'FMA2': [stroke_FMA2, HA_FMA2, HBP_FMA2], 
              'FSB2': [stroke_FSB2, HA_FSB2, HBP_FSB2], 'FMB2': [stroke_FMB2, HA_FMB2, HBP_FMB2], 'FSA3': [stroke_FSA3, HA_FSA3, HBP_FSA3], 
              'FMA3': [stroke_FMA3, HA_FMA3, HBP_FMA3], 'FSB3': [stroke_FSB3, HA_FSB3, HBP_FSB3], 'FMB3': [stroke_FMB3, HA_FMB3, HBP_FMB3]}
dataframed = pd.DataFrame(dictionary)

dataframed.set_index('Health Issues', inplace=True)

dataframed
# Out:
#                                             MSA1       MMA1       MSB1  \
# Health Issues
# Percent Chance of Stroke                0.343500   0.247146   0.842187
# Percent Chance of Heart Attack          0.530863   0.435448   0.971754
# Percent Chance of High Blood Pressure  13.583845  16.676474  15.250065
#
#                                             MMB1       MSA2       MMA2  \
# Health Issues
# Percent Chance of Stroke                0.814402   1.406009   1.024160
# Percent Chance of Heart Attack          1.071582   3.120185   2.685137
# Percent Chance of High Blood Pressure  17.402486  35.073190  33.528099
#
#                                             MSB2       MMB2       MSA3  \
# Health Issues
# Percent Chance of Stroke                5.726954   4.297521   5.673512
# Percent Chance of Heart Attack          8.184001   8.000000  12.600070
# Percent Chance of High Blood Pressure  46.129688  42.280992  53.985381
#
# ...

# %%
dictionar = {'MSA1': [stroke_MSA1_E1, stroke_MSA1_E2, stroke_MSA1_D1, stroke_MSA1_D2, stroke_MSA1_S1, stroke_MSA1_S2, 
                      HA_MSA1_E1, HA_MSA1_E2, HA_MSA1_D1, HA_MSA1_D2, HA_MSA1_S1, HA_MSA1_S2, 
                      HBP_MSA1_E1, HBP_MSA1_E2, HBP_MSA1_D1, HBP_MSA1_D2, HBP_MSA1_S1, HBP_MSA1_S2], 
             'MMA1': [stroke_MMA1_E1, stroke_MMA1_E2, stroke_MMA1_D1, stroke_MMA1_D2, stroke_MMA1_S1, stroke_MMA1_S2, 
                      HA_MMA1_E1, HA_MMA1_E2, HA_MMA1_D1, HA_MMA1_D2, HA_MMA1_S1, HA_MMA1_S2, 
                      HBP_MMA1_E1, HBP_MMA1_E2, HBP_MMA1_D1, HBP_MMA1_D2, HBP_MMA1_S1, HBP_MMA1_S2], 
             'MSB1': [stroke_MSB1_E1, stroke_MSB1_E2, stroke_MSB1_D1, stroke_MSB1_D2, stroke_MSB1_S1, stroke_MSB1_S2, 
                      HA_MSB1_E1, HA_MSB1_E2, HA_MSB1_D1, HA_MSB1_D2, HA_MSB1_S1, HA_MSB1_S2, 
                      HBP_MSB1_E1, HBP_MSB1_E2, HBP_MSB1_D1, HBP_MSB1_D2, HBP_MSB1_S1, HBP_MSB1_S2], 
             'MMB1': [stroke_MMB1_E1, stroke_MMB1_E2, stroke_MMB1_D1, stroke_MMB1_D2, stroke_MMB1_S1, stroke_MMB1_S2, 
                      HA_MMB1_E1, HA_MMB1_E2, HA_MMB1_D1, HA_MMB1_D2, HA_MMB1_S1, HA_MMB1_S2, 
                      HBP_MMB1_E1, HBP_MMB1_E2, HBP_MMB1_D1, HBP_MMB1_D2, HBP_MMB1_S1, HBP_MMB1_S2], 
             'MSA2': [stroke_MSA2_E1, stroke_MSA2_E2, stroke_MSA2_D1, stroke_MSA2_D2, stroke_MSA2_S1, stroke_MSA2_S2, 
                      HA_MSA2_E1, HA_MSA2_E2, HA_MSA2_D1, HA_MSA2_D2, HA_MSA2_S1, HA_MSA2_S2, 
                      HBP_MSA2_E1, HBP_MSA2_E2, HBP_MSA2_D1, HBP_MSA2_D2, HBP_MSA2_S1, HBP_MSA2_S2], 
             'MMA2': [stroke_MMA2_E1, stroke_MMA2_E2, stroke_MMA2_D1, stroke_MMA2_D2, stroke_MMA2_S1, stroke_MMA2_S2, 
                      HA_MMA2_E1, HA_MMA2_E2, HA_MMA2_D1, HA_MMA2_D2, HA_MMA2_S1, HA_MMA2_S2, 
                      HBP_MMA2_E1, HBP_MMA2_E2, HBP_MMA2_D1, HBP_MMA2_D2, HBP_MMA2_S1, HBP_MMA2_S2], 
             'MSB2': [stroke_MSB2_E1, stroke_MSB2_E2, stroke_MSB2_D1, stroke_MSB2_D2, stroke_MSB2_S1, stroke_MSB2_S2, 
                      HA_MSB2_E1, HA_MSB2_E2, HA_MSB2_D1, HA_MSB2_D2, HA_MSB2_S1, HA_MSB2_S2, 
                      HBP_MSB2_E1, HBP_MSB2_E2, HBP_MSB2_D1, HBP_MSB2_D2, HBP_MSB2_S1, HBP_MSB2_S2], 
             'MMB2': [stroke_MMB2_E1, stroke_MMB2_E2, stroke_MMB2_D1, stroke_MMB2_D2, stroke_MMB2_S1, stroke_MMB2_S2, 
                      HA_MMB2_E1, HA_MMB2_E2, HA_MMB2_D1, HA_MMB2_D2, HA_MMB2_S1, HA_MMB2_S2, 
                      HBP_MMB2_E1, HBP_MMB2_E2, HBP_MMB2_D1, HBP_MMB2_D2, HBP_MMB2_S1, HBP_MMB2_S2], 
             'MSA3': [stroke_MSA3_E1, stroke_MSA3_E2, stroke_MSA3_D1, stroke_MSA3_D2, stroke_MSA3_S1, stroke_MSA3_S2, 
                      HA_MSA3_E1, HA_MSA3_E2, HA_MSA3_D1, HA_MSA3_D2, HA_MSA3_S1, HA_MSA3_S2, 
                      HBP_MSA3_E1, HBP_MSA3_E2, HBP_MSA3_D1, HBP_MSA3_D2, HBP_MSA3_S1, HBP_MSA3_S2], 
             'MMA3': [stroke_MMA3_E1, stroke_MMA3_E2, stroke_MMA3_D1, stroke_MMA3_D2, stroke_MMA3_S1, stroke_MMA3_S2, 
                      HA_MMA3_E1, HA_MMA3_E2, HA_MMA3_D1, HA_MMA3_D2, HA_MMA3_S1, HA_MMA3_S2, 
                      HBP_MMA3_E1, HBP_MMA3_E2, HBP_MMA3_D1, HBP_MMA3_D2, HBP_MMA3_S1, HBP_MMA3_S2], 
             'MSB3': [stroke_MSB3_E1, stroke_MSB3_E2, stroke_MSB3_D1, stroke_MSB3_D2, stroke_MSB3_S1, stroke_MSB3_S2, 
                      HA_MSB3_E1, HA_MSB3_E2, HA_MSB3_D1, HA_MSB3_D2, HA_MSB3_S1, HA_MSB3_S2, 
                      HBP_MSB3_E1, HBP_MSB3_E2, HBP_MSB3_D1, HBP_MSB3_D2, HBP_MSB3_S1, HBP_MSB3_S2], 
             'MMB3': [stroke_MMB3_E1, stroke_MMB3_E2, stroke_MMB3_D1, stroke_MMB3_D2, stroke_MMB3_S1, stroke_MMB3_S2, 
                      HA_MMB3_E1, HA_MMB3_E2, HA_MMB3_D1, HA_MMB3_D2, HA_MMB3_S1, HA_MMB3_S2,
                      HBP_MMB3_E1, HBP_MMB3_E2, HBP_MMB3_D1, HBP_MMB3_D2, HBP_MMB3_S1, HBP_MMB3_S2], 
             'FSA1': [stroke_FSA1_E1, stroke_FSA1_E2, stroke_FSA1_D1, stroke_FSA1_D2, stroke_FSA1_S1, stroke_FSA1_S2, 
                      HA_FSA1_E1, HA_FSA1_E2, HA_FSA1_D1, HA_FSA1_D2, HA_FSA1_S1, HA_FSA1_S2, 
                      HBP_FSA1_E1, HBP_FSA1_E2, HBP_FSA1_D1, HBP_FSA1_D2, HBP_FSA1_S1, HBP_FSA1_S2], 
             'FMA1': [stroke_FMA1_E1, stroke_FMA1_E2, stroke_FMA1_D1, stroke_FMA1_D2, stroke_FMA1_S1, stroke_FMA1_S2, 
                      HA_FMA1_E1, HA_FMA1_E2, HA_FMA1_D1, HA_FMA1_D2, HA_FMA1_S1, HA_FMA1_S2, 
                      HBP_FMA1_E1, HBP_FMA1_E2, HBP_FMA1_D1, HBP_FMA1_D2, HBP_FMA1_S1, HBP_FMA1_S2], 
             'FSB1': [stroke_FSB1_E1, stroke_FSB1_E2, stroke_FSB1_D1, stroke_FSB1_D2, stroke_FSB1_S1, stroke_FSB1_S2, 
                      HA_FSB1_E1, HA_FSB1_E2, HA_FSB1_D1, HA_FSB1_D2, HA_FSB1_S1, HA_FSB1_S2, 
                      HBP_FSB1_E1, HBP_FSB1_E2, HBP_FSB1_D1, HBP_FSB1_D2, HBP_FSB1_S1, HBP_FSB1_S2], 
             'FMB1': [stroke_FMB1_E1, stroke_FMB1_E2, stroke_FMB1_D1, stroke_FMB1_D2, stroke_FMB1_S1, stroke_FMB1_S2, 
                      HA_FMB1_E1, HA_FMB1_E2, HA_FMB1_D1, HA_FMB1_D2, HA_FMB1_S1, HA_FMB1_S2, 
                      HBP_FMB1_E1, HBP_FMB1_E2, HBP_FMB1_D1, HBP_FMB1_D2, HBP_FMB1_S1, HBP_FMB1_S2], 
             'FSA2': [stroke_FSA2_E1, stroke_FSA2_E2, stroke_FSA2_D1, stroke_FSA2_D2, stroke_FSA2_S1, stroke_FSA2_S2, 
                      HA_FSA2_E1, HA_FSA2_E2, HA_FSA2_D1, HA_FSA2_D2, HA_FSA2_S1, HA_FSA2_S2, 
                      HBP_FSA2_E1, HBP_FSA2_E2, HBP_FSA2_D1, HBP_FSA2_D2, HBP_FSA2_S1, HBP_FSA2_S2], 
             'FMA2': [stroke_FMA2_E1, stroke_FMA2_E2, stroke_FMA2_D1, stroke_FMA2_D2, stroke_FMA2_S1, stroke_FMA2_S2, 
                      HA_FMA2_E1, HA_FMA2_E2, HA_FMA2_D1, HA_FMA2_D2, HA_FMA2_S1, HA_FMA2_S2, 
                      HBP_FMA2_E1, HBP_FMA2_E2, HBP_FMA2_D1, HBP_FMA2_D2, HBP_FMA2_S1, HBP_FMA2_S2], 
             'FSB2': [stroke_FSB2_E1, stroke_FSB2_E2, stroke_FSB2_D1, stroke_FSB2_D2, stroke_FSB2_S1, stroke_FSB2_S2, 
                      HA_FSB2_E1, HA_FSB2_E2, HA_FSB2_D1, HA_FSB2_D2, HA_FSB2_S1, HA_FSB2_S2, 
                      HBP_FSB2_E1, HBP_FSB2_E2, HBP_FSB2_D1, HBP_FSB2_D2, HBP_FSB2_S1, HBP_FSB2_S2], 
             'FMB2': [stroke_FMB2_E1, stroke_FMB2_E2, stroke_FMB2_D1, stroke_FMB2_D2, stroke_FMB2_S1, stroke_FMB2_S2, 
                      HA_FMB2_E1, HA_FMB2_E2, HA_FMB2_D1, HA_FMB2_D2, HA_FMB2_S1, HA_FMB2_S2, 
                      HBP_FMB2_E1, HBP_FMB2_E2, HBP_FMB2_D1, HBP_FMB2_D2, HBP_FMB2_S1, HBP_FMB2_S2], 
             'FSA3': [stroke_FSA3_E1, stroke_FSA3_E2, stroke_FSA3_D1, stroke_FSA3_D2, stroke_FSA3_S1, stroke_FSA3_S2, 
                      HA_FSA3_E1, HA_FSA3_E2, HA_FSA3_D1, HA_FSA3_D2, HA_FSA3_S1, HA_FSA3_S2, 
                      HBP_FSA3_E1, HBP_FSA3_E2, HBP_FSA3_D1, HBP_FSA3_D2, HBP_FSA3_S1, HBP_FSA3_S2], 
             'FMA3': [stroke_FMA3_E1, stroke_FMA3_E2, stroke_FMA3_D1, stroke_FMA3_D2, stroke_FMA3_S1, stroke_FMA3_S2, 
                      HA_FMA3_E1, HA_FMA3_E2, HA_FMA3_D1, HA_FMA3_D2, HA_FMA3_S1, HA_FMA3_S2, 
                      HBP_FMA3_E1, HBP_FMA3_E2, HBP_FMA3_D1, HBP_FMA3_D2, HBP_FMA3_S1, HBP_FMA3_S2], 
             'FSB3': [stroke_FSB3_E1, stroke_FSB3_E2, stroke_FSB3_D1, stroke_FSB3_D2, stroke_FSB3_S1, stroke_FSB3_S2, 
                      HA_FSB3_E1, HA_FSB3_E2, HA_FSB3_D1, HA_FSB3_D2, HA_FSB3_S1, HA_FSB3_S2, 
                      HBP_FSB3_E1, HBP_FSB3_E2, HBP_FSB3_D1, HBP_FSB3_D2, HBP_FSB3_S1, HBP_FSB3_S2], 
             'FMB3': [stroke_FMB3_E1, stroke_FMB3_E2, stroke_FMB3_D1, stroke_FMB3_D2, stroke_FMB3_S1, stroke_FMB3_S2, 
                      HA_FMB3_E1, HA_FMB3_E2, HA_FMB3_D1, HA_FMB3_D2, HA_FMB3_S1, HA_FMB3_S2,
                      HBP_FMB3_E1, HBP_FMB3_E2, HBP_FMB3_D1, HBP_FMB3_D2, HBP_FMB3_S1, HBP_FMB3_S2], 
             'Index': ['Stroke With Exercise', 'Stroke Without Exercise', 'Stroke With Drinking', 'Stroke Without Drinking', 'Stroke With Smoking', 'Stroke Without Smoking', 
                       'Heart Attack With Exercise', 'Heart Attack Without Exercise', 'Heart Attack With Drinking', 'Heart Attack Without Drinking', 'Heart Attack With Smoking', 'Heart Attack Without Smoking', 
                       'High BP With Exercise', 'High BP Without Exercise', 'High BP With Drinking', 'High BP Without Drinking', 'High BP With Smoking', 'High BP Without Smoking']}


datafram = pd.DataFrame(dictionar)

datafram.set_index('Index', inplace=True)

datafram
# Out:
#                                     MSA1       MMA1       MSB1       MMB1  \
# Index
# Stroke With Exercise            0.267201   0.188383   1.034143   0.490540
# Stroke Without Exercise         0.895765   0.447094   1.472618   1.138211
# Stroke With Drinking            0.370041   0.242298   0.923631   0.517688
# Stroke Without Drinking         0.281124   0.249377   1.418919   1.051625
# Stroke With Smoking             0.246070   0.225162   0.836070   0.657109
# Stroke Without Smoking          0.752634   0.359066   2.109890   1.272727
# Heart Attack With Exercise      0.414162   0.423862   0.738674   0.911002
# Heart Attack Without Exercise   1.058632   0.596125   1.196503   1.788618
# Heart Attack With Drinking      0.547661   0.346141   0.788466   1.035375
# Heart Attack Without Drinking   0.481928   0.706567   0.990991   1.051625
# Heart Attack With Smoking       0.341763   0.351815   0.537474   1.015532
# Heart Attack Without Smoking    1.304566   0.897666   1.846154   1.454545
# ...

# %%
diction = {'MSA1': [stroke_MSA1, stroke_MSA1_E1, stroke_MSA1_E2, stroke_MSA1_D1, stroke_MSA1_D2, stroke_MSA1_S1, stroke_MSA1_S2, 
                      HA_MSA1, HA_MSA1_E1, HA_MSA1_E2, HA_MSA1_D1, HA_MSA1_D2, HA_MSA1_S1, HA_MSA1_S2, 
                      HBP_MSA1, HBP_MSA1_E1, HBP_MSA1_E2, HBP_MSA1_D1, HBP_MSA1_D2, HBP_MSA1_S1, HBP_MSA1_S2],
             'MMA1': [stroke_MMA1, stroke_MMA1_E1, stroke_MMA1_E2, stroke_MMA1_D1, stroke_MMA1_D2, stroke_MMA1_S1, stroke_MMA1_S2, 
                      HA_MMA1, HA_MMA1_E1, HA_MMA1_E2, HA_MMA1_D1, HA_MMA1_D2, HA_MMA1_S1, HA_MMA1_S2, 
                      HBP_MMA1, HBP_MMA1_E1, HBP_MMA1_E2, HBP_MMA1_D1, HBP_MMA1_D2, HBP_MMA1_S1, HBP_MMA1_S2], 
             'MSB1': [stroke_MSB1, stroke_MSB1_E1, stroke_MSB1_E2, stroke_MSB1_D1, stroke_MSB1_D2, stroke_MSB1_S1, stroke_MSB1_S2, 
                      HA_MSB1, HA_MSB1_E1, HA_MSB1_E2, HA_MSB1_D1, HA_MSB1_D2, HA_MSB1_S1, HA_MSB1_S2, 
                      HBP_MSB1, HBP_MSB1_E1, HBP_MSB1_E2, HBP_MSB1_D1, HBP_MSB1_D2, HBP_MSB1_S1, HBP_MSB1_S2], 
             'MMB1': [stroke_MMB1, stroke_MMB1_E1, stroke_MMB1_E2, stroke_MMB1_D1, stroke_MMB1_D2, stroke_MMB1_S1, stroke_MMB1_S2, 
                      HA_MMB1, HA_MMB1_E1, HA_MMB1_E2, HA_MMB1_D1, HA_MMB1_D2, HA_MMB1_S1, HA_MMB1_S2, 
                      HBP_MMB1,HBP_MMB1_E1, HBP_MMB1_E2, HBP_MMB1_D1, HBP_MMB1_D2, HBP_MMB1_S1, HBP_MMB1_S2], 
             'MSA2': [stroke_MSA2, stroke_MSA2_E1, stroke_MSA2_E2, stroke_MSA2_D1, stroke_MSA2_D2, stroke_MSA2_S1, stroke_MSA2_S2, 
                      HA_MSA2, HA_MSA2_E1, HA_MSA2_E2, HA_MSA2_D1, HA_MSA2_D2, HA_MSA2_S1, HA_MSA2_S2, 
                      HBP_MSA2, HBP_MSA2_E1, HBP_MSA2_E2, HBP_MSA2_D1, HBP_MSA2_D2, HBP_MSA2_S1, HBP_MSA2_S2], 
             'MMA2': [stroke_MMA2, stroke_MMA2_E1, stroke_MMA2_E2, stroke_MMA2_D1, stroke_MMA2_D2, stroke_MMA2_S1, stroke_MMA2_S2, 
                      HA_MMA2, HA_MMA2_E1, HA_MMA2_E2, HA_MMA2_D1, HA_MMA2_D2, HA_MMA2_S1, HA_MMA2_S2, 
                      HBP_MMA2, HBP_MMA2_E1, HBP_MMA2_E2, HBP_MMA2_D1, HBP_MMA2_D2, HBP_MMA2_S1, HBP_MMA2_S2], 
             'MSB2': [stroke_MSB2, stroke_MSB2_E1, stroke_MSB2_E2, stroke_MSB2_D1, stroke_MSB2_D2, stroke_MSB2_S1, stroke_MSB2_S2, 
                      HA_MSB2, HA_MSB2_E1, HA_MSB2_E2, HA_MSB2_D1, HA_MSB2_D2, HA_MSB2_S1, HA_MSB2_S2, 
                      HBP_MSB2, HBP_MSB2_E1, HBP_MSB2_E2, HBP_MSB2_D1, HBP_MSB2_D2, HBP_MSB2_S1, HBP_MSB2_S2], 
             'MMB2': [stroke_MMB2, stroke_MMB2_E1, stroke_MMB2_E2, stroke_MMB2_D1, stroke_MMB2_D2, stroke_MMB2_S1, stroke_MMB2_S2, 
                      HA_MMB2, HA_MMB2_E1, HA_MMB2_E2, HA_MMB2_D1, HA_MMB2_D2, HA_MMB2_S1, HA_MMB2_S2, 
                      HBP_MMB2, HBP_MMB2_E1, HBP_MMB2_E2, HBP_MMB2_D1, HBP_MMB2_D2, HBP_MMB2_S1, HBP_MMB2_S2], 
             'MSA3': [stroke_MSA3, stroke_MSA3_E1, stroke_MSA3_E2, stroke_MSA3_D1, stroke_MSA3_D2, stroke_MSA3_S1, stroke_MSA3_S2, 
                      HA_MSA3, HA_MSA3_E1, HA_MSA3_E2, HA_MSA3_D1, HA_MSA3_D2, HA_MSA3_S1, HA_MSA3_S2, 
                      HBP_MSA3, HBP_MSA3_E1, HBP_MSA3_E2, HBP_MSA3_D1, HBP_MSA3_D2, HBP_MSA3_S1, HBP_MSA3_S2], 
             'MMA3': [stroke_MMA3,stroke_MMA3_E1, stroke_MMA3_E2, stroke_MMA3_D1, stroke_MMA3_D2, stroke_MMA3_S1, stroke_MMA3_S2, 
                      HA_MMA3, HA_MMA3_E1, HA_MMA3_E2, HA_MMA3_D1, HA_MMA3_D2, HA_MMA3_S1, HA_MMA3_S2, 
                      HBP_MMA3, HBP_MMA3_E1, HBP_MMA3_E2, HBP_MMA3_D1, HBP_MMA3_D2, HBP_MMA3_S1, HBP_MMA3_S2], 
             'MSB3': [stroke_MSB3, stroke_MSB3_E1, stroke_MSB3_E2, stroke_MSB3_D1, stroke_MSB3_D2, stroke_MSB3_S1, stroke_MSB3_S2, 
                      HA_MSB3, HA_MSB3_E1, HA_MSB3_E2, HA_MSB3_D1, HA_MSB3_D2, HA_MSB3_S1, HA_MSB3_S2, 
                      HBP_MSB3, HBP_MSB3_E1, HBP_MSB3_E2, HBP_MSB3_D1, HBP_MSB3_D2, HBP_MSB3_S1, HBP_MSB3_S2], 
             'MMB3': [stroke_MMB3, stroke_MMB3_E1, stroke_MMB3_E2, stroke_MMB3_D1, stroke_MMB3_D2, stroke_MMB3_S1, stroke_MMB3_S2, 
                      HA_MMB3, HA_MMB3_E1, HA_MMB3_E2, HA_MMB3_D1, HA_MMB3_D2, HA_MMB3_S1, HA_MMB3_S2,
                      HBP_MMB3, HBP_MMB3_E1, HBP_MMB3_E2, HBP_MMB3_D1, HBP_MMB3_D2, HBP_MMB3_S1, HBP_MMB3_S2], 
             'FSA1': [stroke_FSA1, stroke_FSA1_E1, stroke_FSA1_E2, stroke_FSA1_D1, stroke_FSA1_D2, stroke_FSA1_S1, stroke_FSA1_S2, 
                      HA_FSA1, HA_FSA1_E1, HA_FSA1_E2, HA_FSA1_D1, HA_FSA1_D2, HA_FSA1_S1, HA_FSA1_S2, 
                      HBP_FSA1, HBP_FSA1_E1, HBP_FSA1_E2, HBP_FSA1_D1, HBP_FSA1_D2, HBP_FSA1_S1, HBP_FSA1_S2], 
             'FMA1': [stroke_FMA1, stroke_FMA1_E1, stroke_FMA1_E2, stroke_FMA1_D1, stroke_FMA1_D2, stroke_FMA1_S1, stroke_FMA1_S2, 
                      HA_FMA1, HA_FMA1_E1, HA_FMA1_E2, HA_FMA1_D1, HA_FMA1_D2, HA_FMA1_S1, HA_FMA1_S2, 
                      HBP_FMA1, HBP_FMA1_E1, HBP_FMA1_E2, HBP_FMA1_D1, HBP_FMA1_D2, HBP_FMA1_S1, HBP_FMA1_S2], 
             'FSB1': [stroke_FSB1, stroke_FSB1_E1, stroke_FSB1_E2, stroke_FSB1_D1, stroke_FSB1_D2, stroke_FSB1_S1, stroke_FSB1_S2, 
                      HA_FSB1, HA_FSB1_E1, HA_FSB1_E2, HA_FSB1_D1, HA_FSB1_D2, HA_FSB1_S1, HA_FSB1_S2, 
                      HBP_FSB1, HBP_FSB1_E1, HBP_FSB1_E2, HBP_FSB1_D1, HBP_FSB1_D2, HBP_FSB1_S1, HBP_FSB1_S2], 
             'FMB1': [stroke_FMB1, stroke_FMB1_E1, stroke_FMB1_E2, stroke_FMB1_D1, stroke_FMB1_D2, stroke_FMB1_S1, stroke_FMB1_S2, 
                      HA_FMB1, HA_FMB1_E1, HA_FMB1_E2, HA_FMB1_D1, HA_FMB1_D2, HA_FMB1_S1, HA_FMB1_S2, 
                      HBP_FMB1, HBP_FMB1_E1, HBP_FMB1_E2, HBP_FMB1_D1, HBP_FMB1_D2, HBP_FMB1_S1, HBP_FMB1_S2], 
             'FSA2': [stroke_FSA2, stroke_FSA2_E1, stroke_FSA2_E2, stroke_FSA2_D1, stroke_FSA2_D2, stroke_FSA2_S1, stroke_FSA2_S2, 
                      HA_FSA2, HA_FSA2_E1, HA_FSA2_E2, HA_FSA2_D1, HA_FSA2_D2, HA_FSA2_S1, HA_FSA2_S2, 
                      HBP_FSA2, HBP_FSA2_E1, HBP_FSA2_E2, HBP_FSA2_D1, HBP_FSA2_D2, HBP_FSA2_S1, HBP_FSA2_S2], 
             'FMA2': [stroke_FMA2, stroke_FMA2_E1, stroke_FMA2_E2, stroke_FMA2_D1, stroke_FMA2_D2, stroke_FMA2_S1, stroke_FMA2_S2, 
                      HA_FMA2, HA_FMA2_E1, HA_FMA2_E2, HA_FMA2_D1, HA_FMA2_D2, HA_FMA2_S1, HA_FMA2_S2, 
                      HBP_FMA2, HBP_FMA2_E1, HBP_FMA2_E2, HBP_FMA2_D1, HBP_FMA2_D2, HBP_FMA2_S1, HBP_FMA2_S2], 
             'FSB2': [stroke_FSB2, stroke_FSB2_E1, stroke_FSB2_E2, stroke_FSB2_D1, stroke_FSB2_D2, stroke_FSB2_S1, stroke_FSB2_S2, 
                      HA_FSB2, HA_FSB2_E1, HA_FSB2_E2, HA_FSB2_D1, HA_FSB2_D2, HA_FSB2_S1, HA_FSB2_S2, 
                      HBP_FSB2, HBP_FSB2_E1, HBP_FSB2_E2, HBP_FSB2_D1, HBP_FSB2_D2, HBP_FSB2_S1, HBP_FSB2_S2], 
             'FMB2': [stroke_FMB2, stroke_FMB2_E1, stroke_FMB2_E2, stroke_FMB2_D1, stroke_FMB2_D2, stroke_FMB2_S1, stroke_FMB2_S2, 
                      HA_FMB2, HA_FMB2_E1, HA_FMB2_E2, HA_FMB2_D1, HA_FMB2_D2, HA_FMB2_S1, HA_FMB2_S2, 
                      HBP_FMB2, HBP_FMB2_E1, HBP_FMB2_E2, HBP_FMB2_D1, HBP_FMB2_D2, HBP_FMB2_S1, HBP_FMB2_S2], 
             'FSA3': [stroke_FSA3, stroke_FSA3_E1, stroke_FSA3_E2, stroke_FSA3_D1, stroke_FSA3_D2, stroke_FSA3_S1, stroke_FSA3_S2, 
                      HA_FSA3, HA_FSA3_E1, HA_FSA3_E2, HA_FSA3_D1, HA_FSA3_D2, HA_FSA3_S1, HA_FSA3_S2, 
                      HBP_FSA3, HBP_FSA3_E1, HBP_FSA3_E2, HBP_FSA3_D1, HBP_FSA3_D2, HBP_FSA3_S1, HBP_FSA3_S2], 
             'FMA3': [stroke_FMA3, stroke_FMA3_E1, stroke_FMA3_E2, stroke_FMA3_D1, stroke_FMA3_D2, stroke_FMA3_S1, stroke_FMA3_S2, 
                      HA_FMA3, HA_FMA3_E1, HA_FMA3_E2, HA_FMA3_D1, HA_FMA3_D2, HA_FMA3_S1, HA_FMA3_S2, 
                      HBP_FMA3, HBP_FMA3_E1, HBP_FMA3_E2, HBP_FMA3_D1, HBP_FMA3_D2, HBP_FMA3_S1, HBP_FMA3_S2], 
             'FSB3': [stroke_FSB3, stroke_FSB3_E1, stroke_FSB3_E2, stroke_FSB3_D1, stroke_FSB3_D2, stroke_FSB3_S1, stroke_FSB3_S2, 
                      HA_FSB3, HA_FSB3_E1, HA_FSB3_E2, HA_FSB3_D1, HA_FSB3_D2, HA_FSB3_S1, HA_FSB3_S2, 
                      HBP_FSB3, HBP_FSB3_E1, HBP_FSB3_E2, HBP_FSB3_D1, HBP_FSB3_D2, HBP_FSB3_S1, HBP_FSB3_S2], 
             'FMB3': [stroke_FMB3, stroke_FMB3_E1, stroke_FMB3_E2, stroke_FMB3_D1, stroke_FMB3_D2, stroke_FMB3_S1, stroke_FMB3_S2, 
                      HA_FMB3, HA_FMB3_E1, HA_FMB3_E2, HA_FMB3_D1, HA_FMB3_D2, HA_FMB3_S1, HA_FMB3_S2,
                      HBP_FMB3, HBP_FMB3_E1, HBP_FMB3_E2, HBP_FMB3_D1, HBP_FMB3_D2, HBP_FMB3_S1, HBP_FMB3_S2], 
             'Title': ['Stroke', 'Stroke With Exercise', 'Stroke Without Exercise', 'Stroke Without Drinking', 'Stroke With Drinking', 'Stroke Non Smoker', 'Stroke Smoker', 
                       'Heart Attack', 'Heart Attack With Exercise', 'Heart Attack Without Exercise', 'Heart Attack Without Drinking', 'Heart Attack With Drinking', 'Heart Attack Non Smoker', 'Heart Attack Smoker', 
                       'High BP', 'High BP With Exercise', 'High BP Without Exercise', 'High BP Without Drinking', 'High BP With Drinking', 'High BP Non Smoker', 'High BP Smoker']}
dataframedcomb = pd.DataFrame(diction)

dataframedcomb.set_index('Title', inplace=True)

dataframedcomb
# Out:
#                                     MSA1       MMA1       MSB1       MMB1  \
# Title
# Stroke                          0.343500   0.247146   0.842187   0.814402
# Stroke With Exercise            0.267201   0.188383   1.034143   0.490540
# Stroke Without Exercise         0.895765   0.447094   1.472618   1.138211
# Stroke Without Drinking         0.370041   0.242298   0.923631   0.517688
# Stroke With Drinking            0.281124   0.249377   1.418919   1.051625
# Stroke Non Smoker               0.246070   0.225162   0.836070   0.657109
# Stroke Smoker                   0.752634   0.359066   2.109890   1.272727
# Heart Attack                    0.530863   0.435448   0.971754   1.071582
# Heart Attack With Exercise      0.414162   0.423862   0.738674   0.911002
# Heart Attack Without Exercise   1.058632   0.596125   1.196503   1.788618
# Heart Attack Without Drinking   0.547661   0.346141   0.788466   1.035375
# Heart Attack With Drinking      0.481928   0.706567   0.990991   1.051625
# ...

# %%
dataframedcomb.to_csv('final.statfile1.csv')

# %%
df = pd.read_csv('final.statfile1.csv', index_col='Title')

# %%
df
# Out:
#                                     MSA1       MMA1       MSB1       MMB1  \
# Title
# Stroke                          0.343500   0.247146   0.842187   0.814402
# Stroke With Exercise            0.267201   0.188383   1.034143   0.490540
# Stroke Without Exercise         0.895765   0.447094   1.472618   1.138211
# Stroke Without Drinking         0.370041   0.242298   0.923631   0.517688
# Stroke With Drinking            0.281124   0.249377   1.418919   1.051625
# Stroke Non Smoker               0.246070   0.225162   0.836070   0.657109
# Stroke Smoker                   0.752634   0.359066   2.109890   1.272727
# Heart Attack                    0.530863   0.435448   0.971754   1.071582
# Heart Attack With Exercise      0.414162   0.423862   0.738674   0.911002
# Heart Attack Without Exercise   1.058632   0.596125   1.196503   1.788618
# Heart Attack Without Drinking   0.547661   0.346141   0.788466   1.035375
# Heart Attack With Drinking      0.481928   0.706567   0.990991   1.051625
# ...
