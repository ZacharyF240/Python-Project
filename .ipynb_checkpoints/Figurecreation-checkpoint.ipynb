# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('final.statfile1.csv', index_col='Title')

# %%
df
# Out:
#                                     MSA1       MMA1       MSB1       MMB1  \
# Title
# Stroke                          0.343500   0.247146   0.842187   0.814402
# Stroke With Exercise            0.267201   0.188383   1.034143   0.490540
# Stroke Without Exercise         0.895765   0.447094   1.472618   1.138211
# Stroke Without Drinking         0.370041   0.242298   0.923631   0.517688
# Stroke With Drinking            0.281124   0.249377   1.418919   1.051625
# Stroke Non Smoker               0.246070   0.225162   0.836070   0.657109
# Stroke Smoker                   0.752634   0.359066   2.109890   1.272727
# Heart Attack                    0.530863   0.435448   0.971754   1.071582
# Heart Attack With Exercise      0.414162   0.423862   0.738674   0.911002
# Heart Attack Without Exercise   1.058632   0.596125   1.196503   1.788618
# Heart Attack Without Drinking   0.547661   0.346141   0.788466   1.035375
# Heart Attack With Drinking      0.481928   0.706567   0.990991   1.051625
# Heart Attack Non Smoker         0.341763   0.351815   0.537474   1.015532
# Heart Attack Smoker             1.304566   0.897666   1.846154   1.454545
# High BP                        13.583845  16.676474  15.250065  17.402486
# High BP With Exercise          12.852371  16.200942  10.357846  17.379117
# High BP Without Exercise       17.996743  19.523100  13.989876  19.186992
# High BP Without Drinking       14.328005  16.857044  10.678081  17.860224
# High BP With Drinking          11.606426  15.960100  11.621622  17.495220
# High BP Non Smoker             12.276145  15.761328   9.510302  16.726404
# High BP Smoker                 18.314099  21.723519  16.219780  19.818182
#
#                                     MSA2       MMA2       MSB2       MMB2  \
# Title
# Stroke                          1.406009   1.024160   5.726954   4.297521
# Stroke With Exercise            1.356852   0.861303   5.098301   4.785894
# Stroke Without Exercise         1.326260   1.729400   6.356164   4.521277
# Stroke Without Drinking         1.025641   0.804829   4.422311   3.895072
# Stroke With Drinking            2.189781   1.486989   6.856061   4.932182
# Stroke Non Smoker               1.154734   0.940463   4.922365   3.853383
# Stroke Smoker                   2.136752   1.701094   6.749311   6.041131
# Heart Attack                    3.120185   2.685137   8.184001   8.000000
# Heart Attack With Exercise      2.767978   2.592790   7.597468   7.682620
# Heart Attack Without Exercise   3.978780   2.916243   9.205479   8.953901
# Heart Attack Without Drinking   2.564103   2.313883   6.852590   5.564388
# Heart Attack With Drinking      4.578633   3.469641   9.621212  10.110974
# Heart Attack Non Smoker         2.566076   2.495260   6.838454   6.954887
# Heart Attack Smoker             5.042735   4.374241   9.963269  11.568123
# High BP                        35.073190  33.528099  46.129688  42.280992
# High BP With Exercise          32.727273  32.205647  45.884705  42.569270
# High BP Without Exercise       41.644562  38.724992  48.328767  43.262411
# High BP Without Drinking       34.871795  32.957746  44.183267  40.143084
# High BP With Drinking          34.505640  34.840975  48.030303  44.081381
# High BP Non Smoker             34.642032  33.310580  46.977205  41.917293
# High BP Smoker                 35.384615  36.026731  45.041322  43.187661
#
#                                     MSA3       MMA3  ...       FSB1  \
# Title                                                ...
# Stroke                          5.673512   4.178028  ...   1.181018
# Stroke With Exercise            5.345758   3.859690  ...   1.034143
# Stroke Without Exercise         7.164634   5.525847  ...   1.472618
# Stroke Without Drinking         3.974284   3.387143  ...   0.923631
# Stroke With Drinking            8.192090   5.630739  ...   1.418919
# Stroke Non Smoker               5.469079   4.184425  ...   0.836070
# Stroke Smoker                   6.650831   4.182042  ...   2.109890
# Heart Attack                   12.600070  10.115226  ...   0.891132
# Heart Attack With Exercise     11.230996   9.396997  ...   0.738674
# Heart Attack Without Exercise  16.920732  12.745098  ...   1.196503
# Heart Attack Without Drinking  10.753945   8.460651  ...   0.788466
# Heart Attack With Drinking     15.348399  12.977284  ...   0.990991
# Heart Attack Non Smoker        11.947833   9.821775  ...   0.537474
# Heart Attack Smoker            15.439430  14.268143  ...   1.846154
# High BP                        53.985381  54.560647  ...  11.230406
# High BP With Exercise          52.672879  53.366964  ...  10.357846
# High BP Without Exercise       60.365854  59.670232  ...  13.989876
# High BP Without Drinking       53.477499  53.646584  ...  10.678081
# High BP With Drinking          54.990584  56.428226  ...  11.621622
# High BP Non Smoker             54.606647  54.736536  ...   9.510302
# High BP Smoker                 51.781473  53.259533  ...  16.219780
#
#                                     FMB1       FSA2       FMA2       FSB2  \
# Title
# Stroke                          1.034260   1.424563   1.343018   6.138556
# Stroke With Exercise            0.847880   1.142690   1.077489   5.131614
# Stroke Without Exercise         1.319261   2.083333   2.504892   7.244607
# Stroke Without Drinking         0.771456   1.116928   0.943288   4.288747
# Stroke With Drinking            1.096606   1.970443   1.994146   7.161489
# Stroke Non Smoker               0.800000   1.277615   1.272484   5.094080
# Stroke Smoker                   2.020202   2.204929   2.207358   8.158813
# Heart Attack                    0.904977   1.100799   1.171714   5.480854
# Heart Attack With Exercise      0.997506   0.966891   0.915866   5.184791
# Heart Attack Without Exercise   0.791557   1.644737   1.996086   5.982906
# Heart Attack Without Drinking   1.060752   0.977312   0.805246   3.439490
# Heart Attack With Drinking      0.887728   1.416256   1.738017   6.663505
# Heart Attack Non Smoker         0.589474   0.851743   0.942581   4.703993
# Heart Attack Smoker             2.188552   2.464332   3.010033   6.980803
# High BP                        10.277957  26.527088  22.776483  41.566793
# High BP With Exercise           9.426434  23.791386  20.606986  38.633342
# High BP Without Exercise       13.192612  36.293860  32.681018  46.682947
# High BP Without Drinking        9.643202  25.165794  20.338203  36.475584
# High BP With Drinking          10.809399  29.064039  26.948408  44.510315
# High BP Non Smoker              8.715789  26.244344  22.268479  41.326296
# High BP Smoker                 17.003367  28.404669  28.026756  41.972077
#
#                                     FMB2       FSA3       FMA3       FSB3  \
# Title
# Stroke                          5.310281   3.507632   3.025661   8.910235
# Stroke With Exercise            4.485336   3.172475   2.531431   7.815126
# Stroke Without Exercise         6.766917   4.671533   5.277045  10.592809
# Stroke Without Drinking         3.508772   2.935665   2.026538   6.015485
# Stroke With Drinking            5.877075   4.347826   4.329128  10.019175
# Stroke Non Smoker               4.670913   3.699634   2.834342   8.727720
# Stroke Smoker                   6.684142   2.150538   7.142857   9.667674
# Heart Attack                    4.908923   4.449497   3.140559  10.384233
# Heart Attack With Exercise      4.140311   3.753351   2.701325   9.271709
# Heart Attack Without Exercise   6.265664   6.423358   4.749340  12.293489
# Heart Attack Without Drinking   3.391813   2.873204   2.412545   6.611078
# Heart Attack With Drinking      5.607896   6.129722   4.013761  11.960690
# Heart Attack Non Smoker         3.736730   4.065934   2.958173  10.038926
# Heart Attack Smoker             8.781127   7.526882   6.650246  12.286002
# High BP                        39.734486  51.575187  46.214733  62.437893
# High BP With Exercise          36.745256  48.257373  43.560992  59.271709
# High BP Without Exercise       44.527987  61.167883  56.398417  68.270165
# High BP Without Drinking       36.491228  47.282948  42.870929  55.628350
# High BP With Drinking          41.004935  56.022808  50.458716  65.220518
# High BP Non Smoker             39.872611  51.025641  46.257567  63.491088
# High BP Smoker                 39.318480  54.480287  47.290640  58.006042
#
#                                     FMB3
# Title
# Stroke                          6.823266
# Stroke With Exercise            5.625000
# Stroke Without Exercise         8.771930
# Stroke Without Drinking         4.497751
# Stroke With Drinking            7.647983
# Stroke Non Smoker               6.120690
# Stroke Smoker                  12.363636
# Heart Attack                    9.134974
# Heart Attack With Exercise      8.125000
# Heart Attack Without Exercise  10.760234
# Heart Attack Without Drinking   7.046477
# Heart Attack With Drinking     10.005238
# Heart Attack Non Smoker         8.663793
# Heart Attack Smoker            13.454545
# High BP                        59.023117
# High BP With Exercise          54.500000
# High BP Without Exercise       66.783626
# High BP Without Drinking       49.325337
# High BP With Drinking          62.283918
# High BP Non Smoker             58.405172
# High BP Smoker                 61.818182
#
# [21 rows x 24 columns]

# %%
values = []
for index, row in df.iterrows():
    if index == 'Stroke':
        values.append(row.values)
values
y1 = values[0].tolist()

y1
# Out:
# [0.3434995315915478,
#  0.247146051547605,
#  0.8421870951023581,
#  0.8144020574367767,
#  1.4060092449922958,
#  1.024159663865546,
#  5.72695363014964,
#  4.297520661157025,
#  5.673512008353637,
#  4.178027970797784,
#  11.293886570095752,
#  9.689677010766308,
#  0.3264417845484222,
#  0.507998270644185,
#  1.181017822632596,
#  1.0342598577892694,
#  1.4245629181955537,
#  1.3430176784980128,
#  6.138555977784273,
#  5.310280950910775,
#  3.5076323481649885,
#  3.025660666411337,
#  8.910235177210996,
#  6.823266219239374]

# %%
values = []
for index, row in df.iterrows():
    if index == 'Stroke With Exercise':
        values.append(row.values)
values
y2 = values[0].tolist()

y2
# Out:
# [0.2672010688042752,
#  0.1883830455259026,
#  1.0341431385423503,
#  0.4905395935529082,
#  1.35685210312076,
#  0.8613034984904989,
#  5.098300566477841,
#  4.785894206549118,
#  5.345757724374693,
#  3.859690286250587,
#  11.09720483938256,
#  8.975039830058417,
#  0.2776675922253074,
#  0.5009741163373226,
#  1.0341431385423503,
#  0.8478802992518704,
#  1.142689715792558,
#  1.077489449582473,
#  5.13161393246477,
#  4.485336400230017,
#  3.172475424486149,
#  2.5314305130818893,
#  7.815126050420168,
#  5.625]

# %%
values = []
for index, row in df.iterrows():
    if index == 'Stroke Without Exercise':
        values.append(row.values)
values
y3 = values[0].tolist()

y3
# Out:
# [0.8957654723127036,
#  0.4470938897168405,
#  1.4726184997699034,
#  1.1382113821138211,
#  1.326259946949602,
#  1.7293997965412005,
#  6.356164383561644,
#  4.521276595744681,
#  7.164634146341463,
#  5.525846702317291,
#  11.009174311926609,
#  11.190233977619531,
#  0.4778972520908005,
#  0.4310344827586206,
#  1.4726184997699034,
#  1.3192612137203166,
#  2.083333333333333,
#  2.5048923679060664,
#  7.244607244607244,
#  6.7669172932330826,
#  4.671532846715328,
#  5.277044854881266,
#  10.592808551992224,
#  8.771929824561402]

# %%
values = []
for index, row in df.iterrows():
    if index == 'Stroke With Drinking':
        values.append(row.values)
values
y4 = values[0].tolist()

y4
# Out:
# [0.2811244979919678,
#  0.2493765586034912,
#  1.418918918918919,
#  1.051625239005736,
#  2.18978102189781,
#  1.486988847583643,
#  6.8560606060606055,
#  4.932182490752158,
#  8.192090395480225,
#  5.630739487675205,
#  13.035714285714286,
#  10.55495103373232,
#  0.554016620498615,
#  0.4829621679635095,
#  1.418918918918919,
#  1.0966057441253263,
#  1.9704433497536944,
#  1.9941456275155507,
#  7.161489210339103,
#  5.8770749214894575,
#  4.3478260869565215,
#  4.329128440366972,
#  10.019175455417066,
#  7.647983237297014]

# %%
values = []
for index, row in df.iterrows():
    if index == 'Stroke Without Drinking':
        values.append(row.values)
values
y5 = values[0].tolist()

y5
# Out:
# [0.3700414446417999,
#  0.2422983731394946,
#  0.9236314485244426,
#  0.5176876617773942,
#  1.0256410256410255,
#  0.8048289738430584,
#  4.422310756972111,
#  3.8950715421303657,
#  3.974284044418469,
#  3.3871432689535887,
#  8.753799392097264,
#  8.710503842869342,
#  0.2496029044701611,
#  0.4952380952380952,
#  0.9236314485244426,
#  0.7714561234329798,
#  1.1169284467713787,
#  0.9432877027493384,
#  4.288747346072187,
#  3.508771929824561,
#  2.9356652092442226,
#  2.0265379975874547,
#  6.015485407980941,
#  4.497751124437781]

# %%
values = []
for index, row in df.iterrows():
    if index == 'Stroke Non Smoker':
        values.append(row.values)
values
y6 = values[0].tolist()

y6
# Out:
# [0.2460697197539302,
#  0.2251618350689558,
#  0.8360704687966557,
#  0.6571087216248507,
#  1.1547344110854505,
#  0.9404626469472884,
#  4.922365378262306,
#  3.853383458646616,
#  5.469078670593184,
#  4.184424641611778,
#  10.315284441398218,
#  9.39977349943375,
#  0.2426278462112728,
#  0.4270896888346553,
#  0.8360704687966557,
#  0.8,
#  1.2776151184455682,
#  1.272484486686042,
#  5.094079853143644,
#  4.670912951167728,
#  3.6996336996337,
#  2.834342322509632,
#  8.727719729563614,
#  6.120689655172414]

# %%
values = []
for index, row in df.iterrows():
    if index == 'Stroke Smoker':
        values.append(row.values)
values
y7 = values[0].tolist()

y7
# Out:
# [0.7526342197691922,
#  0.3590664272890485,
#  2.10989010989011,
#  1.2727272727272727,
#  2.1367521367521367,
#  1.701093560145808,
#  6.749311294765841,
#  6.041131105398458,
#  6.65083135391924,
#  4.182041820418204,
#  14.175506268081003,
#  12.144702842377262,
#  0.904977375565611,
#  1.2121212121212122,
#  2.10989010989011,
#  2.0202020202020203,
#  2.204928664072633,
#  2.2073578595317724,
#  8.158813263525305,
#  6.684141546526867,
#  2.1505376344086025,
#  7.142857142857142,
#  9.667673716012084,
#  12.363636363636363]

# %%
x = []
for column_name, column_data in df.iteritems():
    x.append(column_name)
x
# Out:
# ['MSA1',
#  'MMA1',
#  'MSB1',
#  'MMB1',
#  'MSA2',
#  'MMA2',
#  'MSB2',
#  'MMB2',
#  'MSA3',
#  'MMA3',
#  'MSB3',
#  'MMB3',
#  'FSA1',
#  'FMA1',
#  'FSB1',
#  'FMB1',
#  'FSA2',
#  'FMA2',
#  'FSB2',
#  'FMB2',
#  'FSA3',
#  'FMA3',
#  'FSB3',
#  'FMB3']

# %%
plt.figure(figsize=(14,8))

#Stroke
plt.scatter(x,y1, 
            c = 'black',)
#Stroke with Excersize
plt.scatter(x,y2,
            c = 'pink',)
#Stroke without Excersize
plt.scatter(x,y3,
            c = 'blue',)
#labeling
plt.title('Chance of Having had a Stroke Based on Demographic and Exercise', fontsize=20)
plt.ylabel('Percent ', fontsize = 14)
plt.xlabel('Demographic Group', fontsize = 14)

#show 
plt.savefig('StrokeEgraph')

# %%
plt.figure(figsize=(14,8))

#Stroke
plt.scatter(x,y1, 
            c = 'black',)
#Stroke with driking
plt.scatter(x,y4,
            c = 'blue',)
#Stroke without without drinking
plt.scatter(x,y5,
            c = 'pink',)
#labeling
plt.title('Chance of Having had a Stroke Based on Demographic and Drinking', fontsize=20)
plt.ylabel('Percent ', fontsize = 14)
plt.xlabel('Demographic Group', fontsize = 14)

#show 
plt.savefig('StrokeDgraph')

# %%
plt.figure(figsize=(14,8))

#Stroke
plt.scatter(x,y1, 
            c = 'black',)
#Stroke with no smoker
plt.scatter(x,y6,
            c = 'pink',)
#Stroke without smoker
plt.scatter(x,y7,
            c = 'blue',)
#labeling
plt.title('Chance of Having had a Stroke Based on Demographic and Smoking', fontsize=20)
plt.ylabel('Percent ', fontsize = 14)
plt.xlabel('Demographic Group', fontsize = 14)

#show 
plt.savefig('StrokeSgraph')

# %%
 #HA

# %%
values = []
for index, row in df.iterrows():
    if index == 'High BP':
        values.append(row.values)
values
y1b = values[0].tolist()

y1b
# Out:
# [13.583845112938484,
#  16.676474049664588,
#  15.2500647836227,
#  17.402486069438492,
#  35.07318952234206,
#  33.5280987394958,
#  46.12968778865694,
#  42.28099173553719,
#  53.9853811347024,
#  54.56064737443926,
#  62.41099926344218,
#  61.52628245725143,
#  7.445981657080678,
#  6.279723303069607,
#  11.23040584066996,
#  10.277957336780863,
#  26.527088279732357,
#  22.77648348636426,
#  41.566793335282085,
#  39.73448595245446,
#  51.57518674894446,
#  46.214732541810285,
#  62.43789334216629,
#  59.023117076808354]

# %%
values = []
for index, row in df.iterrows():
    if index == 'High BP With Exercise':
        values.append(row.values)
values
y2b = values[0].tolist()
y2b
# Out:
# [12.852371409485638,
#  16.20094191522763,
#  10.35784635587656,
#  17.379117028731606,
#  32.72727272727273,
#  32.205647309536495,
#  45.88470509830056,
#  42.56926952141058,
#  52.67287886218735,
#  53.36696386672924,
#  61.45181476846058,
#  60.38236856080722,
#  6.882189607298692,
#  6.081269134428054,
#  10.35784635587656,
#  9.42643391521197,
#  23.7913858775271,
#  20.606985723264792,
#  38.633342196224405,
#  36.74525589419206,
#  48.257372654155496,
#  43.5609921848454,
#  59.27170868347339,
#  54.50000000000001]

# %%
values = []
for index, row in df.iterrows():
    if index == 'High BP Without Exercise':
        values.append(row.values)
values
y3b = values[0].tolist()
y3b
# Out:
# [17.996742671009773,
#  19.523099850968705,
#  13.989875747814082,
#  19.1869918699187,
#  41.644562334217504,
#  38.72499152255002,
#  48.32876712328767,
#  43.26241134751773,
#  60.36585365853659,
#  59.67023172905526,
#  64.90825688073394,
#  64.1912512716175,
#  9.67741935483871,
#  7.471264367816093,
#  13.989875747814082,
#  13.192612137203168,
#  36.29385964912281,
#  32.68101761252446,
#  46.682946682946685,
#  44.52798663324979,
#  61.16788321167883,
#  56.39841688654354,
#  68.27016520894071,
#  66.78362573099416]

# %%
values = []
for index, row in df.iterrows():
    if index == 'High BP With Drinking':
        values.append(row.values)
values
y4b = values[0].tolist()
y4b
# Out:
# [11.606425702811244,
#  15.96009975062344,
#  11.621621621621625,
#  17.495219885277248,
#  34.505640345056406,
#  34.84097480380009,
#  48.03030303030303,
#  44.081381011097406,
#  54.99058380414312,
#  56.42822619623006,
#  62.54464285714286,
#  63.16648531011969,
#  7.313019390581718,
#  6.546820499060907,
#  11.621621621621625,
#  10.809399477806789,
#  29.064039408866996,
#  26.94840834248079,
#  44.51031539008774,
#  41.00493494840735,
#  56.02280826799715,
#  50.45871559633027,
#  65.22051773729626,
#  62.28391828182295]

# %%
values = []
for index, row in df.iterrows():
    if index == 'High BP Without Drinking':
        values.append(row.values)
values
y5b = values[0].tolist()
y5b
# Out:
# [14.328004736530492,
#  16.857043959847697,
#  10.678080648794772,
#  17.860224331320104,
#  34.87179487179487,
#  32.95774647887324,
#  44.18326693227092,
#  40.14308426073132,
#  53.477498538866165,
#  53.64658402997981,
#  62.61398176291794,
#  59.86336464560205,
#  7.488087134104833,
#  6.076190476190476,
#  10.678080648794772,
#  9.643201542912246,
#  25.165794066317627,
#  20.33820315196135,
#  36.475583864118896,
#  36.49122807017544,
#  47.28294815740162,
#  42.87092882991556,
#  55.62835020845741,
#  49.32533733133433]

# %%
values = []
for index, row in df.iterrows():
    if index == 'High BP Non Smoker':
        values.append(row.values)
values
y6b = values[0].tolist()
y6b
# Out:
# [12.276144907723856,
#  15.761328454826906,
#  9.510301582561958,
#  16.726403823178014,
#  34.64203233256351,
#  33.310580204778155,
#  46.97720515361744,
#  41.91729323308271,
#  54.60664703407657,
#  54.73653622626888,
#  62.78272789581906,
#  62.62740656851642,
#  6.7562523329600594,
#  5.845027455765711,
#  9.510301582561958,
#  8.715789473684211,
#  26.24434389140272,
#  22.268478517005736,
#  41.32629646626893,
#  39.87261146496815,
#  51.02564102564102,
#  46.25756741882224,
#  63.49108789182545,
#  58.4051724137931]

# %%
values = []
for index, row in df.iterrows():
    if index == 'High BP Smoker':
        values.append(row.values)
values
y7b = values[0].tolist()
y7b
# Out:
# [18.314099347717008,
#  21.723518850987432,
#  16.21978021978022,
#  19.818181818181817,
#  35.38461538461539,
#  36.026731470230864,
#  45.04132231404959,
#  43.18766066838046,
#  51.78147268408551,
#  53.25953259532595,
#  61.62005785920925,
#  56.33074935400517,
#  11.312217194570136,
#  10.787878787878787,
#  16.21978021978022,
#  17.003367003367003,
#  28.404669260700388,
#  28.02675585284281,
#  41.97207678883071,
#  39.31847968545216,
#  54.48028673835126,
#  47.29064039408867,
#  58.00604229607252,
#  61.81818181818181]

# %%
plt.figure(figsize=(14,8))

#HBP
plt.scatter(x,y1b, 
            c = 'black',)
#HBP with Excersize
plt.scatter(x,y2b,
            c = 'pink',)
#HBP without Excersize
plt.scatter(x,y3b,
            c = 'blue',)
#labeling
plt.title('Chance of Having been Diagnosed with High Blood Pressure Based on Demographic and Exercise', fontsize=15)
plt.ylabel('Percent ', fontsize = 14)
plt.xlabel('Demographic Group', fontsize = 14)

#show 
plt.savefig('HBPEgraph')

# %%
plt.figure(figsize=(14,8))

#HBP
plt.scatter(x,y1b, 
            c = 'black',)
#HBP with driking
plt.scatter(x,y4b,
            c = 'blue',)
#HBP without without drinking
plt.scatter(x,y5b,
            c = 'pink',)
#labeling
plt.title('Chance of Having been Diagnosed with High Blood Pressure Based on Demographic and Drinking', fontsize=15)
plt.ylabel('Percent ', fontsize = 14)
plt.xlabel('Demographic Group', fontsize = 14)

#show 
plt.savefig('HBPDgraph')

# %%
plt.figure(figsize=(14,8))

#HBP
plt.scatter(x,y1b, 
            c = 'black',)
#HBP with no smoker
plt.scatter(x,y6b,
            c = 'pink',)
#HBP without smoker
plt.scatter(x,y7b,
            c = 'blue',)
#labeling
plt.title('Chance of Having been Diagnosed with High Blood Pressure Based on Demographic and Smoking', fontsize=15)
plt.ylabel('Percent ', fontsize = 14)
plt.xlabel('Demographic Group', fontsize = 14)

#show 
plt.savefig('HBPSgraph')

# %%
values = []
for index, row in df.iterrows():
    if index == 'Heart Attack' or index == 'Heart Attack With Exercise' or index == 'Heart Attack Without Exercise' or index == 'Heart Attack With Drinking' or index == 'Heart Attack Without Drinking' or index == 'Heart Attack Non Smoker' or index == 'Heart Attack Smoker':
        values.append(row.values)  
values

y1c = values[0].tolist()
y2c = values[1].tolist()
y3c = values[2].tolist()
y4c = values[3].tolist()
y5c = values[4].tolist()
y6c = values[5].tolist()
y7c = values[6].tolist()

# %%
values
# Out:
# [array([ 0.53086291,  0.43544781,  0.97175434,  1.07158165,  3.1201849 ,
#          2.68513655,  8.18400148,  8.        , 12.60006961, 10.11522561,
#         18.65946477, 17.00443319,  0.18653816,  0.28102032,  0.89113163,
#          0.90497738,  1.10079862,  1.1717144 ,  5.48085355,  4.90892251,
#          4.44949659,  3.14055917, 10.38423319,  9.1349739 ]),
#  array([ 0.41416166,  0.42386185,  0.73867367,  0.9110021 ,  2.76797829,
#          2.59278991,  7.59746751,  7.68261965, 11.23099559,  9.39699672,
#         16.31205674, 15.45406267,  0.1586672 ,  0.18090732,  0.73867367,
#          0.99750623,  0.9668913 ,  0.91586603,  5.18479128,  4.14031052,
#          3.75335121,  2.70132518,  9.27170868,  8.125     ]),
#  array([ 1.05863192,  0.59612519,  1.19650253,  1.78861789,  3.97877984,
#          2.91624279,  9.20547945,  8.95390071, 16.92073171, 12.74509804,
#         22.55351682, 20.34587996,  0.23894863,  0.64655172,  1.19650253,
#          0.79155673,  1.64473684,  1.99608611,  5.98290598,  6.26566416,
#          6.42335766,  4.74934037, 12.29348882, 10.76023392]),
#  array([ 0.54766134,  0.34614053,  0.78846587,  1.03537532,  2.56410256,
#          2.3138833 ,  6.85258964,  5.56438792, 10.75394506,  8.46065148,
#         15.37993921, 15.62766866,  0.13614704,  0.19047619,  0.78846587,
#          1.06075217,  0.97731239,  0.8052456 ,  3.43949045,  3.39181287,
#          2.87320425,  2.41254524,  6.61107802,  7.04647676]),
#  array([ 0.48192771,  0.70656692,  0.99099099,  1.05162524,  4.57863305,
#          3.46964064,  9.62121212, 10.11097411, 15.34839925, 12.97728371,
#         21.16071429, 18.38955386,  0.27700831,  0.37563724,  0.99099099,
#          0.88772846,  1.41625616,  1.73801683,  6.66350486,  5.60789592,
#          6.12972202,  4.01376147, 11.96069032, 10.00523834]),
#  array([ 0.3417635 ,  0.35181537,  0.53747387,  1.01553166,  2.56607647,
#          2.49525976,  6.83845391,  6.95488722, 11.9478334 ,  9.82177451,
#         17.75188485, 17.02529256,  0.13064576,  0.23184869,  0.53747387,
#          0.58947368,  0.85174341,  0.9425811 ,  4.70399266,  3.73673036,
#          4.06593407,  2.95817281, 10.03892645,  8.6637931 ]),
#  array([ 1.30456598,  0.89766607,  1.84615385,  1.45454545,  5.04273504,
#          4.37424058,  9.96326905, 11.56812339, 15.43942993, 14.26814268,
#         21.79363549, 18.0878553 ,  0.45248869,  0.60606061,  1.84615385,
#          2.18855219,  2.46433204,  3.01003344,  6.98080279,  8.78112713,
#          7.52688172,  6.65024631, 12.28600201, 13.45454545])]

# %%
plt.figure(figsize=(14,8))

plt.scatter(x, y1c,
            color = 'black',
            label = 'Average')
plt.scatter(x, y2c,
            color = 'pink',
            label = 'With Exercise')
plt.scatter(x, y3c,
            color = 'blue',
            label = 'Without Exercise')

plt.title('Chance of Having a Heart Attack Based on Demographics and Exercise', fontsize=18)            
plt.ylabel('Percentage', fontsize=14)
plt.xlabel('Demographics', fontsize=14)


plt.savefig('HAExercise.jpg', dpi=100)

plt.show()

# %%
plt.figure(figsize=(14,8))

plt.scatter(x, y1c,
            color = 'black',
            label = 'Average')
plt.scatter(x, y4c,
            color = 'pink',
            label = 'Without Drinking')
plt.scatter(x, y5c,
            color = 'blue',
            label = 'With Drinking')

plt.title('Chance of Having a Heart Attack Based on Demographics and Drinking', fontsize=18)            
plt.ylabel('Percentage', fontsize=14)
plt.xlabel('Demographics', fontsize=14)



plt.savefig('HADrinking.jpg', dpi=100)

plt.show()

# %%
plt.figure(figsize=(14,8))

plt.scatter(x, y1c,
            color = 'black',
            label = 'Average')
plt.scatter(x, y6c,
            color = 'pink',
            label = 'Without Smoking')
plt.scatter(x, y7c,
            color = 'blue',
            label = 'With Smoking')

plt.title('Chance of Having a Heart Attack Based on Demographics and Smoking', fontsize=18)            
plt.ylabel('Percentage', fontsize=14)
plt.xlabel('Demographics', fontsize=14)



plt.savefig('HASmoking.jpg', dpi=100)

plt.show()
